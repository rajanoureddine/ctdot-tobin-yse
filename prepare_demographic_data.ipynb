# %% [markdown]
# # Setup

# %%
# !pip install fsspec
# Out:
# Requirement already satisfied: fsspec in c:\users\rajan\anaconda3\lib\site-packages (2022.2.0)

# %%
import requests
import pandas as pd
import pathlib

# %%
census_api_key = '529389300296df4951e09f06b7628da596dd8eeb'

# %%
DATA_PATH = pathlib.Path().resolve() / "data"

# %% [markdown]
# # Call API

# %% [markdown]
# ## Set up API Call

# %%
# Set Census API URL and year
host = 'https://api.census.gov/data'
year = '/2018'

# We are using data from the 2018 ACS
dataset_acronym = '/acs/acs1/subject/variables'

# Set the action to get
g = '?get='

# Set the state to get
# location = '&for=state:*'
# Try with codes - setting for all counties in connecticut
location = '&for=county:*&in=state:09'

# Set the user key
usr_key = f"&key={census_api_key}"

# %% [markdown]
# ## Set the variables to extract

# %%
# See here https://api.census.gov/data/2018/acs/acs1/subject/groups/S1901.html
series = "S1901_C01_"
all_categories = [series+f'{x:03}'+"E" for x in range(1,14)]

# %%
variables = ','.join(all_categories)
variables
# Out:
# 'S1901_C01_001E,S1901_C01_002E,S1901_C01_003E,S1901_C01_004E,S1901_C01_005E,S1901_C01_006E,S1901_C01_007E,S1901_C01_008E,S1901_C01_009E,S1901_C01_010E,S1901_C01_011E,S1901_C01_012E,S1901_C01_013E'

# %%
# Let's also name them using a dictionary
var_names = {
    "S1901_C01_001E" : "Households - Total",
    "S1901_C01_002E" : "Less than 10,000",
    "S1901_C01_003E" : "10,000 to 14,999",
    "S1901_C01_004E" : "15,000 to 24,999",
    "S1901_C01_005E" : "25,000 to 34,999",
    "S1901_C01_006E" : "34,000 to 49,999",
    "S1901_C01_007E" : "50,000 to 75,999",
    "S1901_C01_008E" : "75,000 to 99,999", 
    "S1901_C01_009E" : "100,000 to 149,999",
    "S1901_C01_010E" : "150,000 to 199,999",
    "S1901_C01_011E" : "200,000 or more",
    "S1901_C01_012E" : "Median",
    "S1901_C01_013E" : "Mean"
}

# %% [markdown]
# ## Create the call

# %%
#Put it all together in one f-string:
query_url = f"{host}{year}{dataset_acronym}{g}{variables}{location}{usr_key}"

# %%
# Check the query url
query_url
# Out:
# 'https://api.census.gov/data/2018/acs/acs1/subject/variables?get=S1901_C01_001E,S1901_C01_002E,S1901_C01_003E,S1901_C01_004E,S1901_C01_005E,S1901_C01_006E,S1901_C01_007E,S1901_C01_008E,S1901_C01_009E,S1901_C01_010E,S1901_C01_011E,S1901_C01_012E,S1901_C01_013E&for=county:*&in=state:09&key=529389300296df4951e09f06b7628da596dd8eeb'

# %%
# Use requests package to call out to the API
response = requests.get(query_url)

# %%
response
# Out:
# <Response [200]>

# %%
# Convert JSON response into dataframe
df = pd.read_json(response.text)

# Set the first row as the column names
df. columns = df.iloc[0] 

# Now get rid of the first row, that is now duplicated
df = df[1:]

# Now reset the index
df = df.reset_index(drop=True)

# Set the column names
df.rename(columns=var_names, inplace=True)

# %%
# Save
df.to_csv(DATA_PATH / "S1901_CT.csv")

# %% [markdown]
# # Direct import of income by ZIP

# %%
income_by_zip = pd.read_csv(DATA_PATH /"income_by_zip"/ "ACSST5Y2018.S1901-Data.csv", header = [0,1])

# %%
income_by_zip_small = income_by_zip[["GEO_ID", "NAME", "S1901_C01_012E"]]
income_by_zip_small["ZIP"] = income_by_zip_small["NAME"]["Geographic Area Name"].str[-6:]
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_12896\3694600316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_by_zip_small["ZIP"] = income_by_zip_small["NAME"]["Geographic Area Name"].str[-6:]

# %%
income_by_zip_small.to_csv(DATA_PATH / "S1901_CT_income_by_zip.csv")

# %%
list(income_by_zip.columns)
# Out:
# [('GEO_ID', 'Geography'),
#  ('NAME', 'Geographic Area Name'),
#  ('S1901_C01_001E', 'Estimate!!Households!!Total'),
#  ('S1901_C01_001EA', 'Annotation of Estimate!!Households!!Total'),
#  ('S1901_C01_001M', 'Margin of Error!!Households MOE!!Total'),
#  ('S1901_C01_001MA', 'Annotation of Margin of Error!!Households MOE!!Total'),
#  ('S1901_C01_002E', 'Estimate!!Households!!Total!!Less than $10,000'),
#  ('S1901_C01_002EA',
#   'Annotation of Estimate!!Households!!Total!!Less than $10,000'),
#  ('S1901_C01_002M',
#   'Margin of Error!!Households MOE!!Total!!Less than $10,000'),
#  ('S1901_C01_002MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!Less than $10,000'),
#  ('S1901_C01_003E', 'Estimate!!Households!!Total!!$10,000 to $14,999'),
#  ('S1901_C01_003M',
#   'Margin of Error!!Households MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C01_003MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C01_003EA',
#   'Annotation of Estimate!!Households!!Total!!$10,000 to $14,999'),
#  ('S1901_C01_004E', 'Estimate!!Households!!Total!!$15,000 to $24,999'),
#  ('S1901_C01_004EA',
#   'Annotation of Estimate!!Households!!Total!!$15,000 to $24,999'),
#  ('S1901_C01_004M',
#   'Margin of Error!!Households MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C01_004MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C01_005E', 'Estimate!!Households!!Total!!$25,000 to $34,999'),
#  ('S1901_C01_005M',
#   'Margin of Error!!Households MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C01_005MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C01_005EA',
#   'Annotation of Estimate!!Households!!Total!!$25,000 to $34,999'),
#  ('S1901_C01_006E', 'Estimate!!Households!!Total!!$35,000 to $49,999'),
#  ('S1901_C01_006EA',
#   'Annotation of Estimate!!Households!!Total!!$35,000 to $49,999'),
#  ('S1901_C01_006M',
#   'Margin of Error!!Households MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C01_006MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C01_007E', 'Estimate!!Households!!Total!!$50,000 to $74,999'),
#  ('S1901_C01_007M',
#   'Margin of Error!!Households MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C01_007MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C01_007EA',
#   'Annotation of Estimate!!Households!!Total!!$50,000 to $74,999'),
#  ('S1901_C01_008E', 'Estimate!!Households!!Total!!$75,000 to $99,999'),
#  ('S1901_C01_008EA',
#   'Annotation of Estimate!!Households!!Total!!$75,000 to $99,999'),
#  ('S1901_C01_008M',
#   'Margin of Error!!Households MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C01_008MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C01_009E', 'Estimate!!Households!!Total!!$100,000 to $149,999'),
#  ('S1901_C01_009M',
#   'Margin of Error!!Households MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C01_009MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C01_009EA',
#   'Annotation of Estimate!!Households!!Total!!$100,000 to $149,999'),
#  ('S1901_C01_010E', 'Estimate!!Households!!Total!!$150,000 to $199,999'),
#  ('S1901_C01_010M',
#   'Margin of Error!!Households MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C01_010MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C01_010EA',
#   'Annotation of Estimate!!Households!!Total!!$150,000 to $199,999'),
#  ('S1901_C01_011E', 'Estimate!!Households!!Total!!$200,000 or more'),
#  ('S1901_C01_011M',
#   'Margin of Error!!Households MOE!!Total!!$200,000 or more'),
#  ('S1901_C01_011MA',
#   'Annotation of Margin of Error!!Households MOE!!Total!!$200,000 or more'),
#  ('S1901_C01_011EA',
#   'Annotation of Estimate!!Households!!Total!!$200,000 or more'),
#  ('S1901_C01_012E', 'Estimate!!Households!!Median income (dollars)'),
#  ('S1901_C01_012M',
#   'Margin of Error!!Households MOE!!Median income (dollars)'),
#  ('S1901_C01_012MA',
#   'Annotation of Margin of Error!!Households MOE!!Median income (dollars)'),
#  ('S1901_C01_012EA',
#   'Annotation of Estimate!!Households!!Median income (dollars)'),
#  ('S1901_C01_013E', 'Estimate!!Households!!Mean income (dollars)'),
#  ('S1901_C01_013M', 'Margin of Error!!Households MOE!!Mean income (dollars)'),
#  ('S1901_C01_013MA',
#   'Annotation of Margin of Error!!Households MOE!!Mean income (dollars)'),
#  ('S1901_C01_013EA',
#   'Annotation of Estimate!!Households!!Mean income (dollars)'),
#  ('S1901_C01_014E',
#   'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C01_014M',
#   'Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C01_014MA',
#   'Annotation of Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C01_014EA',
#   'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C01_015E',
#   'Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C01_015M',
#   'Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C01_015MA',
#   'Annotation of Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C01_015EA',
#   'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C01_016E',
#   'Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C01_016M',
#   'Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C01_016MA',
#   'Annotation of Margin of Error!!Households MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C01_016EA',
#   'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C02_001E', 'Estimate!!Families!!Total'),
#  ('S1901_C02_001EA', 'Annotation of Estimate!!Families!!Total'),
#  ('S1901_C02_001M', 'Margin of Error!!Families MOE!!Total'),
#  ('S1901_C02_001MA', 'Annotation of Margin of Error!!Families MOE!!Total'),
#  ('S1901_C03_001E', 'Estimate!!Married-couple families!!Total'),
#  ('S1901_C03_001M', 'Margin of Error!!Married-couple families MOE!!Total'),
#  ('S1901_C03_001MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total'),
#  ('S1901_C03_001EA', 'Annotation of Estimate!!Married-couple families!!Total'),
#  ('S1901_C04_001E', 'Estimate!!Nonfamily households!!Total'),
#  ('S1901_C04_001EA', 'Annotation of Estimate!!Nonfamily households!!Total'),
#  ('S1901_C04_001M', 'Margin of Error!!Nonfamily households MOE!!Total'),
#  ('S1901_C04_001MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total'),
#  ('S1901_C02_002E', 'Estimate!!Families!!Total!!Less than $10,000'),
#  ('S1901_C02_002M', 'Margin of Error!!Families MOE!!Total!!Less than $10,000'),
#  ('S1901_C02_002MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!Less than $10,000'),
#  ('S1901_C02_002EA',
#   'Annotation of Estimate!!Families!!Total!!Less than $10,000'),
#  ('S1901_C03_002E',
#   'Estimate!!Married-couple families!!Total!!Less than $10,000'),
#  ('S1901_C03_002EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!Less than $10,000'),
#  ('S1901_C03_002M',
#   'Margin of Error!!Married-couple families MOE!!Total!!Less than $10,000'),
#  ('S1901_C03_002MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!Less than $10,000'),
#  ('S1901_C04_002E',
#   'Estimate!!Nonfamily households!!Total!!Less than $10,000'),
#  ('S1901_C04_002M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!Less than $10,000'),
#  ('S1901_C04_002MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!Less than $10,000'),
#  ('S1901_C04_002EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!Less than $10,000'),
#  ('S1901_C02_003E', 'Estimate!!Families!!Total!!$10,000 to $14,999'),
#  ('S1901_C02_003M',
#   'Margin of Error!!Families MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C02_003MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C02_003EA',
#   'Annotation of Estimate!!Families!!Total!!$10,000 to $14,999'),
#  ('S1901_C03_003E',
#   'Estimate!!Married-couple families!!Total!!$10,000 to $14,999'),
#  ('S1901_C03_003M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C03_003MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C03_003EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$10,000 to $14,999'),
#  ('S1901_C04_003E',
#   'Estimate!!Nonfamily households!!Total!!$10,000 to $14,999'),
#  ('S1901_C04_003EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$10,000 to $14,999'),
#  ('S1901_C04_003M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C04_003MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$10,000 to $14,999'),
#  ('S1901_C02_004E', 'Estimate!!Families!!Total!!$15,000 to $24,999'),
#  ('S1901_C02_004M',
#   'Margin of Error!!Families MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C02_004MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C02_004EA',
#   'Annotation of Estimate!!Families!!Total!!$15,000 to $24,999'),
#  ('S1901_C03_004E',
#   'Estimate!!Married-couple families!!Total!!$15,000 to $24,999'),
#  ('S1901_C03_004EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$15,000 to $24,999'),
#  ('S1901_C03_004M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C03_004MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C04_004E',
#   'Estimate!!Nonfamily households!!Total!!$15,000 to $24,999'),
#  ('S1901_C04_004EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$15,000 to $24,999'),
#  ('S1901_C04_004M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C04_004MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$15,000 to $24,999'),
#  ('S1901_C02_005E', 'Estimate!!Families!!Total!!$25,000 to $34,999'),
#  ('S1901_C02_005EA',
#   'Annotation of Estimate!!Families!!Total!!$25,000 to $34,999'),
#  ('S1901_C02_005M',
#   'Margin of Error!!Families MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C02_005MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C03_005E',
#   'Estimate!!Married-couple families!!Total!!$25,000 to $34,999'),
#  ('S1901_C03_005EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$25,000 to $34,999'),
#  ('S1901_C03_005M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C03_005MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C04_005E',
#   'Estimate!!Nonfamily households!!Total!!$25,000 to $34,999'),
#  ('S1901_C04_005M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C04_005MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$25,000 to $34,999'),
#  ('S1901_C04_005EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$25,000 to $34,999'),
#  ('S1901_C02_006E', 'Estimate!!Families!!Total!!$35,000 to $49,999'),
#  ('S1901_C02_006EA',
#   'Annotation of Estimate!!Families!!Total!!$35,000 to $49,999'),
#  ('S1901_C02_006M',
#   'Margin of Error!!Families MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C02_006MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C03_006E',
#   'Estimate!!Married-couple families!!Total!!$35,000 to $49,999'),
#  ('S1901_C03_006M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C03_006MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C03_006EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$35,000 to $49,999'),
#  ('S1901_C04_006E',
#   'Estimate!!Nonfamily households!!Total!!$35,000 to $49,999'),
#  ('S1901_C04_006M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C04_006MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$35,000 to $49,999'),
#  ('S1901_C04_006EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$35,000 to $49,999'),
#  ('S1901_C02_007E', 'Estimate!!Families!!Total!!$50,000 to $74,999'),
#  ('S1901_C02_007EA',
#   'Annotation of Estimate!!Families!!Total!!$50,000 to $74,999'),
#  ('S1901_C02_007M',
#   'Margin of Error!!Families MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C02_007MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C03_007E',
#   'Estimate!!Married-couple families!!Total!!$50,000 to $74,999'),
#  ('S1901_C03_007M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C03_007MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C03_007EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$50,000 to $74,999'),
#  ('S1901_C04_007E',
#   'Estimate!!Nonfamily households!!Total!!$50,000 to $74,999'),
#  ('S1901_C04_007M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C04_007MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$50,000 to $74,999'),
#  ('S1901_C04_007EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$50,000 to $74,999'),
#  ('S1901_C02_008E', 'Estimate!!Families!!Total!!$75,000 to $99,999'),
#  ('S1901_C02_008EA',
#   'Annotation of Estimate!!Families!!Total!!$75,000 to $99,999'),
#  ('S1901_C02_008M',
#   'Margin of Error!!Families MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C02_008MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C03_008E',
#   'Estimate!!Married-couple families!!Total!!$75,000 to $99,999'),
#  ('S1901_C03_008M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C03_008MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C03_008EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$75,000 to $99,999'),
#  ('S1901_C04_008E',
#   'Estimate!!Nonfamily households!!Total!!$75,000 to $99,999'),
#  ('S1901_C04_008EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$75,000 to $99,999'),
#  ('S1901_C04_008M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C04_008MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$75,000 to $99,999'),
#  ('S1901_C02_009E', 'Estimate!!Families!!Total!!$100,000 to $149,999'),
#  ('S1901_C02_009M',
#   'Margin of Error!!Families MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C02_009MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C02_009EA',
#   'Annotation of Estimate!!Families!!Total!!$100,000 to $149,999'),
#  ('S1901_C03_009E',
#   'Estimate!!Married-couple families!!Total!!$100,000 to $149,999'),
#  ('S1901_C03_009M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C03_009MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C03_009EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$100,000 to $149,999'),
#  ('S1901_C04_009E',
#   'Estimate!!Nonfamily households!!Total!!$100,000 to $149,999'),
#  ('S1901_C04_009EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$100,000 to $149,999'),
#  ('S1901_C04_009M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C04_009MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$100,000 to $149,999'),
#  ('S1901_C02_010E', 'Estimate!!Families!!Total!!$150,000 to $199,999'),
#  ('S1901_C02_010M',
#   'Margin of Error!!Families MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C02_010MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C02_010EA',
#   'Annotation of Estimate!!Families!!Total!!$150,000 to $199,999'),
#  ('S1901_C03_010E',
#   'Estimate!!Married-couple families!!Total!!$150,000 to $199,999'),
#  ('S1901_C03_010M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C03_010MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C03_010EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$150,000 to $199,999'),
#  ('S1901_C04_010E',
#   'Estimate!!Nonfamily households!!Total!!$150,000 to $199,999'),
#  ('S1901_C04_010EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$150,000 to $199,999'),
#  ('S1901_C04_010M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C04_010MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$150,000 to $199,999'),
#  ('S1901_C02_011E', 'Estimate!!Families!!Total!!$200,000 or more'),
#  ('S1901_C02_011EA',
#   'Annotation of Estimate!!Families!!Total!!$200,000 or more'),
#  ('S1901_C02_011M', 'Margin of Error!!Families MOE!!Total!!$200,000 or more'),
#  ('S1901_C02_011MA',
#   'Annotation of Margin of Error!!Families MOE!!Total!!$200,000 or more'),
#  ('S1901_C03_011E',
#   'Estimate!!Married-couple families!!Total!!$200,000 or more'),
#  ('S1901_C03_011M',
#   'Margin of Error!!Married-couple families MOE!!Total!!$200,000 or more'),
#  ('S1901_C03_011MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Total!!$200,000 or more'),
#  ('S1901_C03_011EA',
#   'Annotation of Estimate!!Married-couple families!!Total!!$200,000 or more'),
#  ('S1901_C04_011E', 'Estimate!!Nonfamily households!!Total!!$200,000 or more'),
#  ('S1901_C04_011M',
#   'Margin of Error!!Nonfamily households MOE!!Total!!$200,000 or more'),
#  ('S1901_C04_011MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Total!!$200,000 or more'),
#  ('S1901_C04_011EA',
#   'Annotation of Estimate!!Nonfamily households!!Total!!$200,000 or more'),
#  ('S1901_C02_012E', 'Estimate!!Families!!Median income (dollars)'),
#  ('S1901_C02_012M', 'Margin of Error!!Families MOE!!Median income (dollars)'),
#  ('S1901_C02_012MA',
#   'Annotation of Margin of Error!!Families MOE!!Median income (dollars)'),
#  ('S1901_C02_012EA',
#   'Annotation of Estimate!!Families!!Median income (dollars)'),
#  ('S1901_C03_012E',
#   'Estimate!!Married-couple families!!Median income (dollars)'),
#  ('S1901_C03_012M',
#   'Margin of Error!!Married-couple families MOE!!Median income (dollars)'),
#  ('S1901_C03_012MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Median income (dollars)'),
#  ('S1901_C03_012EA',
#   'Annotation of Estimate!!Married-couple families!!Median income (dollars)'),
#  ('S1901_C04_012E', 'Estimate!!Nonfamily households!!Median income (dollars)'),
#  ('S1901_C04_012EA',
#   'Annotation of Estimate!!Nonfamily households!!Median income (dollars)'),
#  ('S1901_C04_012M',
#   'Margin of Error!!Nonfamily households MOE!!Median income (dollars)'),
#  ('S1901_C04_012MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Median income (dollars)'),
#  ('S1901_C02_013E', 'Estimate!!Families!!Mean income (dollars)'),
#  ('S1901_C02_013M', 'Margin of Error!!Families MOE!!Mean income (dollars)'),
#  ('S1901_C02_013MA',
#   'Annotation of Margin of Error!!Families MOE!!Mean income (dollars)'),
#  ('S1901_C02_013EA',
#   'Annotation of Estimate!!Families!!Mean income (dollars)'),
#  ('S1901_C03_013E',
#   'Estimate!!Married-couple families!!Mean income (dollars)'),
#  ('S1901_C03_013M',
#   'Margin of Error!!Married-couple families MOE!!Mean income (dollars)'),
#  ('S1901_C03_013MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!Mean income (dollars)'),
#  ('S1901_C03_013EA',
#   'Annotation of Estimate!!Married-couple families!!Mean income (dollars)'),
#  ('S1901_C04_013E', 'Estimate!!Nonfamily households!!Mean income (dollars)'),
#  ('S1901_C04_013M',
#   'Margin of Error!!Nonfamily households MOE!!Mean income (dollars)'),
#  ('S1901_C04_013MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!Mean income (dollars)'),
#  ('S1901_C04_013EA',
#   'Annotation of Estimate!!Nonfamily households!!Mean income (dollars)'),
#  ('S1901_C02_014E',
#   'Estimate!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C02_014M',
#   'Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C02_014MA',
#   'Annotation of Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C02_014EA',
#   'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C03_014E',
#   'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C03_014EA',
#   'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C03_014M',
#   'Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C03_014MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C04_014E',
#   'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C04_014M',
#   'Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C04_014MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C04_014EA',
#   'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months'),
#  ('S1901_C02_015E',
#   'Estimate!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C02_015M',
#   'Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C02_015MA',
#   'Annotation of Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C02_015EA',
#   'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C03_015E',
#   'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C03_015M',
#   'Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C03_015MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C03_015EA',
#   'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C04_015E',
#   'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C04_015M',
#   'Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C04_015MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C04_015EA',
#   'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months'),
#  ('S1901_C02_016E',
#   'Estimate!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C02_016M',
#   'Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C02_016MA',
#   'Annotation of Margin of Error!!Families MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C02_016EA',
#   'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C03_016E',
#   'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C03_016EA',
#   'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C03_016M',
#   'Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C03_016MA',
#   'Annotation of Margin of Error!!Married-couple families MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C04_016E',
#   'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C04_016EA',
#   'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C04_016M',
#   'Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('S1901_C04_016MA',
#   'Annotation of Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months'),
#  ('Unnamed: 258_level_0', 'Unnamed: 258_level_1')]
