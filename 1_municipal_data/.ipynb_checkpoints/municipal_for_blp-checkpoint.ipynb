# %% [markdown]
# # Quality Check - Reconstructed Municipal Data

# %% [markdown]
# The purpose of this file is to Quality Check the re-constructed municipal data, compiled by RN in the file `reconstruct_municipal.ipynb`

# %%
# !pip install seaborn

# %%
# Warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# DataFrames
import pandas as pd

# Path Management
import pathlib
import os

# Progress Tracking
from tqdm import tqdm

# Regular expressions
import re

# Maths
import numpy as np

# System
from sys import platform
# import platform

# Import Geopandas
import geopandas as gpd
from shapely.geometry import Point
from geopandas.tools import geocode
import geopy

# Heatmaps
import seaborn as sns

# %%
# Set paths
path = raw_path = pathlib.Path().resolve()

if platform == "windows":
    raw_path = pathlib.Path().resolve().parent.parent / "Dropbox" / "2019 MV Data by Town" / "Vehicles_2022" / "Compiled"
elif platform == "linux":
    raw_path = pathlib.Path().resolve().parent.parent / "rn_home"/ "data" / "municipal_dataset_latest"
    vin_detail_output = pathlib.Path().resolve().parent.parent / "rn_home"/ "data" / "vin_matching"
raw_path.is_dir()
# Out:
# True

# %% [markdown]
# # Functions

# %%
def fetch_vin_data(vin, variables = None):
        """
        Input: An unmatched, but corrected VIN
        Output: A matched VIN or NA
        
        """
        if not variables:
            variables = ["Manufacturer Name", "Model", "Model Year", "Fuel Type - Primary", "Electrification Level"]
        else:
            variables = variables
        
        url = (f"https://vpic.nhtsa.dot.gov/api/vehicles/DecodeVin/{vin.strip()}?format=csv")

        # Download response
        resp_df = pd.read_csv(url)

        # Extract needed
        resp_df = resp_df.loc[:, ["variable", "value"]].T
        # resp_df = resp_df.loc[resp_df["variable"].isin(variables), ["variable", "value"]].T
        resp_df.columns = resp_df.iloc[0]
        resp_df = resp_df.drop("variable", axis = 0)
        resp_df["vin_corrected"] = vin
        
        return resp_df

# %% [markdown]
# # 1. Load data

# %%
def reset_recompiled_data(version):
    recompiled_data = pd.read_csv(raw_path / f"2019-21_data_compiled_RN_{version}.csv", index_col = 0)
    return recompiled_data

def reset_original_data():
    if platform == "linux":
        original_data = pd.read_csv(path.parent.parent /"data"/"municipal_compilation"/"old_file"/ "2019-21 data compiled.csv", chunksize = 1000)
    else:
        original_data = pd.read_csv(raw_path / "2019-21 data compiled.csv", chunksize = 1000)
    return original_data

# %%
recompiled_data = reset_recompiled_data("102323")
# Out:
# /tmp/ipykernel_1210693/2915909440.py:2: DtypeWarning: Columns (6,7,8,9,10,12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   recompiled_data = pd.read_csv(raw_path / f"2019-21_data_compiled_RN_{version}.csv", index_col = 0)

# %% [markdown]
# # Checks

# %% [markdown]
# ## Missing Vins

# %%
missing_vins = recompiled_data.loc[recompiled_data["vehicle_id"].isna(), ["record_from", "vehicle_id"]].reset_index().groupby("record_from").count()[["index"]]

# %%
missing_vins.sort_values("index", ascending = False)
# Out:
#                                    index
# record_from
# 11_Bloomfield_MVData_2019.csv      19643
# 107_Orange_MVData_2020.csv         14650
# 124_Seymour_MV_21.csv              13860
# 016_Bridgewater_MV_21_ALTERED.csv   4886
# 141_Thompson_MV_21.xlsx              457
# 121_Salem_MVData_2019.csv            218
# 101_North_Haven_MV_21.xlsx            84
# 083_Middletown_MV_21.xlsx             82
# 136_Sterling_MVData_2019.csv          69
# 105_Old_Lyme_MVData_2019.csv          37
# 163_Windham_MV_21.xlsx                37
# 136_Sterling_MV_21.xlsx               34
# 163_Windham_MVData_2020.csv           34
# 147_Voluntown_MVData_2020.csv         29
# 024_Chaplin_MV_21.xlsx                29
# 028_Colchester_MV_21_ALTERED.csv       8
# 077_Manchester_MV_21_ALTERED.csv       2
# 089_New_Britain_MV_21.xlsx             2
# 62_Hamden_MVData_2020.csv              2
# 63_Hampton_MVData_2019.csv             2
# 159_Wethersfield_MV_21.xlsx            1
# 150_Washington_MVData_2020.csv         1
# 159_Wethersfield_MVData_2019.csv       1

# %% [markdown]
# ## 0. SUMMARY

# %% [markdown]
# ## Check VIN detail

# %%
# Get a set of 5000 random vins
vins = recompiled_data["vehicle_id"].unique().tolist()
random_indices = np.random.randint(0, len(vins), 5000)
vins_sample = [vins[i] for i in random_indices]

# %%
vins_sample_details = pd.DataFrame([])

for vin in tqdm(vins_sample):
    try:
        chars = fetch_vin_data(vin)
        vins_sample_details = pd.concat([vins_sample_details, chars]).reset_index(drop=True)
    except:
        pass
# Out:
#  30%|███       | 1511/5000 [05:22<10:56,  5.32it/s]

# %%
vins_sample_details.to_csv(vin_detail_output / "municipal_vin_details_sample.csv")

# %%
vins_sample_details = pd.read_csv(vin_detail_output / "municipal_vin_details_sample.csv", index_col = [0])
# Out:
# /tmp/ipykernel_1210693/874121374.py:1: DtypeWarning: Columns (57,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   vins_sample_details = pd.read_csv(vin_detail_output / "municipal_vin_details_sample.csv", index_col = [0])

# %%
vins_sample_details.columns.tolist()
# Out:
# ['Suggested VIN',
#  'Error Code',
#  'Possible Values',
#  'Additional Error Text',
#  'Error Text',
#  'Vehicle Descriptor',
#  'Destination Market',
#  'Make',
#  'Manufacturer Name',
#  'Model',
#  'Model Year',
#  'Plant City',
#  'Series',
#  'Trim',
#  'Vehicle Type',
#  'Plant Country',
#  'Plant Company Name',
#  'Plant State',
#  'Trim2',
#  'Series2',
#  'Note',
#  'Base Price ($)',
#  'Non-Land Use',
#  'Body Class',
#  'Doors',
#  'Windows',
#  'Wheel Base Type',
#  'Track Width (inches)',
#  'Gross Vehicle Weight Rating From',
#  'Bed Length (inches)',
#  'Curb Weight (pounds)',
#  'Wheel Base (inches) From',
#  'Wheel Base (inches) To',
#  'Gross Combination Weight Rating From',
#  'Gross Combination Weight Rating To',
#  'Gross Vehicle Weight Rating To',
#  'Bed Type',
#  'Cab Type',
#  'Trailer Type Connection',
#  'Trailer Body Type',
#  'Trailer Length (feet)',
#  'Other Trailer Info',
#  'Number of Wheels',
#  'Wheel Size Front (inches)',
#  'Wheel Size Rear (inches)',
#  'Entertainment System',
#  'Steering Location',
#  'Number of Seats',
#  'Number of Seat Rows',
#  'Transmission Style',
#  'Transmission Speeds',
#  'Drive Type',
#  'Axles',
#  'Axle Configuration',
#  'Brake System Type',
#  'Brake System Description',
#  'Other Battery Info',
#  'Battery Type',
#  'Number of Battery Cells per Module',
#  'Battery Current (Amps) From',
#  'Battery Voltage (Volts) From',
#  'Battery Energy (kWh) From',
#  'EV Drive Unit',
#  'Battery Current (Amps) To',
#  'Battery Voltage (Volts) To',
#  'Battery Energy (kWh) To',
#  'Number of Battery Modules per Pack',
#  'Number of Battery Packs per Vehicle',
#  'Charger Level',
#  'Charger Power (kW)',
#  'Engine Number of Cylinders',
#  'Displacement (CC)',
#  'Displacement (CI)',
#  'Displacement (L)',
#  'Engine Stroke Cycles',
#  'Engine Model',
#  'Engine Power (kW)',
#  'Fuel Type - Primary',
#  'Valve Train Design',
#  'Engine Configuration',
#  'Fuel Type - Secondary',
#  'Fuel Delivery / Fuel Injection Type',
#  'Engine Brake (hp) From',
#  'Cooling Type',
#  'Engine Brake (hp) To',
#  'Electrification Level',
#  'Other Engine Info',
#  'Turbo',
#  'Top Speed (MPH)',
#  'Engine Manufacturer',
#  'Pretensioner',
#  'Seat Belt Type',
#  'Other Restraint System Info',
#  'Curtain Air Bag Locations',
#  'Seat Cushion Air Bag Locations',
#  'Front Air Bag Locations',
#  'Knee Air Bag Locations',
#  'Side Air Bag Locations',
#  'Anti-lock Braking System (ABS)',
#  'Electronic Stability Control (ESC)',
#  'Traction Control',
#  'Tire Pressure Monitoring System (TPMS) Type',
#  'Active Safety System Note',
#  'Auto-Reverse System for Windows and Sunroofs',
#  'Automatic Pedestrian Alerting Sound (for Hybrid and EV only)',
#  'Event Data Recorder (EDR)',
#  'Keyless Ignition',
#  'SAE Automation Level From',
#  'SAE Automation Level To',
#  'Adaptive Cruise Control (ACC)',
#  'Crash Imminent Braking (CIB)',
#  'Blind Spot Warning (BSW)',
#  'Forward Collision Warning (FCW)',
#  'Lane Departure Warning (LDW)',
#  'Lane Keeping Assistance (LKA)',
#  'Backup Camera',
#  'Parking Assist',
#  'Bus Length (feet)',
#  'Bus Floor Configuration Type',
#  'Bus Type',
#  'Other Bus Info',
#  'Custom Motorcycle Type',
#  'Motorcycle Suspension Type',
#  'Motorcycle Chassis Type',
#  'Other Motorcycle Info',
#  'Dynamic Brake Support (DBS)',
#  'Pedestrian Automatic Emergency Braking (PAEB)',
#  'Automatic Crash Notification (ACN) / Advanced Automatic Crash Notification (AACN)',
#  'Daytime Running Light (DRL)',
#  'Headlamp Light Source',
#  'Semiautomatic Headlamp Beam Switching',
#  'Adaptive Driving Beam (ADB)',
#  'Rear Cross Traffic Alert',
#  'Rear Automatic Emergency Braking',
#  'Blind Spot Intervention (BSI)',
#  'Lane Centering Assistance',
#  'vin_corrected']

# %%
vars_wanted = ['Make', 'Manufacturer Name', 'Model',
               'Model Year', 'Trim', 'Base Price ($)',
               'Body Class', 'Doors', 'Curb Weight (pounds)', 'Gross Combination Weight Rating From', 'Battery Energy (kWh) From',
               'Engine Power (kW)',
               'Wheel Base (inches) From', 'Wheel Base (inches) To',
               'Engine Brake (hp) From']

# %%
missing_details = vins_sample_details.notna().sum()
missing_details_select = pd.DataFrame(missing_details.loc[vars_wanted]).reset_index().rename({0: "Number Available"}, axis =1)
missing_details_select["Percentage"] = missing_details_select.loc[:, "Number Available"]/5000

# %%
missing_details_select.sort_values("Percentage", ascending = False)
# Out:
#                                    index  Number Available  Percentage
# 1                      Manufacturer Name              4500      0.9000
# 0                                   Make              4498      0.8996
# 3                             Model Year              4494      0.8988
# 2                                  Model              4441      0.8882
# 6                             Body Class              4438      0.8876
# 7                                  Doors              3588      0.7176
# 14                Engine Brake (hp) From              2432      0.4864
# 4                                   Trim              1877      0.3754
# 12              Wheel Base (inches) From               898      0.1796
# 5                         Base Price ($)               657      0.1314
# 8                   Curb Weight (pounds)                41      0.0082
# 13                Wheel Base (inches) To                31      0.0062
# 11                     Engine Power (kW)                28      0.0056
# 10             Battery Energy (kWh) From                 3      0.0006
# 9   Gross Combination Weight Rating From                 0      0.0000

# %%
print(missing_details_select.sort_values("Percentage", ascending = False).to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
# index & Number Available & Percentage \\
# \midrule
# Manufacturer Name & 4500 & 0.900000 \\
# Make & 4498 & 0.899600 \\
# Model Year & 4494 & 0.898800 \\
# Model & 4441 & 0.888200 \\
# Body Class & 4438 & 0.887600 \\
# Doors & 3588 & 0.717600 \\
# Engine Brake (hp) From & 2432 & 0.486400 \\
# Trim & 1877 & 0.375400 \\
# Wheel Base (inches) From & 898 & 0.179600 \\
# Base Price ($) & 657 & 0.131400 \\
# Curb Weight (pounds) & 41 & 0.008200 \\
# Wheel Base (inches) To & 31 & 0.006200 \\
# Engine Power (kW) & 28 & 0.005600 \\
# Battery Energy (kWh) From & 3 & 0.000600 \\
# Gross Combination Weight Rating From & 0 & 0.000000 \\
# \bottomrule
# \end{tabular}

# %%
vars_wanted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vars_wanted
#
# NameError: name 'vars_wanted' is not defined

# %% [markdown]
# ## 1a. Define required functions

# %%
def create_valid_zip(zip):
    try:
        zip_str = str(zip)
        zip_str = zip_str.strip()
        has_dot = re.search(r"\.", zip_str)

        # Get rid of decimal places
        if has_dot:
            zip_str = zip_str[0:re.search(r"\.", zip_str).start()]

        split_zip = re.split("-", zip_str)
        
        if len(split_zip) == 2:
            return create_valid_zip(split_zip[0])
        else:
            # If length is less than 4, return na
            if len(zip_str) < 4:
                return np.NaN
                
            # If length is 4 or 5, check it
            elif((len(zip_str) == 5) | (len(zip_str) == 4)):
                matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)
                if matched:
                    return matched[0].zfill(5)
                else:
                    return np.NaN
            # If the zip is between 5 and 8 (inclusive) long, we assume the first 4 are the first part
            # And the second 4 are the second part
            # There is no other way to do this... 
            elif((len(zip_str) > 5) & (len(zip_str)<9)):
                return create_valid_zip(zip_str[0:4])
            elif (len(zip_str) == 9):
                return create_valid_zip(zip_str[0:5])
            else:
                return np.NaN
        
    except Exception as e:
        print(e)
        return np.NaN

def ct_zip(zip):
    try:
        zip_str = str(int(zip)).zfill(5)
        if zip_str[0:2] == "06":
            return True
        else:
            return False
    except:
        return False
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1555671/1937731973.py:22: SyntaxWarning: invalid escape sequence '\s'
#   matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)

# %% [markdown]
# ## 1b. CT Zips and State inconsistencies

# %% [markdown]
# ### 1bi. Extract from dataset

# %%
recompiled_data = reset_recompiled_data("102323")

# %%
ct_zip_nonct_state = pd.DataFrame()
nonct_zip_ct_state = pd.DataFrame()

i = 0

for chunk in tqdm(recompiled_data):
    # Clean up
    chunk = chunk.reset_index()
    chunk = chunk.rename(columns = {"index" : "original_index"})
    
    # Check that the ZIPs and the states match
    chunk_corrected_zips = chunk
    chunk_corrected_zips["zip_corrected"] = chunk_corrected_zips["zip"].apply(lambda x: create_valid_zip(x))
    # get_valid_zips(chunk, "zip")
    # Join them
    #chunk_corrected_zips = chunk.join(valid_zips).reset_index(drop = True)
    
    # Get CT zip codes
    ct_zip_mask = chunk_corrected_zips["zip_corrected"].apply(lambda x: ct_zip(x))
    ct_state_mask = chunk_corrected_zips["state"] == "CT"
    ct_zip_nonct_state_mask = ~ct_state_mask & ct_zip_mask
    nonct_zip_ct_state_mask = ~ct_zip_mask & ct_state_mask
    
    # Get ct zip nonct state
    ct_zip_nonct_state_chunk = chunk_corrected_zips.loc[ct_zip_nonct_state_mask]
    ct_zip_nonct_state_chunk = ct_zip_nonct_state_chunk.dropna(axis = 0, subset = ["zip_corrected"])
    ct_zip_nonct_state = pd.concat([ct_zip_nonct_state, ct_zip_nonct_state_chunk])

    # Get non CT zip ct state
    nonct_zip_ct_state_chunk = chunk_corrected_zips.loc[nonct_zip_ct_state_mask]
    nonct_zip_ct_state_chunk = nonct_zip_ct_state_chunk.dropna(axis = 0, subset = ["zip_corrected"])
    nonct_zip_ct_state = pd.concat([nonct_zip_ct_state, nonct_zip_ct_state_chunk])
# Out:
# 5788it [01:17, 74.90it/s]

# %%
ct_zip_nonct_state
# Out:
#      original_index                   record_from  \
# 491             491     110_Plainville_MV_21.xlsx
# 941            8941     110_Plainville_MV_21.xlsx
# 107            9107     110_Plainville_MV_21.xlsx
# 12            23012    101_North_Haven_MV_21.xlsx
# 430           33430    101_North_Haven_MV_21.xlsx
# ..              ...                           ...
# 23          5705023  105_Old_Lyme_MVData_2019.csv
# 24          5705024  105_Old_Lyme_MVData_2019.csv
# 25          5705025  105_Old_Lyme_MVData_2019.csv
# 26          5705026  105_Old_Lyme_MVData_2019.csv
# 33          5705033  105_Old_Lyme_MVData_2019.csv
#
#                                          name                          street  \
# 491  APOLO-CEVALLOS JORGE E                    234 EAST ST UNIT 20
# 941  LAVIGNE JOSEPH J                          35 WAYNE DR
# 107  LESANO CONSTRUCTION LLC                   111 DIAMON AVE
# 12   CRAFT BEER GUILD DISTRIBUTING OF CONNECT            352 SACKETT POINT RD
# 430                           MULLEN ASHLEY L                   9 MAIDEN LANE
# ..                                        ...                             ...
# 23                            BD HOLDINGS LLC                      PO BOX 447
# 24                            BD HOLDINGS LLC                      PO BOX 447
# 25                            BD HOLDINGS LLC                      PO BOX 447
# 26                            BD HOLDINGS LLC                      PO BOX 447
# 33      BD REMODELING AND RESTOR ATION CT LLC                      PO BOX 447
#
#                                city state   zip vehicle_year vehicle_make  \
# 491  PLAINVILE                         PA  6062         2014        HYUND
# 941  PLAINVILLE                        QC  6062         2011        SUBAR
# 107  PLAINVILLE                        OT  6062         2005        DODGE
# 12                      NORTH HAVEN    CA  6473         2013         HINO
# 430                     NORTH HAVEN    WI  6473         2013        LINCO
# ..                              ...   ...   ...          ...          ...
# 23                   FISHERS ISLAND    NY  6390         2011         FORD
# 24                   FISHERS ISLAND    NY  6390         2001        TOYOT
# 25                   FISHERS ISLAND    NY  6390         2018        MITSU
# 26                   FISHERS ISLAND    NY  6390         2007         SAAB
# 33                   FISHERS ISLAND    NY  6390         1949         FORD
#
#     vehicle_model vehicle_class         vehicle_id lease_street      UID  \
# 491      SONATA H             1  KMHEC4A47EA113558          NaN      NaN
# 941      IMPREZA              1  JF1GH6B69BH820812          NaN      NaN
# 107      RAM 1500             3  1D7HU18D55S317908          NaN      NaN
# 12       HINO 268             2  5PVNJ8JT3D4554181          NaN  55219.0
# 430       MKS AWD             1  1LNHL9EK5DG603365          NaN  65637.0
# ..            ...           ...                ...          ...      ...
# 23       ECONOLIN             3  1FBSS3BL6BDB06822          NaN  50478.0
# 24       TUNDRA/S             3  5TBBT44121S216756          NaN  50479.0
# 25       OUTLANDE             1  JA4AZ3A30JZ070576          NaN  50480.0
# 26       9-3 2.0T             3  YS3FD49Y071126547          NaN  50481.0
# 33          TRUCK             2         97HC200727          NaN  50488.0
#
#       lease_city lease_state lease_zip zip_corrected
# 491          NaN         NaN       NaN         06062
# 941          NaN         NaN       NaN         06062
# 107          NaN         NaN       NaN         06062
# 12   NORTH HAVEN          CT      6473         06473
# 430          NaN          CT     53597         06473
# ..           ...         ...       ...           ...
# 23           NaN         NaN       NaN         06390
# 24           NaN         NaN       NaN         06390
# 25           NaN         NaN       NaN         06390
# 26           NaN         NaN       NaN         06390
# 33           NaN         NaN       NaN         06390
#
# [380 rows x 18 columns]

# %%
version = "102323"
ct_zip_nonct_state.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / f"ct_zip_nonct_state_{version}.csv")
nonct_zip_ct_state.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / f"nonct_zip_ct_state_{version}.csv")

# %% [markdown]
# ### 1bii. Read and assess errors

# %%
ct_zip_nonct_state = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "ct_zip_nonct_state_102023.csv", index_col = 0)
nonct_zip_ct_state = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "nonct_zip_ct_state_102023.csv", index_col = 0)
old = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "non_matching_zips_states.csv")
# Out:
# /tmp/ipykernel_2394416/1671633160.py:3: DtypeWarning: Columns (12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   old = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "non_matching_zips_states.csv")

# %% [markdown]
# * There appear to be a few kinds of errors:
#     * **CT ZIP, Non CT Address:**
#         * E.g. "31 SLIPTOWN RD" / "SHARON" / "NH" / 6010 (31 Sliptown Rd. is a real address in New Hampshire)
#         * "12941 N Fox Hollow Dr" / "MARANA" / "AZ" (Real address, but wrong ZIP code"
#         * Note that in both of the above instances from 017_Brisol_MV_21 - the underlying file provides no further information on how to parse this information.
#         * 79 WOODLAND RD CARIBOU ME 6417 - Not a CT address, CT Zip code. The Deep River underlying file provides no way to fix this.
#     * **Erroneous CT Addresses**
#         * E.g. 693 DOGWOOD DR CHESHIRE OT --> Probably means "CT," this is a real address
#         * E.g. 152 DAISY LN DURHAM HI 6422 --> 152 Daisy Lane is a CT address. Perhaps "CT" was written wrong?

# %% [markdown]
# ### 1biii. Investigate CT ZIPs non CT state

# %%
print(f"Of the {len(ct_zip_nonct_state)} rows, {ct_zip_nonct_state["state"].isna().sum()} are NA for state")
# Out:
# Of the 380 rows, 0 are NA for state

# %%
ct_zip_nonct_state[ct_zip_nonct_state["state"].notna()].groupby("record_from").count()[["vehicle_id"]].sort_values("vehicle_id", ascending=False).head(5)
# Out:
#                               vehicle_id
# record_from
# 135_Stamford_MV_21.xlsx               16
# 034_Danbury_MV_21.xlsx                14
# 105_Old_Lyme_MV_21.xlsx               13
# 093_New_Haven_MV_21.xlsx              12
# 135_Stamford_MVData_2020.csv          11

# %%
# Observe Stamford
ct_zip_nonct_state[(ct_zip_nonct_state["record_from"].str.contains("135_Stamford_MV_21")) & (ct_zip_nonct_state["state"].notna())].head(3)
# Out:
#                  record_from                                      name  \
# 108  135_Stamford_MV_21.xlsx  AGUILAR-CARRERA ELIAS
# 109  135_Stamford_MV_21.xlsx  AGUILAR-CARRERA ELIAS
# 110  135_Stamford_MV_21.xlsx  AGUILAR-CARRERA ELIAS
#
#                              street                            city state  \
# 108  31 CAROLINA RD 2FL              STAMFORD                          MD
# 109  31 CAROLINA RD 2FL              STAMFORD                          MD
# 110  31 CAROLINA RD 2FL              STAMFORD                          MD
#
#       zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 108  6902        2001.0        CHEVR      4500 W45            2.0
# 109  6902        2005.0        GMC        SIERRA K            2.0
# 110  6902        2000.0        TOYOT      SIENNA L            1.0
#
#             vehicle_id lease_street  UID lease_city lease_state lease_zip  \
# 108  J8BC4B14617002821          NaN  NaN        NaN         NaN       NaN
# 109  1GDJK34215E234911          NaN  NaN        NaN         NaN       NaN
# 110  4T3ZF13C1YU217680          NaN  NaN        NaN         NaN       NaN
#
#      zip_corrected
# 108           6902
# 109           6902
# 110           6902

# %% [markdown]
# **These are erroneous - attempt geocoding them without the state and see where they land**

# %%
# Observe Danbury
ct_zip_nonct_state[(ct_zip_nonct_state["record_from"].str.contains("Danbury")) & (ct_zip_nonct_state["state"].notna())].head(3)
# Out:
#                 record_from                                      name  \
# 254  034_Danbury_MV_21.xlsx  ADAMS JILL L
# 255  034_Danbury_MV_21.xlsx  ALVES PRISCILA M
# 256  034_Danbury_MV_21.xlsx  CAJAMARCA SEGUNDO
#
#                              street                            city state  \
# 254  6 CEDAR CREST DR                DANBURY                           CA
# 255  8 TOWER PL APT A                DANBURY                           MD
# 256  3 FIRST STREET EXT              DANBURY                           NY
#
#       zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 254  6811        2017.0        NISSA      MURANO S            1.0
# 255  6810        2016.0        HONDA      CR-V SE             1.0
# 256  6810        2008.0        HONDA      CIVIC EX            1.0
#
#             vehicle_id lease_street  UID lease_city lease_state lease_zip  \
# 254  5N1AZ2MH9HN125868          NaN  NaN        NaN         NaN       NaN
# 255  2HKRM4H46GH651740          NaN  NaN        NaN         NaN       NaN
# 256  2HGFA16818H501014          NaN  NaN        NaN         NaN       NaN
#
#      zip_corrected
# 254           6811
# 255           6810
# 256           6810

# %% [markdown]
# **These are erroneous**

# %%
# Observe Old Lyme
ct_zip_nonct_state[(ct_zip_nonct_state["record_from"].str.contains("Lyme")) & (ct_zip_nonct_state["state"].notna())].head(3)
# Out:
#                  record_from                                      name  \
# 225  105_Old_Lyme_MV_21.xlsx  BD HOLDINGS LLC
# 226  105_Old_Lyme_MV_21.xlsx  BD HOLDINGS LLC
# 227  105_Old_Lyme_MV_21.xlsx  BD HOLDINGS LLC
#
#                              street                            city state  \
# 225  PO BOX 447                      FISHERS ISLAND                    NY
# 226  PO BOX 447                      FISHERS ISLAND                    NY
# 227  1420 THE GLOAMING #447          FISHERS ISLAND                    NY
#
#       zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 225  6390        2002.0        FORD       ECONOLIN            3.0
# 226  6390        2011.0        FORD       ECONOLIN            3.0
# 227  6390        2004.0        FORD       E450 SUP            2.0
#
#             vehicle_id lease_street  UID lease_city lease_state lease_zip  \
# 225  1FTNE24L62HB67748          NaN  NaN        NaN         NaN       NaN
# 226  1FBSS3BL6BDB06822          NaN  NaN        NaN         NaN       NaN
# 227  1FDXE45P14HB09356          NaN  NaN        NaN         NaN       NaN
#
#      zip_corrected
# 225           6390
# 226           6390
# 227           6390

# %% [markdown]
# **These are correct**

# %%
# Observe NHV
ct_zip_nonct_state[(ct_zip_nonct_state["record_from"].str.contains("New_Haven")) & (ct_zip_nonct_state["state"].notna())].head(3)
# Out:
#                  record_from                                      name  \
# 20  093_New_Haven_MV_21.xlsx  A T AND T COMMUNICATIONS
# 21  093_New_Haven_MV_21.xlsx  BRADLEY NICOLE L
# 22  093_New_Haven_MV_21.xlsx  CEDAR ROOFING LLC
#
#                             street                            city state  \
# 20  909 CHESTNUT ST 34A07           ST LOUIS                          MO
# 21  116 SPRINGSIDE AVE              NEW HAVEN                         MD
# 22  125 CEDAR ST                    NEW HAVEN                         OT
#
#      zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 20  6492        1987.0        TOTEE      4896               10.0
# 21  6515        2019.0        NISSA      PATHFIND            1.0
# 22  6519        1998.0        ACURA      INTEGRA             3.0
#
#            vehicle_id lease_street      UID lease_city lease_state lease_zip  \
# 20  050402                     NaN  50039.0        NaN         NaN       NaN
# 21  5N1DR2MM5KC652562          NaN  55559.0        NaN         NaN       NaN
# 22  JH4DC4454WS003338          NaN  58671.0        NaN         NaN       NaN
#
#     zip_corrected
# 20           6492
# 21           6515
# 22           6519

# %% [markdown]
# **Erroneous**

# %% [markdown]
# ### 1biv. Look at Non-CT ZIP ct State

# %%
nonct_zip_ct_state
# Out:
#      original_index                            record_from  \
# 242           54242               140_Thomaston_MV_21.xlsx
# 175          105175                  146_Vernon_MV_21.xlsx
# 35           130035                 103_Norwalk_MV_21.xlsx
# 36           130036                 103_Norwalk_MV_21.xlsx
# 38           130038                 103_Norwalk_MV_21.xlsx
# ..              ...                                    ...
# 908         5540908  77_Manchester_MVData_2019_ALTERED.csv
# 178         5618178          36_Deep_River_MVData_2019.csv
# 734         5650734         54_Glastonbury_MVData_2019.csv
# 726         5683726             26_Chester_MVData_2020.csv
# 53          5779053              56_Granby_MVData_2019.csv
#
#                                                   name  \
# 242           STARKS BRITTANY D
# 175           LEASE PLAN U.S.A. INC.
# 35   HEIDEMANN BEVERLY                             ...
# 36   MANDUJANO JAIME                               ...
# 38   SON YOUNG SANG                                ...
# ..                                                 ...
# 908           CHMIELEWSKI THOMAS D
# 178           ORELLANA ANA C
# 734           WARD GEORGE D JR
# 726           FISHMAN HOWARD W
# 53            GANNOTTI MARY E
#
#                                                 street  \
# 242                     30 LEIGH AVE
# 175                     1165 SANCTURARY PARKWAY
# 35   146 W ROCKS RD                                ...
# 36   58 N TAYLOR AVE                               ...
# 38   198 ELY AVE                                   ...
# ..                                                 ...
# 908                     105 ZENA RD
# 178                     185 ESTANCIA DR 237
# 734                     118 PRINCETON AVE
# 726                     116 N 7TH ST APT 5
# 53                      451 MAIN RD
#
#                                city state         zip vehicle_year  \
# 242  THOMASTON                         CT       36787         2012
# 175  ALPHARETTA                        CT       30009         2019
# 35             NORWALK                 CT  68512-232          2011
# 36             NORWALK                 CT  68541-410          1977
# 38             NORWALK                 CT  68544-229          2011
# ..                              ...   ...         ...          ...
# 908  KINGSTON                          CT  12401-           2014.0
# 178  SAN JOSE                          CT       95134         2012
# 734  FEEDING HILLS                     CT        1030         2010
# 726  BROOKLYN NY                       CT       11211         1999
# 53   GRANVILLE                         CT        1034         2005
#
#                        vehicle_make                   vehicle_model  \
# 242                           FORD                         ESCAPE X
# 175                           CHEVR                        COLORADO
# 35   YAKIM                           VINS
# 36   HOLSC                           2000
# 38   CHANGZHOU NANXIASHU             TRAILER
# ..                              ...                             ...
# 908                           SUBAR                        XV CROSS
# 178                           TOYOT                        MATRIX
# 734                           HONDA                        ACCORD L
# 726                           MERCU                        SABLE GS
# 53                            VOLVO                        XC90
#
#     vehicle_class            vehicle_id lease_street  UID lease_city  \
# 242             1     1FMCU9C75CKA10106          NaN  NaN        NaN
# 175             1     1GCHSBEA3K1227996          NaN  NaN        NaN
# 35             11  510SF1114BN009217             NaN  NaN        NaN
# 36             11  CTUNKNOWN95699011             NaN  NaN        NaN
# 38             11  LN2AD001XBJ000038             NaN  NaN        NaN
# ..            ...                   ...          ...  ...        ...
# 908           NaN     JF2GPACC3E9244364          NaN  NaN        NaN
# 178             1     2T1KU4EE9CC766263          NaN  NaN        NaN
# 734             1     1HGCP2F36AA151587          NaN  NaN        NaN
# 726             1     1MEFM58UXXA622238          NaN  NaN        NaN
# 53              1     YV1CZ592651195747          NaN  NaN        NaN
#
#     lease_state lease_zip zip_corrected
# 242         NaN       NaN         36787
# 175         NaN       NaN         30009
# 35          NaN       NaN         68512
# 36          NaN       NaN         68541
# 38          NaN       NaN         68544
# ..          ...       ...           ...
# 908         NaN       NaN         12401
# 178         NaN       NaN         95134
# 734         NaN       NaN         01030
# 726         NaN       NaN         11211
# 53          NaN       NaN         01034
#
# [808 rows x 18 columns]

# %% [markdown]
# ### Investigate Non CT ZIPS CT state

# %%
print(f"This error is present in {nonct_zip_ct_state["record_from"].nunique()} underlying files, suggesting it is generalized")
print(f"This error affects {len(nonct_zip_ct_state)} rows")
# Out:
# This error is present in 128 underlying files, suggesting it is generalized
# This error affects 808 rows

# %%
nonct_zip_ct_state.groupby("record_from").count()[["vehicle_id"]].sort_values("vehicle_id", ascending=False)
# Out:
#                                vehicle_id
# record_from
# 103_Norwalk_MV_21.xlsx                491
# 099_North_Branford_MV_21.xlsx          36
# 135_Stamford_MVData_2020.csv           13
# 111_Plymouth_MV_21.xlsx                12
# 135_Stamford_MV_21.xlsx                12
# ...                                   ...
# 138_Stratford_MV_21.xlsx                1
# 056_Granby_MV_21.xlsx                   1
# 131_Southington_MV_21.xlsx              1
# 131_Southbury_MVData_2019.csv           1
# 046_Easton_MV_21.xlsx                   1
#
# [128 rows x 1 columns]

# %%
nonct_zip_ct_state[nonct_zip_ct_state["record_from"].str.contains("Norwalk")].head(3)
# Out:
#               record_from                                               name  \
# 2  103_Norwalk_MV_21.xlsx  HEIDEMANN BEVERLY                             ...
# 3  103_Norwalk_MV_21.xlsx  MANDUJANO JAIME                               ...
# 4  103_Norwalk_MV_21.xlsx  SON YOUNG SANG                                ...
#
#                                               street                  city  \
# 2  146 W ROCKS RD                                ...  NORWALK
# 3  58 N TAYLOR AVE                               ...  NORWALK
# 4  198 ELY AVE                                   ...  NORWALK
#
#   state         zip  vehicle_year                    vehicle_make  \
# 2    CT  68512-232         2011.0  YAKIM
# 3    CT  68541-410         1977.0  HOLSC
# 4    CT  68544-229         2011.0  CHANGZHOU NANXIASHU
#
#                     vehicle_model  vehicle_class            vehicle_id  \
# 2  VINS                                     11.0  510SF1114BN009217
# 3  2000                                     11.0  CTUNKNOWN95699011
# 4  TRAILER                                  11.0  LN2AD001XBJ000038
#
#   lease_street  UID lease_city lease_state lease_zip  zip_corrected
# 2          NaN  NaN        NaN         NaN       NaN          68512
# 3          NaN  NaN        NaN         NaN       NaN          68541
# 4          NaN  NaN        NaN         NaN       NaN          68544

# %%
nonct_zip_ct_state[nonct_zip_ct_state["record_from"].str.contains("Norwalk")]["zip"].unique()
# Out:
# array(['68512-232 ', '68541-410 ', '68544-229 ', '68552-003 ',
#        '68501-832 ', '68511-221 ', '68516-038 ', '68501-616 ',
#        '00000     ', '68501-733 ', '68531-132 ', '68541-067 ',
#        '68513-605 ', '68514-466 ', '68512-827 ', '68504-430 ',
#        '68512-214 ', '68511-215 ', '68515-328 ', '68512-431 ',
#        '68543-216 ', '68502-730 ', '68501-835 ', '68552-103 ',
#        '68513-420 ', '68502-722 ', '68515-534 ', '68543-305 ',
#        '68543-627 ', '68543-422 ', '68513-008 ', '68552-235 ',
#        '68544-714 ', '68502-840 ', '68544-716 ', '68504-320 ',
#        '68515-940 ', '68513-108 ', '68511-715 ', '68541-613 ',
#        '68513-221 ', '68542-107 ', '68502-408 ', '68543-512 ',
#        '68511-042 ', '68516-027 ', '68514-316 ', '68502-728 ',
#        '68541-561 ', '68543-548 ', '68516-141 ', '68551-615 ',
#        '68544-304 ', '68512-645 ', '68511-536 ', '68544-727 ',
#        '68544-308 ', '68543-735 ', '68542-514 ', '68501-704 ',
#        '68513-115 ', '69024-108 ', '68552-703 ', '68515-514 ',
#        '68513-305 ', '68502-522 ', '68501-833 ', '68541-452 ',
#        '68503-113 ', '68515-513 ', '68551-012 ', '68544-113 ',
#        '68503-530 ', '68544-516 ', '68543-317 ', '68544-004 ',
#        '68503-322 ', '68501-920 ', '68512-215 ', '68541-402 ',
#        '68552-106 ', '68542-712 ', '68514-314 ', '68531-716 ',
#        '68531-644 ', '68501-823 ', '68501-926 ', '68542-420 ',
#        '68541-120 ', '68513-213 ', '68501-405 ', '68513-911 ',
#        '68504-312 ', '68512-219 ', '68502-541 ', '68512-304 ',
#        '68504-409 ', '68544-204 ', '68513-835 ', '68503-221 ',
#        '68501-707 ', '68544-345 ', '68551-622 ', '68504-317 ',
#        '68544-711 ', '68513-211 ', '68512-638 ', '68541-405 ',
#        '68503-317 ', '68512-326 ', '68544-246 ', '68512-802 ',
#        '68501-125 ', '68542-323 ', '68512-406 ', '68544-011 ',
#        '68542-511 ', '68544-127 ', '68541-406 ', '68544-951 ',
#        '68552-504 ', '68551-020 ', '68541-125 ', '68551-306 ',
#        '68513-516 ', '68542-285 ', '68542-835 ', '68551-449 ',
#        '68503-924 ', '68541-112 ', '68512-818 ', '68543-757 ',
#        '68511-556 ', '68502-224 ', '68542-816 ', '68542-881 ',
#        '68543-612 ', '68542-116 ', '68541-918 ', '68515-117 ',
#        '68542-022 ', '68551-926 ', '68512-313 ', '68541-419 ',
#        '68544-920 ', '68513-900 ', '68503-014 ', '68531-315 ',
#        '68542-830 ', '68501-213 ', '68552-034 ', '68503-630 ',
#        '68513-622 ', '68552-108 ', '68503-433 ', '68512-006 ',
#        '68543-910 ', '68515-207 ', '68542-413 ', '68542-804 ',
#        '68531-535 ', '68511-029 ', '68503-513 ', '68514-319 ',
#        '68514-305 ', '68516-142 ', '68544-134 ', '68513-203 ',
#        '68513-005 ', '68511-138 ', '68515-909 ', '68513-118 ',
#        '68502-847 ', '68503-857 ', '68543-316 ', '68531-136 ',
#        '68501-344 ', '68521-673 ', '68514-850 ', '68543-520 ',
#        '68531-542 ', '43026     ', '11106     ', '68512-424 '],
#       dtype=object)

# %%
nonct_zip_ct_state[nonct_zip_ct_state["record_from"].str.contains("Stamford")].head(5)
# Out:
#                  record_from                                      name  \
# 634  135_Stamford_MV_21.xlsx  BIVIANO NICHOLAS A
# 635  135_Stamford_MV_21.xlsx  DE-MARTINEZ MARIA R
# 636  135_Stamford_MV_21.xlsx  FUENTES-SOTO NOE A
# 637  135_Stamford_MV_21.xlsx  FUENTES-SOTO NOE A
# 638  135_Stamford_MV_21.xlsx  GODOY-PAREDES CARLOS A
#
#                              street                            city state  \
# 634  2428 NAPA TER                   LAKE WYLIE                        CT
# 635  43 CRESCENT ST APT 3            STAMFORD                          CT
# 636  131 W BROAD ST UNIT 1           STAMFORD                          CT
# 637  131 W BROAD ST UNIT 1           STAMFORD                          CT
# 638  148B EAST BOSTON POST ROAD      MAMARONECK                        CT
#
#        zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 634  29710        2016.0        MERCE      C300 4 M            1.0
# 635  60906        2017.0        SUBAR      OUTBACK             1.0
# 636  98387        2008.0        GMC        CANYON              1.0
# 637  98387        2008.0        CHEVR      SILVERAD            3.0
# 638  10543        2005.0        NISSA      PATHFIND            1.0
#
#             vehicle_id lease_street  UID lease_city lease_state lease_zip  \
# 634  WDDWF4KB5GR145755          NaN  NaN        NaN         NaN       NaN
# 635  4S4BSAAC4H3223438          NaN  NaN        NaN         NaN       NaN
# 636  1GTDT13E488180313          NaN  NaN        NaN         NaN       NaN
# 637  1GCHK23658F128932          NaN  NaN        NaN         NaN       NaN
# 638  5N1AR18W55C762007          NaN  NaN        NaN         NaN       NaN
#
#      zip_corrected
# 634          29710
# 635          60906
# 636          98387
# 637          98387
# 638          10543

# %% [markdown]
# ## 1c. Missing Data and Other

# %%
recompiled_data = reset_recompiled_data("102323")

# %%
missing_state_or_zip = pd.DataFrame()
nonct_state_or_nonct_zip = pd.DataFrame()

i = 0

# %%
for chunk in tqdm(recompiled_data):
    # Clean up
    chunk = chunk.reset_index()
    chunk = chunk.rename(columns = {"index" : "original_index"})
    
    # Check that the ZIPs and the states match
    chunk_corrected_zips = chunk
    chunk_corrected_zips["zip_corrected"] = chunk_corrected_zips["zip"].apply(lambda x: create_valid_zip(x))
    
    # Create masks
    ct_zip_mask = chunk_corrected_zips["zip_corrected"].apply(lambda x: ct_zip(x))
    ct_state_mask = chunk_corrected_zips["state"] == "CT"

    missing_mask = chunk_corrected_zips["state"].isna() | chunk_corrected_zips["zip_corrected"].isna()
    nonct_state_or_nonct_zip_mask = ~ct_state_mask | ~ct_zip_mask
    
    # Get missing rows
    missing_rows = chunk_corrected_zips.loc[missing_mask]\

    # Get Non CT state or Non CT Zip
    nonct_state_or_nonct_zip_rows = chunk_corrected_zips.loc[nonct_state_or_nonct_zip_mask]
    nonct_state_or_nonct_zip_rows = nonct_state_or_nonct_zip_rows.dropna(axis = 0, subset = ["zip_corrected", "state"])

    # Concat
    missing_state_or_zip = pd.concat([missing_state_or_zip, missing_rows])
    nonct_state_or_nonct_zip = pd.concat([nonct_state_or_nonct_zip, nonct_state_or_nonct_zip_rows])
# Out:
# 2761it [04:36, 10.00it/s]

# %%
print(f"Thus there are {len(nonct_state_or_nonct_zip)} rows where the state or zip are non-CT,\nand there are a further {len(missing_state_or_zip)} where either state zip is missing")
# Out:
# Thus there are 493698 rows where the state or zip are non-CT,
# and there are a further 94499 where either state zip is missing

# %%
version = "102323"
missing_state_or_zip.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / f"missing_state_or_zip{version}.csv")
nonct_state_or_nonct_zip.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / f"nonct_state_or_nonct_zip{version}.csv")

# %% [markdown]
# ## Further checks

# %% [markdown]
# The original purpose of recompiling the data was to address issues with missing VINs, missing zip codes, and missing street addresses. below, I confirm that these issues have been addressed.

# %%
recompiled_data = reset_recompiled_data("102023")

# %%
i = 0

missing_df = pd.DataFrame([])

for chunk in recompiled_data:
    
    # Give progress
    if (i % 1000 ==0):
        print(f"Currently on chunk number {i}")
        # display(df)
        
    # Create DF
    # Get the total number for that record_from
    total = chunk.groupby("record_from").count()["Unnamed: 0"].reset_index(name="count")
    
    # Get the number with a missing ZIP
    missing_zips = chunk.groupby("record_from")["zip"].apply(lambda x: x.isna().sum()).reset_index(name = "missing zip")
    
    # Get the number with a missing VIN
    missing_vins = chunk.groupby("record_from")["vehicle_id"].apply(lambda x: x.isna().sum()).reset_index(name = "missing VIN")
    
    # Missing address
    missing_streets = chunk.groupby("record_from")["street"].apply(lambda x: x.isna().sum()).reset_index(name = "missing street")
    
    # Get the number with state not in CT
    state_not_CT = chunk.groupby("record_from")["state"].apply(lambda x: (x!="CT").sum()).reset_index(name ="not CT")
    
    # Merge
    all_columns  = missing_zips.merge(missing_vins,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(missing_streets,
                                   how = 'outer',
                                   left_on = 'record_from',
                                   right_on = 'record_from')
    
    all_columns  = all_columns.merge(state_not_CT,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(total,
                                    how = 'outer',
                                    left_on = 'record_from',
                                    right_on = 'record_from')
    
    
    # Assign this to a DF to save
    missing_df = pd.concat([missing_df, all_columns])
    
    # add to count
    i +=1

missing_df = missing_df.groupby("record_from").sum()
missing_df = missing_df.reset_index()
missing_df_new = missing_df.copy(deep=True)
# Out:
# Currently on chunk number 0
# Currently on chunk number 1000
# Currently on chunk number 2000
# Currently on chunk number 3000
# Currently on chunk number 4000
# Currently on chunk number 5000

# %%
original_data = reset_original_data()

# %%
i = 0

missing_df = pd.DataFrame([])

for chunk in original_data:
    
    # Give progress
    if (i % 1000 ==0):
        print(f"Currently on chunk number {i}")
        # display(df)
        
    # Create DF
    # Get the total number for that record_from
    total = chunk.groupby("record_from").count()["Unnamed: 0"].reset_index(name="count")
    
    # Get the number with a missing ZIP
    missing_zips = chunk.groupby("record_from")["zip"].apply(lambda x: x.isna().sum()).reset_index(name = "missing zip")
    
    # Get the number with a missing VIN
    missing_vins = chunk.groupby("record_from")["vehicle_id"].apply(lambda x: x.isna().sum()).reset_index(name = "missing VIN")
    
    # Missing address
    missing_streets = chunk.groupby("record_from")["street"].apply(lambda x: x.isna().sum()).reset_index(name = "missing street")
    
    # Get the number with state not in CT
    state_not_CT = chunk.groupby("record_from")["state"].apply(lambda x: (x!="CT").sum()).reset_index(name ="not CT")
    
    # Merge
    all_columns  = missing_zips.merge(missing_vins,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(missing_streets,
                                   how = 'outer',
                                   left_on = 'record_from',
                                   right_on = 'record_from')
    
    all_columns  = all_columns.merge(state_not_CT,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(total,
                                    how = 'outer',
                                    left_on = 'record_from',
                                    right_on = 'record_from')
    
    
    # Assign this to a DF to save
    missing_df = pd.concat([missing_df, all_columns])
    
    # add to count
    i +=1

missing_df = missing_df.groupby("record_from").sum()
missing_df = missing_df.reset_index()
missing_df_original = missing_df.copy(deep=True)
# Out:
# Currently on chunk number 0
# Currently on chunk number 1000
# Currently on chunk number 2000
# Currently on chunk number 3000
# Currently on chunk number 4000
# Currently on chunk number 5000

# %%
missing_df_original["missing zip rank"] = missing_df_original["missing zip"].rank(method = 'min', ascending = False)
missing_df_original["missing VIN rank"] = missing_df_original["missing VIN"].rank(method = 'min', ascending = False)
missing_df_original["missing street rank"] = missing_df_original["missing street"].rank(method = 'min', ascending = False)

# %%
missing_df_new["missing zip rank"] = missing_df_new["missing zip"].rank(method = 'min', ascending = False)
missing_df_new["missing VIN rank"] = missing_df_new["missing VIN"].rank(method = 'min', ascending = False)
missing_df_new["missing street rank"] = missing_df_new["missing street"].rank(method = 'min', ascending = False)

# %%
missing_df_original.sort_values("missing street rank", ascending = True).head(20)
# Out:
#                        record_from  missing zip  missing VIN  missing street  \
# 91          103_Norwalk_MV_21.xlsx        75044        75044           75044
# 90     103_Norwalk_MVData_2020.csv        71664        71664           71664
# 290  77_Manchester_MVData_2019.csv        48990         3203           48990
# 64        077_Manchester_MV_21.xls        44487            3           44487
# 124  11_Bloomfield_MVData_2019.csv        19643        19643           19643
# 8            009_Bethel_MV_21.xlsx        17855            1           17855
# 99           107_Orange_MV_21.xlsx        13522            0           13522
# 235     27_Clinton_MVData_2020.csv        13202            0           13202
# 169        141_Thompson_MV_21.xlsx        10054          457           10054
# 28             037_Derby_MV_21.xls         9511            0            9511
# 14      016_Bridgewater_MV_21.xlsx         7254         4886            7254
# 104   10_Bethlehem_MVData_2019.csv         4760            0            4760
# 130       122_Salisbury_MV_21.xlsx         4390         4390            4390
# 109    112_Pomfret_MVData_2020.csv         4130            0            4130
# 44           055_Goshen_MV_21.XLSX         4004            0            4004
# 227      1_Andover_MVData_2020.csv         3938         3938            3938
# 232     24_Chaplin_MVData_2020.csv         2567         2567            2567
# 82          098_Norfolk_MV_21.xlsx         1945            0            1945
# 87      101_North_Haven_MV_21.xlsx        24425          194              86
# 69       083_Middletown_MV_21.xlsx        35302           82              82
#
#      not CT  count  missing zip rank  missing VIN rank  missing street rank
# 91    75044  75044               4.0               1.0                  1.0
# 90    71664  71664               5.0               2.0                  2.0
# 290   48990  48990              12.0              12.0                  3.0
# 64    44487  44487              18.0              37.0                  4.0
# 124    1630  19643              71.0               6.0                  5.0
# 8      1678  17855              79.0              44.0                  6.0
# 99    13522  13522             119.0              61.0                  7.0
# 235   13202  13202             123.0              61.0                  8.0
# 169   10054  10054             151.0              14.0                  9.0
# 28     9511   9511             161.0              61.0                 10.0
# 14     7254   7254             190.0               9.0                 11.0
# 104     206   4760             213.0              61.0                 12.0
# 130    4390   4390             217.0              10.0                 13.0
# 109    4130   4130             224.0              61.0                 14.0
# 44     4004   4004             228.0              61.0                 15.0
# 227    3938   3938             229.0              11.0                 16.0
# 232    2567   2567             253.0              13.0                 17.0
# 82     1945   1945             262.0              61.0                 18.0
# 87     2978  24425              56.0              18.0                 19.0
# 69     3060  35302              32.0              23.0                 20.0

# %%
missing_df_original_zips_formerge = missing_df_original[["record_from", "missing zip", "missing zip rank"]].sort_values("missing zip rank", ascending = True).head(15)
missing_df_original_VINS_formerge = missing_df_original[["record_from", "missing VIN", "missing VIN rank"]].sort_values("missing VIN rank", ascending = True).head(10)
missing_df_original_streets_formerge = missing_df_original[["record_from", "missing street", "missing street rank"]].sort_values("missing street rank", ascending = True).head(10)

# %%
missing_df_new_zips_formerge = missing_df_new[["record_from", "missing zip", "missing zip rank"]].sort_values("missing zip rank", ascending = True).head(15)
missing_df_new_VINS_formerge = missing_df_new[["record_from", "missing VIN", "missing VIN rank"]].sort_values("missing VIN rank", ascending = True).head(10)
missing_df_new_streets_formerge = missing_df_new[["record_from", "missing street", "missing street rank"]].sort_values("missing street rank", ascending = True).head(10)

# %%
compare_missing_zips = missing_df_original_zips_formerge.merge(missing_df_new_zips_formerge, how = 'left',
                                                              left_on = "missing zip rank",
                                                              right_on = "missing zip rank",
                                                              suffixes = ("_original", "_recompiled"))

compare_missing_zips = compare_missing_zips.set_index("missing zip rank")

compare_missing_zips["Difference"] = compare_missing_zips["missing zip_recompiled"] - compare_missing_zips["missing zip_original"]

compare_missing_zips = compare_missing_zips.reset_index()

# %%
cm = sns.light_palette("green", as_cmap=True, reverse = True)

# %%
compare_missing_zips = compare_missing_zips.style.background_gradient(subset = ["Difference"], cmap=cm)
# compare_missing_zips.data = compare_missing_zips.data.drop("Town_original", axis = 1)
compare_missing_zips.data = compare_missing_zips.data.drop("missing zip rank", axis = 1)

# %%
total_row_zips = pd.DataFrame(compare_missing_zips.data.sum(), columns=["Total"]).T
total_row_zips.loc["Total", "record_from_original"] = ""
total_row_zips.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_zips.data = pd.concat([compare_missing_zips.data, total_row_zips])

# %%
compare_missing_zips.set_caption("Comparison of Missing ZIP Codes: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_223b5 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_223b5_row0_col4 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_223b5_row1_col4, #T_223b5_row2_col4, #T_223b5_row3_col4 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_223b5_row4_col4 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_223b5_row5_col4 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_223b5_row6_col4 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_223b5_row7_col4 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_223b5_row8_col4, #T_223b5_row9_col4, #T_223b5_row10_col4, #T_223b5_row11_col4, #T_223b5_row12_col4, #T_223b5_row13_col4, #T_223b5_row14_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_223b5_row15_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_223b5">
#   <caption>Comparison of Missing ZIP Codes: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_223b5_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_223b5_level0_col1" class="col_heading level0 col1" >missing zip_original</th>
#       <th id="T_223b5_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_223b5_level0_col3" class="col_heading level0 col3" >missing zip_recompiled</th>
#       <th id="T_223b5_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_223b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_223b5_row0_col0" class="data row0 col0" >15_Bridgeport_MVData_2019.csv</td>
#       <td id="T_223b5_row0_col1" class="data row0 col1" >82704</td>
#       <td id="T_223b5_row0_col2" class="data row0 col2" >107_Orange_MV_21.xlsx</td>
#       <td id="T_223b5_row0_col3" class="data row0 col3" >13522</td>
#       <td id="T_223b5_row0_col4" class="data row0 col4" >-69182</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_223b5_row1_col0" class="data row1 col0" >015_Bridgeport_MV_21.xlsx</td>
#       <td id="T_223b5_row1_col1" class="data row1 col1" >80383</td>
#       <td id="T_223b5_row1_col2" class="data row1 col2" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_223b5_row1_col3" class="data row1 col3" >13202</td>
#       <td id="T_223b5_row1_col4" class="data row1 col4" >-67181</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_223b5_row2_col0" class="data row2 col0" >135_Stamford_MV_21.xlsx</td>
#       <td id="T_223b5_row2_col1" class="data row2 col1" >77594</td>
#       <td id="T_223b5_row2_col2" class="data row2 col2" >131_Southington_MV_21.xlsx</td>
#       <td id="T_223b5_row2_col3" class="data row2 col3" >10089</td>
#       <td id="T_223b5_row2_col4" class="data row2 col4" >-67505</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_223b5_row3_col0" class="data row3 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_223b5_row3_col1" class="data row3 col1" >75044</td>
#       <td id="T_223b5_row3_col2" class="data row3 col2" >037_Derby_MV_21.xls</td>
#       <td id="T_223b5_row3_col3" class="data row3 col3" >9511</td>
#       <td id="T_223b5_row3_col4" class="data row3 col4" >-65533</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_223b5_row4_col0" class="data row4 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_223b5_row4_col1" class="data row4 col1" >71664</td>
#       <td id="T_223b5_row4_col2" class="data row4 col2" >117_Redding_MV_21.xlsx</td>
#       <td id="T_223b5_row4_col3" class="data row4 col3" >8171</td>
#       <td id="T_223b5_row4_col4" class="data row4 col4" >-63493</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_223b5_row5_col0" class="data row5 col0" >151_Waterbury_MV_21.xlsx</td>
#       <td id="T_223b5_row5_col1" class="data row5 col1" >64647</td>
#       <td id="T_223b5_row5_col2" class="data row5 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_223b5_row5_col3" class="data row5 col3" >4886</td>
#       <td id="T_223b5_row5_col4" class="data row5 col4" >-59761</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_223b5_row6_col0" class="data row6 col0" >93_NewHaven_MVData_2019.csv</td>
#       <td id="T_223b5_row6_col1" class="data row6 col1" >60366</td>
#       <td id="T_223b5_row6_col2" class="data row6 col2" >045_East_Lyme_MV_21_ALTERED.csv</td>
#       <td id="T_223b5_row6_col3" class="data row6 col3" >4475</td>
#       <td id="T_223b5_row6_col4" class="data row6 col4" >-55891</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_223b5_row7_col0" class="data row7 col0" >093_New_Haven_MV_21.xlsx</td>
#       <td id="T_223b5_row7_col1" class="data row7 col1" >57470</td>
#       <td id="T_223b5_row7_col2" class="data row7 col2" >44_East_Lyme_MVData_2019.csv</td>
#       <td id="T_223b5_row7_col3" class="data row7 col3" >4301</td>
#       <td id="T_223b5_row7_col4" class="data row7 col4" >-53169</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_223b5_row8_col0" class="data row8 col0" >057_Greenwich_MV_21.xlsx</td>
#       <td id="T_223b5_row8_col1" class="data row8 col1" >51748</td>
#       <td id="T_223b5_row8_col2" class="data row8 col2" >112_Pomfret_MVData_2020.csv</td>
#       <td id="T_223b5_row8_col3" class="data row8 col3" >4130</td>
#       <td id="T_223b5_row8_col4" class="data row8 col4" >-47618</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_223b5_row9_col0" class="data row9 col0" >57_Greenwich_MVData_2020.csv</td>
#       <td id="T_223b5_row9_col1" class="data row9 col1" >51478</td>
#       <td id="T_223b5_row9_col2" class="data row9 col2" >055_Goshen_MV_21.XLSX</td>
#       <td id="T_223b5_row9_col3" class="data row9 col3" >4004</td>
#       <td id="T_223b5_row9_col4" class="data row9 col4" >-47474</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_223b5_row10_col0" class="data row10 col0" >017_Bristol_MV_21.xlsx</td>
#       <td id="T_223b5_row10_col1" class="data row10 col1" >50757</td>
#       <td id="T_223b5_row10_col2" class="data row10 col2" >098_Norfolk_MV_21.xlsx</td>
#       <td id="T_223b5_row10_col3" class="data row10 col3" >1945</td>
#       <td id="T_223b5_row10_col4" class="data row10 col4" >-48812</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_223b5_row11_col0" class="data row11 col0" >77_Manchester_MVData_2019.csv</td>
#       <td id="T_223b5_row11_col1" class="data row11 col1" >48990</td>
#       <td id="T_223b5_row11_col2" class="data row11 col2" >77_Manchester_MVData_2019_ALTERED.csv</td>
#       <td id="T_223b5_row11_col3" class="data row11 col3" >221</td>
#       <td id="T_223b5_row11_col4" class="data row11 col4" >-48769</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_223b5_row12_col0" class="data row12 col0" >51_Fairfield_MVData_2019.csv</td>
#       <td id="T_223b5_row12_col1" class="data row12 col1" >47928</td>
#       <td id="T_223b5_row12_col2" class="data row12 col2" >072_Ledyard_MV_21_ALTERED.csv</td>
#       <td id="T_223b5_row12_col3" class="data row12 col3" >143</td>
#       <td id="T_223b5_row12_col4" class="data row12 col4" >-47785</td>
#     </tr>
#     <tr>
#       <th id="T_223b5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_223b5_row13_col0" class="data row13 col0" >084_Milford_MV_21.xlsx</td>
#       <td id="T_223b5_row13_col1" class="data row13 col1" >47335</td>
#       <td id="T

# %% [markdown]
# ### Comparing missing VINs

# %%
compare_missing_VINS = missing_df_original_VINS_formerge.merge(missing_df_new_VINS_formerge, how = 'left',
                                                              left_on = "missing VIN rank",
                                                              right_on = "missing VIN rank",
                                                              suffixes = ("_original", "_recompiled"))

compare_missing_VINS = compare_missing_VINS.set_index("missing VIN rank")

compare_missing_VINS["Difference"] = compare_missing_VINS["missing VIN_recompiled"] - compare_missing_VINS["missing VIN_original"]

compare_missing_VINS = compare_missing_VINS.reset_index()

compare_missing_VINS = compare_missing_VINS.style.background_gradient(subset = ["Difference"], cmap=cm)

compare_missing_VINS.data = compare_missing_VINS.data.drop("missing VIN rank", axis = 1)

# %%
total_row = pd.DataFrame(compare_missing_VINS.data.sum(), columns=["Total"]).T

# %%
total_row.loc["Total", "record_from_original"] = ""
total_row.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_VINS.data = pd.concat([compare_missing_VINS.data, total_row])

# %%
compare_missing_VINS.set_caption("Comparison of Missing VINs: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_90708 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_90708_row0_col4 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_90708_row1_col4 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_90708_row2_col4 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_90708_row3_col4, #T_90708_row4_col4 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_90708_row5_col4 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_90708_row6_col4, #T_90708_row7_col4 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_90708_row8_col4, #T_90708_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_90708_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90708">
#   <caption>Comparison of Missing VINs: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90708_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_90708_level0_col1" class="col_heading level0 col1" >missing VIN_original</th>
#       <th id="T_90708_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_90708_level0_col3" class="col_heading level0 col3" >missing VIN_recompiled</th>
#       <th id="T_90708_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90708_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90708_row0_col0" class="data row0 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_90708_row0_col1" class="data row0 col1" >75044</td>
#       <td id="T_90708_row0_col2" class="data row0 col2" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_90708_row0_col3" class="data row0 col3" >19643</td>
#       <td id="T_90708_row0_col4" class="data row0 col4" >-55401</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90708_row1_col0" class="data row1 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_90708_row1_col1" class="data row1 col1" >71664</td>
#       <td id="T_90708_row1_col2" class="data row1 col2" >107_Orange_MVData_2020.csv</td>
#       <td id="T_90708_row1_col3" class="data row1 col3" >14650</td>
#       <td id="T_90708_row1_col4" class="data row1 col4" >-57014</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90708_row2_col0" class="data row2 col0" >126_Shelton_MV_21.xlsx</td>
#       <td id="T_90708_row2_col1" class="data row2 col1" >39086</td>
#       <td id="T_90708_row2_col2" class="data row2 col2" >124_Seymour_MV_21.csv</td>
#       <td id="T_90708_row2_col3" class="data row2 col3" >13860</td>
#       <td id="T_90708_row2_col4" class="data row2 col4" >-25226</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90708_row3_col0" class="data row3 col0" >143_Torrington_MV_21.xlsx</td>
#       <td id="T_90708_row3_col1" class="data row3 col1" >29674</td>
#       <td id="T_90708_row3_col2" class="data row3 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_90708_row3_col3" class="data row3 col3" >4886</td>
#       <td id="T_90708_row3_col4" class="data row3 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90708_row4_col0" class="data row4 col0" >143_Torrington_MVData_2020.csv</td>
#       <td id="T_90708_row4_col1" class="data row4 col1" >29674</td>
#       <td id="T_90708_row4_col2" class="data row4 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_90708_row4_col3" class="data row4 col3" >4886</td>
#       <td id="T_90708_row4_col4" class="data row4 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90708_row5_col0" class="data row5 col0" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_90708_row5_col1" class="data row5 col1" >19643</td>
#       <td id="T_90708_row5_col2" class="data row5 col2" >121_Salem_MVData_2019.csv</td>
#       <td id="T_90708_row5_col3" class="data row5 col3" >218</td>
#       <td id="T_90708_row5_col4" class="data row5 col4" >-19425</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90708_row6_col0" class="data row6 col0" >107_Orange_MVData_2020.csv</td>
#       <td id="T_90708_row6_col1" class="data row6 col1" >14650</td>
#       <td id="T_90708_row6_col2" class="data row6 col2" >101_North_Haven_MV_21.xlsx</td>
#       <td id="T_90708_row6_col3" class="data row6 col3" >84</td>
#       <td id="T_90708_row6_col4" class="data row6 col4" >-14566</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90708_row7_col0" class="data row7 col0" >124_Seymour_MV_21.csv</td>
#       <td id="T_90708_row7_col1" class="data row7 col1" >13860</td>
#       <td id="T_90708_row7_col2" class="data row7 col2" >083_Middletown_MV_21.xlsx</td>
#       <td id="T_90708_row7_col3" class="data row7 col3" >82</td>
#       <td id="T_90708_row7_col4" class="data row7 col4" >-13778</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90708_row8_col0" class="data row8 col0" >016_Bridgewater_MV_21.xlsx</td>
#       <td id="T_90708_row8_col1" class="data row8 col1" >4886</td>
#       <td id="T_90708_row8_col2" class="data row8 col2" >136_Sterling_MVData_2019.csv</td>
#       <td id="T_90708_row8_col3" class="data row8 col3" >69</td>
#       <td id="T_90708_row8_col4" class="data row8 col4" >-4817</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90708_row9_col0" class="data row9 col0" >122_Salisbury_MV_21.xlsx</td>
#       <td id="T_90708_row9_col1" class="data row9 col1" >4390</td>
#       <td id="T_90708_row9_col2" class="data row9 col2" >163_Windham_MV_21.xlsx</td>
#       <td id="T_90708_row9_col3" class="data row9 col3" >37</td>
#       <td id="T_90708_row9_col4" class="data row9 col4" >-4353</td>
#     </tr>
#     <tr>
#       <th id="T_90708_level0_row10" class="row_heading level0 row10" >Total</th>
#       <td id="T_90708_row10_col0" class="data row10 col0" ></td>
#       <td id="T_90708_row10_col1" class="data row10 col1" >302571</td>
#       <td id="T_90708_row10_col2" class="data row10 col2" ></td>
#       <td id="T_90708_row10_col3" class="data row10 col3" >58415</td>
#       <td id="T_90708_row10_col4" class="data row10 col4" >-244156</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparing Missing Street Addresses

# %%
compare_missing_streets = missing_df_original_streets_formerge.merge(missing_df_new_streets_formerge, how = 'left',
                                                      left_on = "missing street rank",
                                                      right_on = "missing street rank",
                                                      suffixes = ("_original", "_recompiled"))

compare_missing_streets = compare_missing_streets.set_index("missing street rank")

compare_missing_streets["Difference"] = compare_missing_streets["missing street_recompiled"] - compare_missing_streets["missing street_original"]

compare_missing_streets = compare_missing_streets.reset_index()

compare_missing_streets = compare_missing_streets.style.background_gradient(subset = ["Difference"], cmap=cm)

compare_missing_streets.data = compare_missing_streets.data.drop("missing street rank", axis = 1)

# %%
total_row_streets = pd.DataFrame(compare_missing_streets.data.sum(), columns=["Total"]).T
total_row_streets.loc["Total", "record_from_original"] = ""
total_row_streets.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_streets.data = pd.concat([compare_missing_streets.data, total_row_streets])

# %%
compare_missing_streets.set_caption("Comparison of Missing Street Addresses: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_84c51 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_84c51_row0_col4 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_84c51_row1_col4 {
#   background-color: #bbdcbb;
#   color: #000000;
# }
# #T_84c51_row2_col4 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_84c51_row3_col4 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_84c51_row4_col4 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_84c51_row5_col4 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_84c51_row6_col4, #T_84c51_row7_col4, #T_84c51_row9_col4 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_84c51_row8_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_84c51_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84c51">
#   <caption>Comparison of Missing Street Addresses: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84c51_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_84c51_level0_col1" class="col_heading level0 col1" >missing street_original</th>
#       <th id="T_84c51_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_84c51_level0_col3" class="col_heading level0 col3" >missing street_recompiled</th>
#       <th id="T_84c51_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84c51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84c51_row0_col0" class="data row0 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_84c51_row0_col1" class="data row0 col1" >75044</td>
#       <td id="T_84c51_row0_col2" class="data row0 col2" >107_Orange_MV_21.xlsx</td>
#       <td id="T_84c51_row0_col3" class="data row0 col3" >13522</td>
#       <td id="T_84c51_row0_col4" class="data row0 col4" >-61522</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84c51_row1_col0" class="data row1 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_84c51_row1_col1" class="data row1 col1" >71664</td>
#       <td id="T_84c51_row1_col2" class="data row1 col2" >045_East_Lyme_MV_21_ALTERED.csv</td>
#       <td id="T_84c51_row1_col3" class="data row1 col3" >13325</td>
#       <td id="T_84c51_row1_col4" class="data row1 col4" >-58339</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84c51_row2_col0" class="data row2 col0" >77_Manchester_MVData_2019.csv</td>
#       <td id="T_84c51_row2_col1" class="data row2 col1" >48990</td>
#       <td id="T_84c51_row2_col2" class="data row2 col2" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_84c51_row2_col3" class="data row2 col3" >13202</td>
#       <td id="T_84c51_row2_col4" class="data row2 col4" >-35788</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84c51_row3_col0" class="data row3 col0" >077_Manchester_MV_21.xls</td>
#       <td id="T_84c51_row3_col1" class="data row3 col1" >44487</td>
#       <td id="T_84c51_row3_col2" class="data row3 col2" >037_Derby_MV_21.xls</td>
#       <td id="T_84c51_row3_col3" class="data row3 col3" >9511</td>
#       <td id="T_84c51_row3_col4" class="data row3 col4" >-34976</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84c51_row4_col0" class="data row4 col0" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_84c51_row4_col1" class="data row4 col1" >19643</td>
#       <td id="T_84c51_row4_col2" class="data row4 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_84c51_row4_col3" class="data row4 col3" >4886</td>
#       <td id="T_84c51_row4_col4" class="data row4 col4" >-14757</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84c51_row5_col0" class="data row5 col0" >009_Bethel_MV_21.xlsx</td>
#       <td id="T_84c51_row5_col1" class="data row5 col1" >17855</td>
#       <td id="T_84c51_row5_col2" class="data row5 col2" >10_Bethlehem_MVData_2019.csv</td>
#       <td id="T_84c51_row5_col3" class="data row5 col3" >4760</td>
#       <td id="T_84c51_row5_col4" class="data row5 col4" >-13095</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84c51_row6_col0" class="data row6 col0" >107_Orange_MV_21.xlsx</td>
#       <td id="T_84c51_row6_col1" class="data row6 col1" >13522</td>
#       <td id="T_84c51_row6_col2" class="data row6 col2" >112_Pomfret_MVData_2020.csv</td>
#       <td id="T_84c51_row6_col3" class="data row6 col3" >4130</td>
#       <td id="T_84c51_row6_col4" class="data row6 col4" >-9392</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84c51_row7_col0" class="data row7 col0" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_84c51_row7_col1" class="data row7 col1" >13202</td>
#       <td id="T_84c51_row7_col2" class="data row7 col2" >055_Goshen_MV_21.XLSX</td>
#       <td id="T_84c51_row7_col3" class="data row7 col3" >4004</td>
#       <td id="T_84c51_row7_col4" class="data row7 col4" >-9198</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84c51_row8_col0" class="data row8 col0" >141_Thompson_MV_21.xlsx</td>
#       <td id="T_84c51_row8_col1" class="data row8 col1" >10054</td>
#       <td id="T_84c51_row8_col2" class="data row8 col2" >098_Norfolk_MV_21.xlsx</td>
#       <td id="T_84c51_row8_col3" class="data row8 col3" >1945</td>
#       <td id="T_84c51_row8_col4" class="data row8 col4" >-8109</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84c51_row9_col0" class="data row9 col0" >037_Derby_MV_21.xls</td>
#       <td id="T_84c51_row9_col1" class="data row9 col1" >9511</td>
#       <td id="T_84c51_row9_col2" class="data row9 col2" >101_North_Haven_MV_21.xlsx</td>
#       <td id="T_84c51_row9_col3" class="data row9 col3" >84</td>
#       <td id="T_84c51_row9_col4" class="data row9 col4" >-9427</td>
#     </tr>
#     <tr>
#       <th id="T_84c51_level0_row10" class="row_heading level0 row10" >Total</th>
#       <td id="T_84c51_row10_col0" class="data row10 col0" ></td>
#       <td id="T_84c51_row10_col1" class="data row10 col1" >323972</td>
#       <td id="T_84c51_row10_col2" class="data row10 col2" ></td>
#       <td id="T_84c51_row10_col3" class="data row10 col3" >69369</td>
#       <td id="T_84c51_row10_col4" class="data row10 col4" >-254603</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***

# %% [markdown]
# **Consider missing VINs**

# %%
missing_df_new.sort_values("missing VIN", ascending = False).head(20)
# Out:
#                            record_from  missing zip  missing VIN  \
# 134      11_Bloomfield_MVData_2019.csv            0        19643
# 108         107_Orange_MVData_2020.csv            0        14650
# 144              124_Seymour_MV_21.csv            0        13860
# 15   016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 180            141_Thompson_MV_21.xlsx            0          457
# 137          121_Salem_MVData_2019.csv            0          218
# 97          101_North_Haven_MV_21.xlsx           84           84
# 77           083_Middletown_MV_21.xlsx           82           82
# 168       136_Sterling_MVData_2019.csv           71           69
# 224             163_Windham_MV_21.xlsx           37           37
# 104       105_Old_Lyme_MVData_2019.csv           37           37
# 223        163_Windham_MVData_2020.csv           34           34
# 169            136_Sterling_MV_21.xlsx           36           34
# 191      147_Voluntown_MVData_2020.csv           29           29
# 23              024_Chaplin_MV_21.xlsx           29           29
# 25    028_Colchester_MV_21_ALTERED.csv            8            8
# 71    077_Manchester_MV_21_ALTERED.csv            3            2
# 288         63_Hampton_MVData_2019.csv            2            2
# 287          62_Hamden_MVData_2020.csv            2            2
# 83          089_New_Britain_MV_21.xlsx            2            2
#
#      missing street  not CT  count  missing zip rank  missing VIN rank  \
# 134               0    1630  19643              41.0               1.0
# 108               0    1939  14650              41.0               2.0
# 144               0    1119  15410              41.0               3.0
# 15             4886    5074   7254               6.0               4.0
# 180               7     447  10054              41.0               5.0
# 137               0     126   4914              41.0               6.0
# 97               84    2978  24425              14.0               7.0
# 77               82    3060  35302              15.0               8.0
# 168              69     223   4249              17.0               9.0
# 224              37     848  16516              19.0              10.0
# 104              37     530   9135              19.0              10.0
# 223              34     864  16228              22.0              12.0
# 169              34     161   4091              21.0              12.0
# 191              29     105   3129              23.0              14.0
# 23               29     104   2645              23.0              14.0
# 25                8     701  16219              25.0              16.0
# 71                3    2974  44487              29.0              17.0
# 288               2      67   2446              31.0              17.0
# 287               3    3796  38900              31.0              17.0
# 83                2    2174  45226              31.0              17.0
#
#      missing street rank
# 134                 33.0
# 108                 33.0
# 144                 33.0
# 15                   5.0
# 180                 21.0
# 137                 33.0
# 97                  10.0
# 77                  11.0
# 168                 12.0
# 224                 13.0
# 104                 13.0
# 223                 15.0
# 169                 15.0
# 191                 17.0
# 23                  17.0
# 25                  20.0
# 71                  22.0
# 288                 25.0
# 287                 22.0
# 83                  25.0

# %% [markdown]
# **MISSING VINs**
# * Bloomfield file for 2019 does not contain VINs
# * Orange file for 2019 does not contain VINs
# * Seymour file has major issues for missing VINs
# * Bridgewater file - has this many missing VINs in the underlying file.
# * Thompson file - has 457 missing VINs in the underlying file anyway
#
# That is - since the VINs are missing in the underlying file anyway, nothing can be done to fix these missing VINs. So we are good.

# %% [markdown]
# **Consider missing street addresses**

# %%
 missing_df_new.sort_values("missing street", ascending = False).head(20)
# Out:
#                            record_from  missing zip  missing VIN  \
# 109              107_Orange_MV_21.xlsx        13522            0
# 39     045_East_Lyme_MV_21_ALTERED.csv         4475            0
# 248         27_Clinton_MVData_2020.csv        13202            0
# 33                 037_Derby_MV_21.xls         9511            0
# 15   016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 114       10_Bethlehem_MVData_2019.csv            0            0
# 119        112_Pomfret_MVData_2020.csv         4130            0
# 49               055_Goshen_MV_21.XLSX         4004            0
# 92              098_Norfolk_MV_21.xlsx         1945            0
# 97          101_North_Haven_MV_21.xlsx           84           84
# 77           083_Middletown_MV_21.xlsx           82           82
# 168       136_Sterling_MVData_2019.csv           71           69
# 104       105_Old_Lyme_MVData_2019.csv           37           37
# 224             163_Windham_MV_21.xlsx           37           37
# 169            136_Sterling_MV_21.xlsx           36           34
# 223        163_Windham_MVData_2020.csv           34           34
# 191      147_Voluntown_MVData_2020.csv           29           29
# 23              024_Chaplin_MV_21.xlsx           29           29
# 66       072_Ledyard_MV_21_ALTERED.csv          143            0
# 25    028_Colchester_MV_21_ALTERED.csv            8            8
#
#      missing street  not CT  count  missing zip rank  missing VIN rank  \
# 109           13522   13522  13522               1.0              24.0
# 39            13325    5171  17616               7.0              24.0
# 248           13202   13202  13202               2.0              24.0
# 33             9511    9511   9511               4.0              24.0
# 15             4886    5074   7254               6.0               4.0
# 114            4760     206   4760              41.0              24.0
# 119            4130    4130   4130               9.0              24.0
# 49             4004    4004   4004              10.0              24.0
# 92             1945    1945   1945              11.0              24.0
# 97               84    2978  24425              14.0               7.0
# 77               82    3060  35302              15.0               8.0
# 168              69     223   4249              17.0               9.0
# 104              37     530   9135              19.0              10.0
# 224              37     848  16516              19.0              10.0
# 169              34     161   4091              21.0              12.0
# 223              34     864  16228              22.0              12.0
# 191              29     105   3129              23.0              14.0
# 23               29     104   2645              23.0              14.0
# 66                9     522  13858              13.0              24.0
# 25                8     701  16219              25.0              16.0
#
#      missing street rank
# 109                  1.0
# 39                   2.0
# 248                  3.0
# 33                   4.0
# 15                   5.0
# 114                  6.0
# 119                  7.0
# 49                   8.0
# 92                   9.0
# 97                  10.0
# 77                  11.0
# 168                 12.0
# 104                 13.0
# 224                 13.0
# 169                 15.0
# 223                 15.0
# 191                 17.0
# 23                  17.0
# 66                  19.0
# 25                  20.0

# %% [markdown]
# Orange 2021, Clinton 2020, Derby 2021, Bridgewater 2021 - All missing this info anyway.
# Bethlehem 2019, Pomfret 2020, Goshen 2021 - all the same
# Norfolk 2019 - is missing 1945 addresses in the underlying file

# %% [markdown]
# **Consider missing ZIP codes**

# %%
missing_df_new.sort_values("missing zip", ascending = False).head(20)
# Out:
#                                record_from  missing zip  missing VIN  \
# 109                  107_Orange_MV_21.xlsx        13522            0
# 248             27_Clinton_MVData_2020.csv        13202            0
# 160             131_Southington_MV_21.xlsx        10089            0
# 33                     037_Derby_MV_21.xls         9511            0
# 129                 117_Redding_MV_21.xlsx         8171            0
# 15       016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 39         045_East_Lyme_MV_21_ALTERED.csv         4475            0
# 267           44_East_Lyme_MVData_2019.csv         4301            0
# 119            112_Pomfret_MVData_2020.csv         4130            0
# 49                   055_Goshen_MV_21.XLSX         4004            0
# 92                  098_Norfolk_MV_21.xlsx         1945            0
# 303  77_Manchester_MVData_2019_ALTERED.csv          221            0
# 66           072_Ledyard_MV_21_ALTERED.csv          143            0
# 97              101_North_Haven_MV_21.xlsx           84           84
# 77               083_Middletown_MV_21.xlsx           82           82
# 74                   080_Meriden_MV_21.csv           78            0
# 168           136_Sterling_MVData_2019.csv           71           69
# 123            114_Preston_MVData_2020.csv           48            0
# 224                 163_Windham_MV_21.xlsx           37           37
# 104           105_Old_Lyme_MVData_2019.csv           37           37
#
#      missing street  not CT  count  missing zip rank  missing VIN rank  \
# 109           13522   13522  13522               1.0              24.0
# 248           13202   13202  13202               2.0              24.0
# 160               2   12764  42996               3.0              24.0
# 33             9511    9511   9511               4.0              24.0
# 129               0    8171   8171               5.0              24.0
# 15             4886    5074   7254               6.0               4.0
# 39            13325    5171  17616               7.0              24.0
# 267               0    5215  17448               8.0              24.0
# 119            4130    4130   4130               9.0              24.0
# 49             4004    4004   4004              10.0              24.0
# 92             1945    1945   1945              11.0              24.0
# 303               0    3456  45785              12.0              24.0
# 66                9     522  13858              13.0              24.0
# 97               84    2978  24425              14.0               7.0
# 77               82    3060  35302              15.0               8.0
# 74                0    2475  45360              16.0              24.0
# 168              69     223   4249              17.0               9.0
# 123               0      14   4105              18.0              24.0
# 224              37     848  16516              19.0              10.0
# 104              37     530   9135              19.0              10.0
#
#      missing street rank
# 109                  1.0
# 248                  3.0
# 160                 25.0
# 33                   4.0
# 129                 33.0
# 15                   5.0
# 39                   2.0
# 267                 33.0
# 119                  7.0
# 49                   8.0
# 92                   9.0
# 303                 33.0
# 66                  19.0
# 97                  10.0
# 77                  11.0
# 74                  33.0
# 168                 12.0
# 123                 33.0
# 224                 13.0
# 104                 13.0

# %% [markdown]
# * Orange 2021 - **not an error** - the ZIP is genuinely missing in the underlying file
# * Clinton - is genuinely missing
# * Southington - 10,089 ZIPs are genuinely missing
# * Derby - is genuinely missing
# * Redding - is genuinely missing in the underlying file
# * Bridgewater 2021 - real
# * East Lyme 21 - really 4475 are indeed missing.
# * Pomfret - Real
# * Goshen - Real
# * Norfolk 2021 - genuinely missing
