# %% [markdown]
# # Set up

# %%
# Warning Management
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# DataFrames
import pandas as pd

# Plotting
import matplotlib.pyplot as plt

# Maths
import numpy as np
import math

# Path management
import pathlib
import os
import sys

# Progress tracking
from tqdm import tqdm

# Regular Expressions
import re

# Logging
import logging

# %% [markdown]
# ## Paths and files

# %%
# Paths 
path = pathlib.Path().resolve()
if sys.platform == 'linux':
    data_path = path.parent.parent / "data" 
    vin_matching_list = pd.read_csv(data_path / "vin_matching" / "all_vins_nhtsa.csv").drop_duplicates("vin_corrected")
    chunks = pd.read_csv(data_path /  "municipal_dataset_latest"/ f"2019-21_data_compiled_RN_{version}.csv", header=0, chunksize = 10000)
else:
    data_path = path.parent / "data"
    print("YET TO FIX THIS")

# Version of raw data to get
version = "102323"

# Load Vin Matching list and raw data
# vin_matching_list = pd.read_csv(data_path / "vin_matching" / "all_vins_nhtsa.csv").drop_duplicates("vin_corrected")
# chunks = pd.read_csv(data_path /  "municipal_dataset"/ f"2019-21_data_compiled_RN_{version}.csv", header=0, chunksize = 10000)

# %% [markdown]
# ## Functions used to process dataset

# %%
def create_valid_zip(zip):
    try:
        zip_str = str(zip)
        zip_str = zip_str.strip()
        has_dot = re.search(r"\.", zip_str)

        # Get rid of decimal places
        if has_dot:
            zip_str = zip_str[0:re.search(r"\.", zip_str).start()]

        split_zip = re.split("-", zip_str)
        
        if len(split_zip) == 2:
            return create_valid_zip(split_zip[0])
        else:
            # If length is less than 4, return na
            if len(zip_str) < 4:
                return np.NaN
                
            # If length is 4 or 5, check it
            elif((len(zip_str) == 5) | (len(zip_str) == 4)):
                matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)
                if matched:
                    return matched[0].zfill(5)
                else:
                    return np.NaN
            # If the zip is between 5 and 8 (inclusive) long, we assume the first 4 are the first part
            # And the second 4 are the second part
            # There is no other way to do this... 
            elif((len(zip_str) > 5) & (len(zip_str)<9)):
                return create_valid_zip(zip_str[0:4])
            elif (len(zip_str) == 9):
                return create_valid_zip(zip_str[0:5])
            else:
                return np.NaN
        
    except Exception as e:
        print(e)
        return np.NaN
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1573902/3617627808.py:22: SyntaxWarning: invalid escape sequence '\s'
#   matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)

# %%
def convert_vin_valid(vin):
    try:
        vin_str = str(vin)
        if len(vin_str) < 11:
            return "NA"
        if " " in vin_str[0:11]:
            return "NA"
        else:
            return vin_str[0:8]+"*"+vin_str[9:11]
    except:
        return "NA"

def return_matched_vins(chunk_number, df, vin_column, matching_list):
    match = df.merge(matching_list,
                    left_on = vin_column,
                    right_on = vin_column,
                    how = 'left')
    
    # Get rows of DF where VINS matched
    df_vins_matched = match.loc[match["Manufacturer Name"].notna(), :]
    df_vins_unmatched = match.loc[match["Manufacturer Name"].isna(), :]
    
    # Get length
    len_matched = len(df_vins_matched)
    len_unmatched = len(df_vins_unmatched)
    len_all = len(match)
    
    # Create df
    tally_dict = {"Chunk Number": [chunk_number],
                  "Matched" : [len_matched],
                  "Unmatched" : [len_unmatched],
                  "All" : [len_all]}
    
    match_unmatched_tally = pd.DataFrame(tally_dict)

    return [match, match_unmatched_tally]
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1573902/729533879.py:14: SyntaxWarning: invalid escape sequence '\s'
#   matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", split_zip[0])

# %% [markdown]
# # Process dataset

# %%
version = "102323"

# %%
output_df = pd.DataFrame([])
output_tally_df = pd.DataFrame([])
i = 0
num_to_run = 590

for chunk in tqdm(chunks):
    # Check that we haven't gone too far
    if i >= num_to_run:
        break

    chunk = chunk.reset_index()
    chunk = chunk.rename(columns = {"index" : "original_index"})

    # Reduce reduce the number of columns
    chunk_simplified = chunk[['original_index', 'record_from', 'name', 'street', 'city', 
                          'state', 'zip', 'vehicle_year', 'vehicle_make', 'vehicle_model',
                          'vehicle_class', 'vehicle_id']].reset_index(drop = True)

    # Get corrected zips
    chunk_simplified["zip_corrected"] = chunk_simplified["zip"].apply(lambda x: create_valid_zip(x)).reset_index(drop = True)

    # Get the vin codes, and add them as a column
    chunk_simplified["vin_corrected"] = chunk_simplified["vehicle_id"].apply(lambda x: convert_vin_valid(x))
    chunk_simplified = chunk_simplified.reset_index(drop=True)

    # Get the match and tally
    matches, tally = return_matched_vins(i, chunk_simplified, "vin_corrected", vin_matching_list)

    # Concatenate
    output_df = pd.concat([output_df, matches])
    output_tally_df = pd.concat([output_tally_df, tally])
    
    # Save every 100
    if ((i % 100)+1 ==100) & (i>0):
        dir = path.parent / f"processed_chunks_{version}"
        if not dir.is_dir():
            os.mkdir(dir)
        output_df.to_csv(dir / f"matching_output{i}.csv")
        output_tally_df.to_csv( dir / f"tally_output{i}.csv")
        output_df = pd.DataFrame([])
        output_tally_df = pd.DataFrame([])

    i += 1

# %%
# Final save
output_df.to_csv(dir / f"matching_output{i}.csv")
output_tally_df.to_csv(dir / f"tally_output{i}.csv")

# %% [markdown]
# # Further checks

# %% [markdown]
# # Concatenate all the joined datasets

# %% [markdown]
# ### Check length

# %%
# Check length - this is the same as the legnth of
length = 0
for file in dir.iterdir():
    if file.name[0:8] == "matching":
        print(file.name)
        df = pd.read_csv(file, usecols = ["record_from"])
        length += len(df)

print(length)
# Out:
# matching_output299.csv
# matching_output578.csv
# matching_output199.csv
# matching_output499.csv
# matching_output399.csv
# matching_output99.csv
# 5777151

# %% [markdown]
# ### Check number of VINs missing and not

# %%
processed_chunks_path = dir
tally_all = pd.DataFrame([])
cols = 0

for file in processed_chunks_path.iterdir():
    if file.name[0:5] == "tally":
        # Track progress
        print(file.name)

        # Extract the file and create a counter
        df = pd.read_csv(file, usecols = ["Matched", "Unmatched", "All"])
        df["count"] = 1

        # Add to concatenated file
        tally_all = pd.concat([tally_all, df]).reset_index(drop = True)
# Out:
# tally_output99.csv
# tally_output578.csv
# tally_output299.csv
# tally_output399.csv
# tally_output199.csv
# tally_output499.csv

# %%
summary_tally = tally_all.agg(['sum'], axis = 0).rename(columns = {"Matched" : "Matched VINs",
                                                                   "Unmatched": "Unmatched VINs",
                                                                   "All" : "All Entries"})[["Matched VINs", "Unmatched VINs", "All Entries"]]

# %%
summary_tally.loc["percentage"] = summary_tally.agg(lambda x: x/5787151 * 100, axis = 0).loc["sum"]
summary_tally.loc["percentage"] = summary_tally.loc["percentage"].map('{:.2f}%'.format)

# %%
summary_tally
# Out:
#            Matched VINs Unmatched VINs All Entries
# sum           5523873.0       253278.0   5777151.0
# percentage       95.45%          4.38%      99.83%

# %% [markdown]
# ### Import all all vehicle details

# %%
processed_chunks_path = dir
concat_grouped = pd.DataFrame([])
cols = 0

for file in processed_chunks_path.iterdir():
    if file.name[0:8] == "matching":
        # Track progress
        print(file.name)

        # Extract the file and create a counter
        df = pd.read_csv(file, usecols = ["record_from", "zip_corrected", "Fuel Type - Primary"])
        df["count"] = 1

        # Group - note that this drops NAs 
        grouped = df.groupby(by=["record_from", "zip_corrected", "Fuel Type - Primary"]).sum().reset_index()[["record_from", "zip_corrected", "Fuel Type - Primary", "count"]]
        grouped = grouped.astype({'zip_corrected': 'str',
                                  'Fuel Type - Primary' : 'str',
                                  'count': 'int'})

        # Add this to the concatenated file
        concat_grouped = pd.concat([concat_grouped, grouped])
# Out:
# matching_output299.csv
# matching_output578.csv
# matching_output199.csv
# matching_output499.csv
# matching_output399.csv
# matching_output99.csv

# %%
concat_grouped.to_csv(data_path / "municipal_dataset_extracts"  / "mun_nv_reg_zip_type.csv")

# %%
concat_grouped
# Out:
#                     record_from zip_corrected Fuel Type - Primary  count
# 0         001_Andover_MV_21.csv        1040.0            Gasoline     11
# 1         001_Andover_MV_21.csv        1810.0            Gasoline     20
# 2         001_Andover_MV_21.csv        2199.0            Gasoline      1
# 3         001_Andover_MV_21.csv        2860.0            Gasoline      1
# 4         001_Andover_MV_21.csv        6029.0            Gasoline      1
# ...                         ...           ...                 ...    ...
# 13432  169_Woodstock_MV_21.xlsx       90501.0            Gasoline     20
# 13433  169_Woodstock_MV_21.xlsx       92123.0            Gasoline      1
# 13434  169_Woodstock_MV_21.xlsx       94538.0            Electric      1
# 13435  169_Woodstock_MV_21.xlsx       95865.0            Gasoline     13
# 13436  169_Woodstock_MV_21.xlsx       98112.0            Gasoline      1
#
# [73291 rows x 4 columns]

# %% [markdown]
# # Observe Output Data

# %%
ct_zip_mask = (concat_grouped["zip_corrected"].str[:-2].str.zfill(5).str[0:2])=="06"

# %%
ct_entries = concat_grouped[ct_zip_mask]

# %%
ct_entries["count"].sum()
# Out:
# 4630466

# %%
year_2021_mask = ct_entries["record_from"].str.contains("_21")

# %%
ct_by_type_zip_21 = ct_entries.loc[year_2021_mask, ["zip_corrected", "Fuel Type - Primary", "count"]].groupby(["zip_corrected", "Fuel Type - Primary"]).sum().reset_index()
evs_21 = ct_by_type_zip_21[ct_by_type_zip_21["Fuel Type - Primary"] == "Electric"]["count"].sum()

# %%
rlp_processed = pd.read_csv(data_path / "rlpolk_data" / "new_vehicle_sales_month_year_zip.csv", index_col = [0])
rlp_evs_21 = rlp_processed.loc[(rlp_processed["year"] == 2021) & (rlp_processed["FuelTypePrimary"] == "Electric")]
rlp_evs_21_yr = rlp_evs_21.groupby("ZIP_CODE").sum()[["VEH_COUNT"]].reset_index()
rlp_evs_21_yr["zip_corrected"] = rlp_evs_21_yr["ZIP_CODE"].astype(str)

# %%
municipal_evs_21 = ct_by_type_zip_21[ct_by_type_zip_21["Fuel Type - Primary"] == "Electric"]
municipal_evs_21["zip_corrected"] = municipal_evs_21["zip_corrected"].astype(str).str[:-2]
# Out:
# /tmp/ipykernel_1573902/1804960885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipal_evs_21["zip_corrected"] = municipal_evs_21["zip_corrected"].astype(str).str[:-2]

# %%
compare = municipal_evs_21.merge(rlp_evs_21_yr,
                                 how = 'left',
                                 right_on = "zip_corrected",
                                 left_on = "zip_corrected").rename(columns = {"count" : "count_municipal",
                                                                              "VEH_COUNT":"count_rlpolk"})

# %%
def try_divide(x,y):
    try:
        return x/y
    except:
        return np.NaN

# %%
compare["pct"] = compare.apply(lambda x: try_divide(x.count_municipal, x.count_rlpolk), axis = 1)

# %%
compare.sort_values("pct", ascending = False).head(30)
# Out:
#     zip_corrected Fuel Type - Primary  count_municipal  ZIP_CODE  \
# 101          6281            Electric               48    6281.0
# 115          6354            Electric               15    6354.0
# 28           6052            Electric               21    6052.0
# 171          6469            Electric                6    6469.0
# 9            6021            Electric                6    6021.0
# 222          6751            Electric               23    6751.0
# 111          6339            Electric               37    6339.0
# 126          6375            Electric               20    6375.0
# 161          6447            Electric               44    6447.0
# 138          6401            Electric               29    6401.0
# 98           6278            Electric               20    6278.0
# 11           6023            Electric                4    6023.0
# 14           6027            Electric                4    6027.0
# 86           6247            Electric               12    6247.0
# 181          6481            Electric                4    6481.0
# 100          6280            Electric                8    6280.0
# 55           6090            Electric               12    6090.0
# 151          6423            Electric               35    6423.0
# 215          6706            Electric               11    6706.0
# 76           6226            Electric               22    6226.0
# 133          6384            Electric                7    6384.0
# 118          6359            Electric               21    6359.0
# 108          6334            Electric                7    6334.0
# 105          6331            Electric                7    6331.0
# 71           6118            Electric               45    6118.0
# 164          6455            Electric               17    6455.0
# 246          6796            Electric               10    6796.0
# 148          6419            Electric               40    6419.0
# 96           6268            Electric               69    6268.0
# 41           6071            Electric               29    6071.0
#
#      count_rlpolk       pct
# 101           6.0  8.000000
# 115           2.0  7.500000
# 28            3.0  7.000000
# 171           1.0  6.000000
# 9             1.0  6.000000
# 222           4.0  5.750000
# 111           7.0  5.285714
# 126           4.0  5.000000
# 161          10.0  4.400000
# 138           7.0  4.142857
# 98            5.0  4.000000
# 11            1.0  4.000000
# 14            1.0  4.000000
# 86            3.0  4.000000
# 181           1.0  4.000000
# 100           2.0  4.000000
# 55            3.0  4.000000
# 151           9.0  3.888889
# 215           3.0  3.666667
# 76            6.0  3.666667
# 133           2.0  3.500000
# 118           6.0  3.500000
# 108           2.0  3.500000
# 105           2.0  3.500000
# 71           13.0  3.461538
# 164           5.0  3.400000
# 246           3.0  3.333333
# 148          12.0  3.333333
# 96           21.0  3.285714
# 41            9.0  3.222222

# %%
ct_entries[ct_entries["zip_corrected"] == 6281]
# Out:
# Empty DataFrame
# Columns: [record_from, zip_corrected, Fuel Type - Primary, count]
# Index: []

# %%
# Check
processed_chunks_path = dir
test = pd.DataFrame([])
cols = 0

# %%
for file in processed_chunks_path.iterdir():
    if file.name[0:8] == "matching":
        # Track progress
        print(file.name)

        # Extract the file and create a counter
        df = pd.read_csv(file, usecols = ["record_from", "name", "street", "vehicle_make", "vehicle_model", "zip_corrected", "Fuel Type - Primary", "Electrification Level"])
        out = df[df["zip_corrected"] == 6281]
        out = out[out["Fuel Type - Primary"] == "Electric"]
        
        # Add this to the concatenated file
        test = pd.concat([test, out])
# Out:
# matching_output299.csv
# matching_output578.csv
# matching_output199.csv
# matching_output499.csv
# matching_output399.csv
# matching_output99.csv

# %%
test
# Out:
#                           record_from  \
# 683785          112_Pomfret_MV_21.csv
# 970082  169_Woodstock_MVData_2019.csv
# 971530  169_Woodstock_MVData_2019.csv
# 971978  169_Woodstock_MVData_2019.csv
# 971989  169_Woodstock_MVData_2019.csv
# ...                               ...
# 324544       169_Woodstock_MV_21.xlsx
# 324602       169_Woodstock_MV_21.xlsx
# 324942       169_Woodstock_MV_21.xlsx
# 325260       169_Woodstock_MV_21.xlsx
# 325454       169_Woodstock_MV_21.xlsx
#
#                                             name  \
# 683785  DELUCA JOHN E
# 970082  AMBERG ANNE H
# 971530  CHANG ROBERT A
# 971978  COYLE ANDREA T
# 971989  CRAIG KRISTI L
# ...                                          ...
# 324544  SMITH AARON M
# 324602  SMITH TODD R
# 324942  THAYER DEVIN R
# 325260  VAZQUEZ-SOTO KARISSA
# 325454  WESLER LEE S
#
#                                 street vehicle_make vehicle_model  \
# 683785  236 W QUASSET RD                      CHEVR      BOLT EV
# 970082  1041 ROUTE 169                        TOYOT      PRIUS PL
# 971530  1051 ROUTE 169                        MINI       COOPER S
# 971978  401 NEW SWEDEN RD                     TOYOT      PRIUS PR
# 971989  195 COUNTY RD                         CHEVR      VOLT
# ...                                ...          ...           ...
# 324544  420 BARLOW CEMETERY RD                TOYOT      PRIUS PR
# 324602  976 ROUTE 171                         CHEVR      VOLT LT
# 324942  296 ROUTE 171 APT 16                  TOYOT      PRIUS PR
# 325260  577 ROUTE 197                         NISSA      LEAF S P
# 325454  1041 ROUTE 169                        TOYOT      PRIUS PR
#
#         zip_corrected Fuel Type - Primary  \
# 683785         6281.0            Electric
# 970082         6281.0            Electric
# 971530         6281.0            Electric
# 971978         6281.0            Electric
# 971989         6281.0            Electric
# ...               ...                 ...
# 324544         6281.0            Electric
# 324602         6281.0            Electric
# 324942         6281.0            Electric
# 325260         6281.0            Electric
# 325454         6281.0            Electric
#
#                          Electrification Level
# 683785          BEV (Battery Electric Vehicle)
# 970082  PHEV (Plug-in Hybrid Electric Vehicle)
# 971530  PHEV (Plug-in Hybrid Electric Vehicle)
# 971978  PHEV (Plug-in Hybrid Electric Vehicle)
# 971989  PHEV (Plug-in Hybrid Electric Vehicle)
# ...                                        ...
# 324544  PHEV (Plug-in Hybrid Electric Vehicle)
# 324602  PHEV (Plug-in Hybrid Electric Vehicle)
# 324942  PHEV (Plug-in Hybrid Electric Vehicle)
# 325260          BEV (Battery Electric Vehicle)
# 325454  PHEV (Plug-in Hybrid Electric Vehicle)
#
# [77 rows x 8 columns]

# %%
test[(test["record_from"].str.contains("MV_21"))]
# Out:
#                      record_from                                      name  \
# 683785     112_Pomfret_MV_21.csv  DELUCA JOHN E
# 316814  169_Woodstock_MV_21.xlsx  ALHAQ ZAMEER
# 316841  169_Woodstock_MV_21.xlsx  AMBERG ANNE H
# 316842  169_Woodstock_MV_21.xlsx  AMBERG ANNE H
# 316994  169_Woodstock_MV_21.xlsx  AUGER RAYMOND W
# 317127  169_Woodstock_MV_21.xlsx  BARTELS MICHAEL W
# 317303  169_Woodstock_MV_21.xlsx  BENKHART BRUCE S
# 317433  169_Woodstock_MV_21.xlsx  BERNARD ELIZABETH A
# 318162  169_Woodstock_MV_21.xlsx  CANEDY THOMAS E JR
# 318343  169_Woodstock_MV_21.xlsx  CHANG ROBERT A
# 318411  169_Woodstock_MV_21.xlsx  CHASIN SUSAN D
# 318796  169_Woodstock_MV_21.xlsx  CRAIG KRISTI L
# 319074  169_Woodstock_MV_21.xlsx  DEMERS DAVID A
# 319180  169_Woodstock_MV_21.xlsx  DICKINSON GAIL L
# 319182  169_Woodstock_MV_21.xlsx  DICKINSON MARIA P
# 319218  169_Woodstock_MV_21.xlsx  DILKO RICHARD A
# 319330  169_Woodstock_MV_21.xlsx  DOYLE JANE M
# 319396  169_Woodstock_MV_21.xlsx  DUKE DWIGHT W 3RD
# 319649  169_Woodstock_MV_21.xlsx  ESSLINGER DENISE
# 320317  169_Woodstock_MV_21.xlsx  GRADIE JONATHAN C
# 320630  169_Woodstock_MV_21.xlsx  HAYES BRIDGET C
# 320932  169_Woodstock_MV_21.xlsx  HULME EVA S
# 321167  169_Woodstock_MV_21.xlsx  KAEDING JAMES J
# 321270  169_Woodstock_MV_21.xlsx  KELLY PAUL M
# 321976  169_Woodstock_MV_21.xlsx  LUNDT MEGAN A
# 322054  169_Woodstock_MV_21.xlsx  MAGEE KENNETH W
# 322231  169_Woodstock_MV_21.xlsx  MATSEN KRISTA E
# 322264  169_Woodstock_MV_21.xlsx  MCCALLUM MICHAEL R
# 322419  169_Woodstock_MV_21.xlsx  MERCIER CARL R
# 322597  169_Woodstock_MV_21.xlsx  MORIN DAWN M
# 322631  169_Woodstock_MV_21.xlsx  MORISSETTE LEO A
# 322660  169_Woodstock_MV_21.xlsx  MORSE DAVID A
# 322733  169_Woodstock_MV_21.xlsx  MULLEN DAVID H
# 322915  169_Woodstock_MV_21.xlsx  NIELSEN CARL D
# 322998  169_Woodstock_MV_21.xlsx  NOWAK JAMES E
# 323346  169_Woodstock_MV_21.xlsx  PERL JADRANKA
# 323714  169_Woodstock_MV_21.xlsx  QUINN THOMAS D
# 323715  169_Woodstock_MV_21.xlsx  QUINN THOMAS D
# 324087  169_Woodstock_MV_21.xlsx  RUGGERI LESLEE M
# 324150  169_Woodstock_MV_21.xlsx  SAFIN ERIC Z
# 324198  169_Woodstock_MV_21.xlsx  SAMBOROWSKI LEONARD J
# 324231  169_Woodstock_MV_21.xlsx  SARGENT ERIC M
# 324381  169_Woodstock_MV_21.xlsx  SHAW SCOTT P
# 324544  169_Woodstock_MV_21.xlsx  SMITH AARON M
# 324602  169_Woodstock_MV_21.xlsx  SMITH TODD R
# 324942  169_Woodstock_MV_21.xlsx  THAYER DEVIN R
# 325260  169_Woodstock_MV_21.xlsx  VAZQUEZ-SOTO KARISSA
# 325454  169_Woodstock_MV_21.xlsx  WESLER LEE S
#
#                                 street vehicle_make vehicle_model  \
# 683785  236 W QUASSET RD                      CHEVR      BOLT EV
# 316814  32 GREY FOX LNDG                      TESLA      MODEL 3
# 316841  1041 ROUTE 169                        TOYOT      PRIUS PL
# 316842  1041 ROUTE 169                        TESLA      MODEL 3
# 316994  50 BULL HILL RD                       TESLA      MODEL S
# 317127  31 GREY FOX LNDG                      TESLA      MODEL 3
# 317303  45 WOODSTOCK RD                       TESLA      MODEL S
# 317433  680 RTE 171                           CHEVR      VOLT LT
# 318162  435 BRICKYARD RD                      TOYOT      PRIUS PR
# 318343  1051 RTE 169                          MINI       COOPER S
# 318411  589 NEW SWEDEN RD                     KIA        NIRO EV
# 318796  195 COUNTY RD                         CHEVR      VOLT
# 319074  3 BARBER RD                           FORD       C-MAX SE
# 319180  580 PROSPECT ST                       TESLA      MODEL 3
# 319182  40 SHIELDS RD                         TESLA      MODEL S
# 319218  90 ENGLISH NEIGHBORHOOD RD            CHEVR      BOLT EV
# 319330  PO BOX 1018                           TOYOT      PRIUS PR
# 319396  40 LEBANON HILL RD                    TESLA      MODEL S
# 319649  50 ROCKY HILL RD                      VOLVO      XC60 T8
# 320317  46 WOODSTOCK MEADOWS                  NISSA      LEAF S/S
# 320630  296 ROUTE 171 APT 7                   NISSA      LEAF S/S
# 320932  321 ROCKY HILL RD                     NISSA      LEAF S P
# 321167  1221 ROUTE 169                        HYUND      KONA SEL
# 321270  84 POND FACTORY RD                    TESLA      MODEL S
# 321976  177 PULPIT ROCK RD                    TESLA      MODEL X
# 322054  4 JEANS CT                            TESLA      MODEL 3
# 322231  1086 ROUTE 197                        TESLA      MODEL 3
# 322264  210 ARVIDSON RD                       CHEVR      BOLT EV
# 322419  87 EAST QUASSET ROAD                  CHEVR      BOLT EV
# 322597  62 LEBANON HILL RD                    FORD       C-MAX PR
# 322631  200 POLE BRIDGE RD                    TESLA      MODEL S
# 322660  89 PAINE RD                           CHEVR      BOLT EV
# 322733  135 PERRIN RD                         TESLA      MODEL S
# 322915  34 CENTER RD                          TOYOT      RAV4 PRI
# 322998  449 CENTER RD                         VOLKS      E-GOLF S
# 323346  216 W QUASSET RD                      BMW        X5 XDRIV
# 323714  81 CHILD DOME RD                      TOYOT      RAV4 PRI
# 323715  81 CHILD DOME RD                      HONDA      CLARITY
# 324087  50 MILL BROOK LN                      PORSC      TAYCAN T
# 324150  245 COUNTY RD                         FORD       FOCUS BE
# 324198  133 CALKINS RD                        TESLA      MODEL 3
# 324231  60 SENEXET VILLAGE RD                 CHEVR      VOLT PRE
# 324381  256 SMITH RD                          TESLA      MODEL Y
# 324544  420 BARLOW CEMETERY RD                TOYOT      PRIUS PR
# 324602  976 ROUTE 171                         CHEVR      VOLT LT
# 324942  296 ROUTE 171 APT 16                  TOYOT      PRIUS PR
# 325260  577 ROUTE 197                         NISSA      LEAF S P
# 325454  1041 ROUTE 169                        TOYOT      PRIUS PR
#
#         zip_corrected Fuel Type - Primary  \
# 683785         6281.0            Electric
# 316814         6281.0            Electric
# 316841         6281.0            Electric
# 316842         6281.0            Electric
# 316994         6281.0            Electric
# 317127         6281.0            Electric
# 317303         6281.0            Electric
# 317433         6281.0            Electric
# 318162         6281.0            Electric
# 318343         6281.0            Electric
# 318411         6281.0            Electric
# 318796         6281.0            Electric
# 319074         6281.0            Electric
# 319180         6281.0            Electric
# 319182         6281.0            Electric
# 319218         6281.0            Electric
# 319330         6281.0            Electric
# 319396         6281.0            Electric
# 319649         6281.0            Electric
# 320317         6281.0            Electric
# 320630         6281.0            Electric
# 320932         6281.0            Electric
# 321167         6281.0            Electric
# 321270         6281.0            Electric
# 321976         6281.0            Electric
# 322054         6281.0            Electric
# 322231         6281.0            Electric
# 322264         6281.0            Electric
# 322419         6281.0            Electric
# 322597         6281.0            Electric
# 322631         6281.0            Electric
# 322660         6281.0            Electric
# 322733         6281.0            Electric
# 322915         6281.0            Electric
# 322998         6281.0            Electric
# 323346         6281.0            Electric
# 323714         6281.0            Electric
# 323715         6281.0            Electric
# 324087         6281.0            Electric
# 324150         6281.0            Electric
# 324198         6281.0            Electric
# 324231         6281.0            Electric
# 324381         6281.0            Electric
# 324544         6281.0            Electric
# 324602         6281.0            Electric
# 324942         6281.0            Electric
# 325260         6281.0            Electric
# 325454         6281.0            Electric
#
#                          Electrification Level
# 683785          BEV (Battery Electric Vehicle)
# 316814          BEV (Battery Electric Vehicle)
# 316841  PHEV (Plug-in Hybrid Electric Vehicle)
# 316842          BEV (Battery Electric Vehicle)
# 316994          BEV (Battery Electric Vehicle)
# 317127          BEV (Battery Electric Vehicle)
# 317303          BEV (Battery Electric Vehicle)
# 317433  PHEV (Plug-in Hybrid Electric Vehicle)
# 318162  PHEV (Plug-in Hybrid Electric Vehicle)
# 318343  PHEV (Plug-in Hybrid Electric Vehicle)
# 318411          BEV (Battery Electric Vehicle)
# 318796  PHEV (Plug-in Hybrid Electric Vehicle)
# 319074  PHEV (Plug-in Hybrid Electric Vehicle)
# 319180          BEV (Battery Electric Vehicle)
# 319182          BEV (Battery Electric Vehicle)
# 319218          BEV (Battery Electric Vehicle)
# 319330  PHEV (Plug-in Hybrid Electric Vehicle)
# 319396          BEV (Battery Electric Vehicle)
# 319649  PHEV (Plug-in Hybrid Electric Vehicle)
# 320317          BEV (Battery Electric Vehicle)
# 320630          BEV (Battery Electric Vehicle)
# 320932          BEV (Battery Electric Vehicle)
# 321167          BEV (Battery Electric Vehicle)
# 321270          BEV (Battery Electric Vehicle)
# 321976          BEV (Battery Electric Vehicle)
# 322054          BEV (Battery Electric Vehicle)
# 322231          BEV (Battery Electric Vehicle)
# 322264          BEV (Battery Electric Vehicle)
# 322419          BEV (Battery Electric Vehicle)
# 322597  PHEV (Plug-in Hybrid Electric Vehicle)
# 322631          BEV (Battery Electric Vehicle)
# 322660          BEV (Battery Electric Vehicle)
# 322733          BEV (Battery Electric Vehicle)
# 322915  PHEV (Plug-in Hybrid Electric Vehicle)
# 322998          BEV (Battery Electric Vehicle)
# 323346  PHEV (Plug-in Hybrid Electric Vehicle)
# 323714  PHEV (Plug-in Hybrid Electric Vehicle)
# 323715  PHEV (Plug-in Hybrid Electric Vehicle)
# 324087          BEV (Battery Electric Vehicle)
# 324150          BEV (Battery Electric Vehicle)
# 324198          BEV (Battery Electric Vehicle)
# 324231  PHEV (Plug-in Hybrid Electric Vehicle)
# 324381          BEV (Battery Electric Vehicle)
# 324544  PHEV (Plug-in Hybrid Electric Vehicle)
# 324602  PHEV (Plug-in Hybrid Electric Vehicle)
# 324942  PHEV (Plug-in Hybrid Electric Vehicle)
# 325260          BEV (Battery Electric Vehicle)
# 325454  PHEV (Plug-in Hybrid Electric Vehicle)
