# %% [markdown]
# # Quality Check - Reconstructed Municipal Data

# %% [markdown]
# The purpose of this file is to Quality Check the re-constructed municipal data, compiled by RN in the file `reconstruct_municipal.ipynb`

# %%
# Warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# DataFrames
import pandas as pd

# Path Management
import pathlib
import os

# Progress Tracking
from tqdm import tqdm

# Regular expressions
import re

# Maths
import numpy as np

# System
from sys import platform

# Import Geopandas
import geopandas as gpd
from shapely.geometry import Point
from geopandas.tools import geocode
import geopy

# %%
# Heatmaps
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Heatmaps
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Set paths
path = raw_path = pathlib.Path().resolve()

if platform == "windows":
    raw_path = pathlib.Path().resolve().parent.parent / "Dropbox" / "2019 MV Data by Town" / "Vehicles_2022" / "Compiled"
elif platform == "linux":
    raw_path = pathlib.Path().resolve().parent.parent / "data" / "municipal_dataset_latest"
raw_path.is_dir()
# Out:
# True

# %% [markdown]
# # Load data

# %%
def reset_recompiled_data():
    recompiled_data = pd.read_csv(raw_path / "2019-21_data_compiled_RN_100323.csv", chunksize = 1000)
    return recompiled_data

# %%
original_data = pd.read_csv(raw_path / "2019-21 data compiled.csv", chunksize = 1000)

# %% [markdown]
# # Checks

# %% [markdown]
# ## Check the same files are used

# %%
recompiled_data_sources = []
recompiled_data_len = 0

# %% [markdown]
# Get all the unique file sources in the recompiled data

# %%
i = 0

for chunk in recompiled_data:
    if i %1000 == 0:
        print(f"Currently on chunk {i}")
        
    recompiled_data_len += len(chunk)
    
    sources = list(chunk["record_from"].unique())
    sources_new = [item for item in sources if not item in recompiled_data_sources]
    for item in sources_new:
        recompiled_data_sources.append(item)
        
    i +=1
# Out:
# Currently on chunk 0
# Currently on chunk 1000
# Currently on chunk 2000
# Currently on chunk 3000
# Currently on chunk 4000
# Currently on chunk 5000

# %% [markdown]
# Get all the unique file sources in the original data

# %%
original_data_sources = []
original_data_len = 0

# %%
i = 0

for chunk in original_data:
    if i %1000 == 0:
        print(f"Currently on chunk {i}")
        
    original_data_len += len(chunk)
    
    sources = list(chunk["record_from"].unique())
    sources_new = [item for item in sources if not item in original_data_sources]
    for item in sources_new:
        original_data_sources.append(item)
        
    i +=1
# Out:
# Currently on chunk 0
# Currently on chunk 1000
# Currently on chunk 2000
# Currently on chunk 3000
# Currently on chunk 4000
# Currently on chunk 5000

# %% [markdown]
# Compare them

# %%
diff1 = [item for item in original_data_sources if not item in recompiled_data_sources]
diff2 = [item for item in recompiled_data_sources if not item in original_data_sources]

diff1
# Out:
# ['77_Manchester_MVData_2019.csv',
#  '045_East_Lyme_MV_21.csv',
#  '072_Ledyard_MV_21.xlsx',
#  '077_Manchester_MV_21.xls',
#  '122_Salisbury_MV_21.xlsx',
#  '016_Bridgewater_MV_21.xlsx']

# %% [markdown]
# This makes sense - these are the files that got edited. Manchester 2019 and 2021, Salisbury, and Bridgewater

# %%
diff2 = [item for item in diff2 if not "ALTERED" in item]

# %%
diff2
# Out:
# ['010_Bethlehem_MV_21.xlsx',
#  '020_Burlington_MV_21.xlsx',
#  '024_Chaplin_MV_21.xlsx',
#  '034_Danbury_MV_21.xlsx',
#  '061_Haddam_MV_21.xlsx',
#  '066_Harwinton_MV_21.xlsx',
#  '079_Marlborough_MV_21.xlsx',
#  '086_Montville_MV_21.xlsx',
#  '090_New_Canaan_MV_21.xlsx',
#  '131_Southington_MV_21.xlsx',
#  '147_Voluntown_MV_21.xlsx',
#  '163_Windham_MV_21.xlsx']

# %% [markdown]
# Why weren't these items in the original data sources?... They appear to have been skipped or added later. **Note:** This has not been resolved. But because no issues arise, I assume the files should be included. Below, in `investigate_diff2,` I extract some rows from these files and confirm that they look normal - so it's OK to include them.

# %%
investigate_diff2 = pd.DataFrame([])
i = 0

for chunk in recompiled_data:
    if i %1000 == 0:
        print(f"Currently on chunk {i}")
        
    required = chunk[chunk["record_from"].isin(diff2)]
        
    excerpt_head = required.head(10)
    excerpt_tail = required.tail(10)
    
    excerpt = pd.concat([excerpt_head, excerpt_tail])
    
    investigate_diff2 = pd.concat([investigate_diff2, excerpt])
        
    i +=1
# Out:
# Currently on chunk 0
# Currently on chunk 1000
# Currently on chunk 2000
# Currently on chunk 3000
# Currently on chunk 4000
# Currently on chunk 5000

# %%
heads = []
for item in diff2:
    df = investigate_diff2[investigate_diff2["record_from"] == item]
    heads.append(df.head(10))

for df in heads:
    display(df)
# Out:
#        Unnamed: 0               record_from  \
# 95937       95937  010_Bethlehem_MV_21.xlsx
# 95938       95938  010_Bethlehem_MV_21.xlsx
# 95939       95939  010_Bethlehem_MV_21.xlsx
# 95940       95940  010_Bethlehem_MV_21.xlsx
# 95941       95941  010_Bethlehem_MV_21.xlsx
# 95942       95942  010_Bethlehem_MV_21.xlsx
# 95943       95943  010_Bethlehem_MV_21.xlsx
# 95944       95944  010_Bethlehem_MV_21.xlsx
# 95945       95945  010_Bethlehem_MV_21.xlsx
# 95946       95946  010_Bethlehem_MV_21.xlsx
#
#                                            name  \
# 95937  37-39 CITY HILL STREET LLC
# 95938  37-39 CITY HILL STREET LLC
# 95939  A & B HARD FLOOR LLC
# 95940  A MIM S CORP
# 95941  A MIM S CORP
# 95942  A MIMS CORP
# 95943  A MIMS CORP
# 95944  A MIMS CORP
# 95945  A MIMS CORP
# 95946  ABBEY OF REGINA LAUDIS
#
#                                street                            city state  \
# 95937  15 W SHORE DR                   BETHLEHEM                         CT
# 95938  15 W SHORE DR                   BETHLEHEM                         CT
# 95939  PO BOX 1387                     WATERBURY                         CT
# 95940  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95941  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95942  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95943  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95944  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95945  218 GUILDS HOLLOW RD            BETHLEHEM                         CT
# 95946  273 FLANDERS RD                 BETHLEHEM                         CT
#
#         zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 95937  6751       2021.0        CHEVR      SILVERAD           2.0
# 95938  6751       2022.0        LOOK       STLC              10.0
# 95939  6721       2019.0        GMC        SIERRA K           3.0
# 95940  6751       2000.0        MACK       CX600              2.0
# 95941  6751       2012.0        LANDO      T L               10.0
# 95942  6751       2013.0        PTRB       CONVENTI           2.0
# 95943  6751       1999.0        FONTA      303NDMRV          10.0
# 95944  6751       1995.0        LANDO      317               10.0
# 95945  6751       2004.0        INTER      4000 SER           2.0
# 95946  6751       2005.0        HONDA      ACCORD L           1.0
#
#               vehicle_id                    lease_street  UID  \
# 95937  1GC4YUEY1MF128671  15 WEST SHORE DR                NaN
# 95938  53BLTEA10NP023562  15 WEST SHORE DR                NaN
# 95939  1GT12SEY7KF230918  21 SKY MEADOW RD                NaN
# 95940  1M1AE07Y5YW003647                                  NaN
# 95941  1LH440VHXC1018832                                  NaN
# 95942  1XPSD79X2DD172162                                  NaN
# 95943  4LF4G4825X3508389                                  NaN
# 95944  1LH317VJ9S1007514                                  NaN
# 95945  1HTMMAAM14H667912                                  NaN
# 95946  1HGCM56495A149907                                  NaN
#
#                            lease_city lease_state lease_zip
# 95937  BETHLEHEM                               CT     06751
# 95938  BETHLEHEM                               CT     06751
# 95939  BETHLEHEM                               CT     06751
# 95940
# 95941
# 95942
# 95943
# 95944
# 95945
# 95946  BETHLEHEM                               CT
#         Unnamed: 0                record_from  \
# 318203      318203  020_Burlington_MV_21.xlsx
# 318204      318204  020_Burlington_MV_21.xlsx
# 318205      318205  020_Burlington_MV_21.xlsx
# 318206      318206  020_Burlington_MV_21.xlsx
# 318207      318207  020_Burlington_MV_21.xlsx
# 318208      318208  020_Burlington_MV_21.xlsx
# 318209      318209  020_Burlington_MV_21.xlsx
# 318210      318210  020_Burlington_MV_21.xlsx
# 318211      318211  020_Burlington_MV_21.xlsx
# 318212      318212  020_Burlington_MV_21.xlsx
#
#                                             name  \
# 318203  A-1 ENTERPRISES LLC
# 318204  A-1 ENTERPRISES LLC
# 318205  ABALAN DOUGLAS L
# 318206  ABALAN DOUGLAS L
# 318207  ABALAN RINETTE R
# 318208  ABASCAL RICHARD
# 318209  ABASCAL RICHARD
# 318210  ABDELREHIM MOHAMED E
# 318211  ABDELREHIM MOHAMED E
# 318212  ABDELREHIM MOHAMED E
#
#                                 street                            city state  \
# 318203  8 MARY ROAD                     BURLINGTON                        CT
# 318204  8 MARY ROAD                     BURLINGTON                        CT
# 318205  71 MILFORD ST                   BURLINGTON                        CT
# 318206  71 MILFORD ST                   BURLINGTON                        CT
# 318207  71 MILFORD ST                   BURLINGTON                        CT
# 318208  68 VENICE DR                    BURLINGTON                        CT
# 318209  68 VENICE DR                    BURLINGTON                        CT
# 318210  59 BELDEN RD                    BURLINGTON                        CT
# 318211  59 BELDEN RD                    BURLINGTON                        CT
# 318212  59 BELDEN RD                    BURLINGTON                        CT
#
#          zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 318203  6013       2021.0        FORD       F150 SUP             3
# 318204  6013       2019.0        CHEVR      SILVERAD             2
# 318205  6013       2011.0        DODGE      GRAND CR             1
# 318206  6013       2004.0        DODGE      RAM 1500             1
# 318207  6013       2001.0        HONDA      CR-V EX              1
# 318208  6013       2013.0        TOYOT      TACOMA A             3
# 318209  6013       2011.0        HARLE      FLSTN               12
# 318210  6013       2005.0        HONDA      PILOT EX             1
# 318211  6013       2013.0        TOYOT      CAMRY L/             1
# 318212  6013       2012.0        HONDA      PILOT EX             1
#
#                vehicle_id                    lease_street  UID  \
# 318203  1FTFW1E55MKD52858                                  NaN
# 318204  1HTKHPVK5KH406240  8 MARY RD                       NaN
# 318205  2D4RN5DGXBR683379                                  NaN
# 318206  1D7HU18D84S564872                                  NaN
# 318207  JHLRD18661C024901                                  NaN
# 318208  5TFUU4EN9DX054329                                  NaN
# 318209  1HD1JD517BB017457                                  NaN
# 318210  2HKYF18425H570235  59 BELDEN ROAD                  NaN
# 318211  4T1BF1FK5DU660406                                  NaN
# 318212  5FNYF4H55CB053260                                  NaN
#
#                             lease_city lease_state lease_zip
# 318203
# 318204  BURLINGTON                              CT     06013
# 318205
# 318206
# 318207
# 318208
# 318209
# 318210  BURLINGTON                              CT     06013
# 318211
# 318212
#         Unnamed: 0             record_from                      name  \
# 345894      345894  024_Chaplin_MV_21.xlsx  ABARZUA DAGGETT ASCHLY C
# 345895      345895  024_Chaplin_MV_21.xlsx  ABARZUA DAGGETT ASCHLY C
# 345896      345896  024_Chaplin_MV_21.xlsx             ABELIN DAWN L
# 345897      345897  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345898      345898  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345899      345899  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345900      345900  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345901      345901  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345902      345902  024_Chaplin_MV_21.xlsx          ACAR LEASING LTD
# 345903      345903  024_Chaplin_MV_21.xlsx            ADAMS ALEXIS E
#
#                       street       city state    zip vehicle_year  \
# 345894          26 BEDLAM RD    CHAPLIN    CT   6235       2003.0
# 345895          26 BEDLAM RD    CHAPLIN    CT   6235       2014.0
# 345896        150 CHEWINK RD    CHAPLIN    CT   6235       2009.0
# 345897   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2021.0
# 345898   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2018.0
# 345899   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2019.0
# 345900   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2021.0
# 345901   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2020.0
# 345902   4001 EMBARCADERO DR  ARLINGTON    TX  76014       2019.0
# 345903  20 CAREFREE LN APT 1    CHAPLIN    CT   6235       2018.0
#
#        vehicle_make vehicle_model vehicle_class         vehicle_id  \
# 345894        HONDA      VT750DCB            12  JH2RC44503M708944
# 345895        VOLKS      PASSAT S             1  1VWBN7A38EC063894
# 345896        HONDA       CR-V EX             1  3CZRE48539G703675
# 345897        BUICK      ENCORE P             1  KL4CJESM2MB361970
# 345898        BUICK      ENCORE P             1  KL4CJESB7JB694739
# 345899        CHEVR      TRAX 1LT             1  KL7CJPSBXKB951800
# 345900          GMC       TERRAIN             1  3GKALVEV6ML351991
# 345901        CHEVR      SILVERAD             3  1GCRYEED2LZ369807
# 345902          GMC      SIERRA L             3  2GTV2LEC7K1105839
# 345903        MITSU      OUTLANDE             1  JA4AP3AWXJU023925
#
#        lease_street  UID lease_city lease_state lease_zip
# 345894          NaN  NaN        NaN         NaN       NaN
# 345895          NaN  NaN        NaN         NaN       NaN
# 345896          NaN  NaN        NaN         NaN       NaN
# 345897          NaN  NaN        NaN         NaN       NaN
# 345898          NaN  NaN        NaN         NaN       NaN
# 345899          NaN  NaN        NaN         NaN       NaN
# 345900          NaN  NaN        NaN         NaN       NaN
# 345901          NaN  NaN        NaN         NaN       NaN
# 345902          NaN  NaN        NaN         NaN       NaN
# 345903          NaN  NaN        NaN         NaN       NaN
#         Unnamed: 0             record_from  \
# 421301      421301  034_Danbury_MV_21.xlsx
# 421302      421302  034_Danbury_MV_21.xlsx
# 421303      421303  034_Danbury_MV_21.xlsx
# 421304      421304  034_Danbury_MV_21.xlsx
# 421305      421305  034_Danbury_MV_21.xlsx
# 421306      421306  034_Danbury_MV_21.xlsx
# 421307      421307  034_Danbury_MV_21.xlsx
# 421308      421308  034_Danbury_MV_21.xlsx
# 421309      421309  034_Danbury_MV_21.xlsx
# 421310      421310  034_Danbury_MV_21.xlsx
#
#                                             name  \
# 421301  29 FEDERAL ROAD LLC
# 421302  2J S LLC
# 421303  2M GENERAL SERVICES LLC
# 421304  3M GENERAL SERVICES LLC
# 421305  4 SEASONSLLC
# 421306  4 SEASONSLLC
# 421307  404 CAR LINE LLC
# 421308  46 SL LLC
# 421309  85 MILL PLAIN ROAD LLC
# 421310  A & C ROOFING AND SIDING LLC
#
#                                 street                            city state  \
# 421301  64 TRIANGLE ST.                 DANBURY                           CT
# 421302  12 STARR AVE 14 STARR AVE       DANBURY                           CT
# 421303  12 TRIANGLE ST UNIT 2           DANBURY                           CT
# 421304  13 COTTAGE ST FL 2              DANBURY                           CT
# 421305  50 NORTH STREET                 DANBURY                           CT
# 421306  50 NORTH STREET                 DANBURY                           CT
# 421307  89 WALNUT TRL                   DANBURY                           CT
# 421308  16 HAYESTOWN RD UNIT 3104       DANBURY                           CT
# 421309  85 MILL PLAIN RD                DANBURY                           CT
# 421310  8 MALLORY ST APT 2              DANBURY                           CT
#
#          zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 421301  6810         2007        CHEVR      EXPRESS              3
# 421302  6811         2014        HINO       HINO 268             2
# 421303  6810         1998        FORD       ECONOLIN             3
# 421304  6810         2017        FORD       FUSION S             3
# 421305  6810         2021        CROSS      61435               11
# 421306  6810         2019        CHEVR      EXPRESS              3
# 421307  6811         1999        FORD       EXPEDITI             3
# 421308  6811         2020        PORSC      MACAN                1
# 421309  6811         2017        RAM        RAM CHAS            70
# 421310  6810         2008        GMC        ACADIA S             1
#
#                vehicle_id lease_street  UID lease_city lease_state lease_zip
# 421301  1GBGG29U171156648          NaN  NaN        NaN         NaN       NaN
# 421302  5PVNJ8JT9E4S55479          NaN  NaN        NaN         NaN       NaN
# 421303  1FTRE1429WHA50822          NaN  NaN        NaN         NaN       NaN
# 421304  3FA6P0HD1HR195797          NaN  NaN        NaN         NaN       NaN
# 421305  431FS1411M1000212          NaN  NaN        NaN         NaN       NaN
# 421306  1GCWGAFG3K1255867          NaN  NaN        NaN         NaN       NaN
# 421307  1FMPU18L3XLA05477          NaN  NaN        NaN         NaN       NaN
# 421308  WP1AA2A57LLB09404          NaN  NaN        NaN         NaN       NaN
# 421309  3C7WRNDL8HG625578          NaN  NaN        NaN         NaN       NaN
# 421310  1GKEV23768J245536          NaN  NaN        NaN         NaN       NaN
#         Unnamed: 0            record_from  \
# 938991      938991  061_Haddam_MV_21.xlsx
# 938992      938992  061_Haddam_MV_21.xlsx
# 938993      938993  061_Haddam_MV_21.xlsx
# 938994      938994  061_Haddam_MV_21.xlsx
# 938995      938995  061_Haddam_MV_21.xlsx
# 938996      938996  061_Haddam_MV_21.xlsx
# 938997      938997  061_Haddam_MV_21.xlsx
# 938998      938998  061_Haddam_MV_21.xlsx
# 938999      938999  061_Haddam_MV_21.xlsx
# 938991      938991  061_Haddam_MV_21.xlsx
#
#                                             name  \
# 938991  A & A PROPERTY MAINTENANCE LLC
# 938992  ABARIENTOS ANTONIETA L
# 938993  ABARIENTOS CRISPIN
# 938994  ABARIENTOS CRISPIN
# 938995  ABBATELLO STEVEN G
# 938996  ABBATELLO STEVEN G
# 938997  ABBATELLO STEVEN G
# 938998  ABBOTT ARTHUR H JR
# 938999  ABBOTT ARTHUR H JR
# 938991  A & A PROPERTY MAINTENANCE LLC
#
#                                 street                            city state  \
# 938991  77 OAK RIDGE DR UNIT 1          HADDAM                            CT
# 938992  17 LARKSPUR DR                  HIGGANUM                          CT
# 938993  17 LARKSPUR DR                  HIGGANUM                          CT
# 938994  17 LARKSPUR DR                  HIGGANUM                          CT
# 938995  5 MAPLE AVE WEST                HIGGANUM                          CT
# 938996  5 MAPLE AVE WEST                HIGGANUM                          CT
# 938997  5 MAPLE AVE WEST                HIGGANUM                          CT
# 938998  623 CANDLEWOOD HILL RD          HIGGANUM                          CT
# 938999  623 CANDLEWOOD HILL RD          HIGGANUM                          CT
# 938991  77 OAK RIDGE DR UNIT 1          HADDAM                            CT
#
#            zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 938991  6438.0         2019        FORD       F550 SUP             2
# 938992  6441.0         2005        ACURA      MDX                  1
# 938993  6441.0         2011        AUDI       A4 2.0T              1
# 938994  6441.0         2001        PORSC      911 CARR             1
# 938995  6441.0         1985        CHEVR      K10                 25
# 938996  6441.0         2011        VOLKS      JETTA TD             1
# 938997  6441.0         2003        CHEVR      SILVERAD             1
# 938998  6441.0         2009        SUBAR      OUTBACK              1
# 938999  6441.0         1997        CHEVR      K1500                3
# 938991  6438.0         2019        FORD       F550 SUP             2
#
#                vehicle_id lease_street  UID lease_city lease_state lease_zip
# 938991  1FD0X5HT6KEF91010          NaN  NaN        NaN         NaN       NaN
# 938992  2HNYD182X5H552606          NaN  NaN        NaN         NaN       NaN
# 938993  WAUFFAFL9BA091621          NaN  NaN        NaN         NaN       NaN
# 938994  WP0AA299X1S620343          NaN  NaN        NaN         NaN       NaN
# 938995  2GCEK14H3F1149599          NaN  NaN        NaN         NaN       NaN
# 938996  3VWPL7AJ2BM616673          NaN  NaN        NaN         NaN       NaN
# 938997  1GCEC14X73Z353572          NaN  NaN        NaN         NaN       NaN
# 938998  4S4BP61C497330465          NaN  NaN        NaN         NaN       NaN
# 938999  1GCEK14MXVZ191674          NaN  NaN        NaN         NaN       NaN
# 938991  1FD0X5HT6KEF91010          NaN  NaN        NaN         NaN       NaN
#          Unnamed: 0               record_from  \
# 1043778     1043778  066_Harwinton_MV_21.xlsx
# 1043779     1043779  066_Harwinton_MV_21.xlsx
# 1043780     1043780  066_Harwinton_MV_21.xlsx
# 1043781     1043781  066_Harwinton_MV_21.xlsx
# 1043782     1043782  066_Harwinton_MV_21.xlsx
# 1043783     1043783  066_Harwinton_MV_21.xlsx
# 1043784     1043784  066_Harwinton_MV_21.xlsx
# 1043785     1043785  066_Harwinton_MV_21.xlsx
# 1043786     1043786  066_Harwinton_MV_21.xlsx
# 1043787     1043787  066_Harwinton_MV_21.xlsx
#
#                                              name  \
# 1043778  .SUPREME INDUSTRIES INC.
# 1043779  .SUPREME INDUSTRIES INC.
# 1043780  362 POST ROAD LLC
# 1043781  ABBAMONDI CYNTHIA J
# 1043782  ABBOTTS JEFFREY C
# 1043783  ABBOTTS JEFFREY C
# 1043784  ABBOTTS JEFFREY C
# 1043785  ABELING CHRISTOPHER L
# 1043786  ABLING-JOSEPHSON CORITA P
# 1043787  ABOU ARRAGE ANDRE
#
#                                  street                            city state  \
# 1043778  216 LOWER BOGUE RD              HARWINTON                         CT
# 1043779  216 LOWER BOGUE RD              HARWINTON                         CT
# 1043780  216 BOGUE RD                    HARWINTON                         CT
# 1043781  30 HITHER LANE                  HARWINTON                         CT
# 1043782  95 WILDCAT HILL RD              HARWINTON                         CT
# 1043783  95 WILDCAT HILL RD              HARWINTON                         CT
# 1043784  95 WILDCAT HILL RD              HARWINTON                         CT
# 1043785  576 MAIN ST                     TORRINGTON                        CT
# 1043786  352 CLEARVIEW AVE               HARWINTON                         CT
# 1043787  34 SAND HILL LN                 GLASTONBURY                       CT
#
#           zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 1043778  6791         2019        CHEVR      SILVERAD             1
# 1043779  6791         2017        CHEVR      SILVERAD             3
# 1043780  6791         2018        TIDEW      TP-22-36            11
# 1043781  6791         2016        VOLVO      XC60 T5              1
# 1043782  6791         1983        FIAT       PININFAR            25
# 1043783  6791         2013        VOLKS      BEETLE T             1
# 1043784  6791         2016        RAM        RAM TRUC             3
# 1043785  6790         2011        HONDA      ELEMENT              1
# 1043786  6791         2012        SUBAR      FORESTER             1
# 1043787  6033         2017        HONDA      ACCORD T             1
#
#                 vehicle_id lease_street  UID lease_city lease_state lease_zip
# 1043778  1GCUYDED3KZ127370          NaN  NaN        NaN         NaN       NaN
# 1043779  1GC1KVEG7HF169684          NaN  NaN        NaN         NaN       NaN
# 1043780  45LBS2219J2100584          NaN  NaN        NaN         NaN       NaN
# 1043781  YV4612RM7G2831290          NaN  NaN        NaN         NaN       NaN
# 1043782  ZFRAS00B3D5503101          NaN  NaN        NaN         NaN       NaN
# 1043783  3VW4A7AT1DM617780          NaN  NaN        NaN         NaN       NaN
# 1043784  3C6JR7DTXGG302349          NaN  NaN        NaN         NaN       NaN
# 1043785  5J6YH2H75BL004405          NaN  NaN        NaN         NaN       NaN
# 1043786  JF2SHADC7CH451624          NaN  NaN        NaN         NaN       NaN
# 1043787  1HGCR3F90HA007645          NaN  NaN        NaN         NaN       NaN
#          Unnamed: 0                 record_from name  \
# 1199237     1199237  079_Marlborough_MV_21.xlsx  NaN
# 1199238     1199238  079_Marlborough_MV_21.xlsx  NaN
# 1199239     1199239  079_Marlborough_MV_21.xlsx  NaN
# 1199240     1199240  079_Marlborough_MV_21.xlsx  NaN
# 1199241     1199241  079_Marlborough_MV_21.xlsx  NaN
# 1199242     1199242  079_Marlborough_MV_21.xlsx  NaN
# 1199243     1199243  079_Marlborough_MV_21.xlsx  NaN
# 1199244     1199244  079_Marlborough_MV_21.xlsx  NaN
# 1199245     1199245  079_Marlborough_MV_21.xlsx  NaN
# 1199246     1199246  079_Marlborough_MV_21.xlsx  NaN
#
#                                  street                            city state  \
# 1199237  32 EAST HAMPTON RD              MARLBOROUGH                       CT
# 1199238  PO BOX 453                      MARLBOROUGH                       CT
# 1199239  PO BOX 453                      MARLBOROUGH                       CT
# 1199240  PO BOX 453                      MARLBOROUGH                       CT
# 1199241  2 AVALON LN                     MARLBOROUGH                       CT
# 1199242  2 AVALON LN                     MARLBOROUGH                       CT
# 1199243  2 AVALON LN                     MARLBOROUGH                       CT
# 1199244  2 AVALON LN                     MARLBOROUGH                       CT
# 1199245  20 CARRIAGE LN                  MARLBOROUGH                       CT
# 1199246  20 APACHE LN                    MARLBOROUGH                       CT
#
#           zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 1199237  6447         2018        TOYOT      4RUNNER              1
# 1199238  6447         1999        FORD       F550 SUP             2
# 1199239  6447         2001        ECONO                          10
# 1199240  6447         2016        CHEVR      SILVERAD             3
# 1199241  6447         2018        PORSC      MACAN                1
# 1199242  6447         2015        AUDI       A4 2.0T              1
# 1199243  6447         2020        DUCAT      DIAVEL 1            12
# 1199244  6447         2018        FORD       F150 RAP             1
# 1199245  6447         2016        NISSA      ROGUE S/             1
# 1199246  6447         2019        HONDA      CR-V EXL             1
#
#                 vehicle_id                    lease_street      UID  \
# 1199237  JTEBU5JR9J5607957  32 EAST HAMPTON RD RT 66        50001.0
# 1199238  1FDAF56F0XEA33195  5 SHERWOOD LANE                 50002.0
# 1199239  42EDPFB2X11001464  5 SHERWOOD LANE                 50003.0
# 1199240  1GC1KUEG4GF278550  5 SHERWOOD LANE                 50004.0
# 1199241  WP1AA2A59JLB15167                                  50005.0
# 1199242  WAUBFBFL2FN040366                                  50006.0
# 1199243  ZDMGAHRW2LB003903                                  50007.0
# 1199244  1FTFW1RG0JFE52897                                  50008.0
# 1199245  KNMAT2MV8GP723352                                  50009.0
# 1199246  5J6RW2H8XKA000252                                  50010.0
#
#                              lease_city lease_state lease_zip
# 1199237  MARLBOROUGH                             CT     06447
# 1199238  MARLBOROUGH                             CT     06447
# 1199239  MARLBOROUGH                             CT     06447
# 1199240  MARLBOROUGH                             CT     06447
# 1199241
# 1199242
# 1199243
# 1199244
# 1199245
# 1199246
#          Unnamed: 0               record_from  \
# 1364806     1364806  086_Montville_MV_21.xlsx
# 1364807     1364807  086_Montville_MV_21.xlsx
# 1364808     1364808  086_Montville_MV_21.xlsx
# 1364809     1364809  086_Montville_MV_21.xlsx
# 1364810     1364810  086_Montville_MV_21.xlsx
# 1364811     1364811  086_Montville_MV_21.xlsx
# 1364812     1364812  086_Montville_MV_21.xlsx
# 1364813     1364813  086_Montville_MV_21.xlsx
# 1364814     1364814  086_Montville_MV_21.xlsx
# 1364815     1364815  086_Montville_MV_21.xlsx
#
#                                              name  \
# 1364806  A & B EXCAVATING L.L.C.
# 1364807  A & B EXCAVATING LLC
# 1364808  A & B EXCAVATING LLC
# 1364809  A & B EXCAVATING LLC
# 1364810  A & B EXCAVATING LLC
# 1364811  A & B TREE SERVICE LLC
# 1364812  A & B TREE SERVICES LLC
# 1364813  A J CABRAL TRUCKING
# 1364814  AANENSEN KENNETH T
# 1364815  AANENSEN KENNETH T JR
#
#                                  street                            city state  \
# 1364806  33 COVE RD                      UNCASVILLE                        CT
# 1364807  33 COVE RD                      UNCASVILLE                        CT
# 1364808  33 COVE RD                      UNCASVILLE                        CT
# 1364809  33 COVE RD                      UNCASVILLE                        CT
# 1364810  33 COVE RD                      UNCASVILLE                        CT
# 1364811  PO BOX 335                      MONTVILLE                         CT
# 1364812  PO BOX 335                      MONTVILLE                         CT
# 1364813  12 BONVILLE DR                  UNCASVILLE                        CT
# 1364814  8 ROBIN LN                      OAKDALE                           CT
# 1364815  8 ROBIN LN                      OAKDALE                           CT
#
#           zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 1364806  6382         1988        INTER      C16                 10
# 1364807  6382         2013        FORD       F550 SUP             2
# 1364808  6382         1997        INTER      4000 SER             2
# 1364809  6382         2005        FORD       F350 SUP             2
# 1364810  6382         1998        MITSU      FE639                2
# 1364811  6353         1996        GMC        TOPKICK              2
# 1364812  6353         2012        INTER      4000 SER             2
# 1364813  6382         1994        KENWO      CONSTRUC             2
# 1364814  6370         2021        NISSA      MURANO P             1
# 1364815  6370         2009        HONDA      PILOT EX             1
#
#                 vehicle_id lease_street  UID lease_city lease_state lease_zip
# 1364806  1ZFCF1622JB003085          NaN  NaN        NaN         NaN       NaN
# 1364807  1FD0W5HT9DEA34887          NaN  NaN        NaN         NaN       NaN
# 1364808  1HTSCAAM2VH424900          NaN  NaN        NaN         NaN       NaN
# 1364809  1FDWX37P75EB40966          NaN  NaN        NaN         NaN       NaN
# 1364810  JW6AAE1H5WL001462          NaN  NaN        NaN         NaN       NaN
# 1364811  1GDL7H1P4TJ512163          NaN  NaN        NaN         NaN       NaN
# 1364812  3HAMMAAM6CL549363          NaN  NaN        NaN         NaN       NaN
# 1364813  2XKDD69X9RM635618          NaN  NaN        NaN         NaN       NaN
# 1364814  5N1AZ2DS3MC136494          NaN  NaN        NaN         NaN       NaN
# 1364815  5FNYF48509B031076          NaN  NaN        NaN         NaN       NaN
#          Unnamed: 0                record_from  \
# 1431120     1431120  090_New_Canaan_MV_21.xlsx
# 1431121     1431121  090_New_Canaan_MV_21.xlsx
# 1431122     1431122  090_New_Canaan_MV_21.xlsx
# 1431123     1431123  090_New_Canaan_MV_21.xlsx
# 1431124     1431124  090_New_Canaan_MV_21.xlsx
# 1431125     1431125  090_New_Canaan_MV_21.xlsx
# 1431126     1431126  090_New_Canaan_MV_21.xlsx
# 1431127     1431127  090_New_Canaan_MV_21.xlsx
# 1431128     1431128  090_New_Canaan_MV_21.xlsx
# 1431129     1431129  090_New_Canaan_MV_21.xlsx
#
#                                              name  \
# 1431120  1330 EAST PUTNAM LLC
# 1431121  1ST RIDE & GO CORP
# 1431122  909 WEST ROAD REVOCABLE LIVING TRUST
# 1431123  A & N PLUMBING AND HEATING LLC
# 1431124  A & N PLUMBING AND HEATING LLC
# 1431125  A M SANTELLA COMPANY INC
# 1431126  A M SANTELLA COMPANY INC
# 1431127  A M SANTELLA COMPANY INC
# 1431128  A SILLO DEVELOPMENT LLC
# 1431129  A SILLO DEVELOPMENT LLC
#
#                                  street                            city state  \
# 1431120  PO BOX 811                      NEW CANAAN                        CT
# 1431121  58 PINE ST                      NEW CANAAN                        CT
# 1431122  909 WEST RD                     NEW CANAAN                        CT
# 1431123  22 DOWN RIVER RD                NEW CANAAN                        CT
# 1431124  22 DOWN RIVER RD                NEW CANAAN                        CT
# 1431125  635 CHEESEPRING RD              NEW CANAAN                        CT
# 1431126  635 CHEESEPRING RD              NEW CANAAN                        CT
# 1431127  635 CHEESEPRING RD              NEW CANAAN                        CT
# 1431128  691 OLD STAMFORD ROAD           NEW CANAAN                        CT
# 1431129  691 OLD STAMFORD ROAD           NEW CANAAN                        CT
#
#             zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 1431120  6840.0       2019.0        CHEVR      EQUINOX            1.0
# 1431121  6840.0       2016.0        FORD       TRANSIT            8.0
# 1431122  6840.0       1996.0        JAGUA      XJR               25.0
# 1431123  6840.0       2007.0        FORD       ECONOLIN           3.0
# 1431124  6840.0       2018.0        RAM        PROMASTE           3.0
# 1431125  6840.0       2015.0        RAM        RAM TRUC           3.0
# 1431126  6840.0       2007.0        ISUZU      NPR                2.0
# 1431127  6840.0       2006.0        CAM        6CAM 18           10.0
# 1431128  6840.0       2012.0        CHEVR      SILVERAD           2.0
# 1431129  6840.0       2020.0        CHEVR      SILVERAD           3.0
#
#                 vehicle_id                    lease_street    UID  \
# 1431120  3GNAXVEX0KS674784  261 ELM ST                      50001
# 1431121  1FBZX2CM2GKA71622                                  50002
# 1431122  SAJPX1143TC781554                                  50003
# 1431123  1FTNE24L07DA36751                                  50004
# 1431124  3C6TRVAG6JE110384                                  50005
# 1431125  3C6MR5AJ2FG524435                                  50006
# 1431126  JALB4W16277400371                                  50007
# 1431127  5JPBU23296P015771                                  50008
# 1431128  1GB3KZCG1CF113627  691 OLD STAMFORD RD             50009
# 1431129  3GCPYFED0LG246956  691 OLD STAMFORD RD             50010
#
#                              lease_city lease_state lease_zip
# 1431120  NEW CANAAN                              CT     06840
# 1431121
# 1431122
# 1431123
# 1431124
# 1431125
# 1431126
# 1431127
# 1431128  NEW CANAAN                              CT     06840
# 1431129  NEW CANAAN                              CT     06840
#          Unnamed: 0                 record_from  \
# 2076515     2076515  131_Southington_MV_21.xlsx
# 2076516     2076516  131_Southington_MV_21.xlsx
# 2076517     2076517  131_Southington_MV_21.xlsx
# 2076518     2076518  131_Southington_MV_21.xlsx
# 2076519     2076519  131_Southington_MV_21.xlsx
# 2076520     2076520  131_Southington_MV_21.xlsx
# 2076521     2076521  131_Southington_MV_21.xlsx
# 2076522     2076522  131_Southington_MV_21.xlsx
# 2076523     2076523  131_Southington_MV_21.xlsx
# 2076524     2076524  131_Southington_MV_21.xlsx
#
#                                         name             street          city  \
# 2076515                         18FORE18 INC  201 PATTONWOOD DR   SOUTHINGTON
# 2076516  3 BROTHERS PROPERTY PRESERVATION SE      461C COOKE ST    FARMINGTON
# 2076517                   A & A SURPLUS INC.     389 MARION AVE   PLANTSVILLE
# 2076518                   A & A SURPLUS INC.     389 MARION AVE   PLANTSVILLE
# 2076519                  A AND A SURPLUS INC     389 MARION AVE   PLANTSVILLE
# 2076520          A AND P KRISHNA CORPORATION   151 QUEEN STREET   SOUTHINGTON
# 2076521            A CUT ABOVE GREENCARE LLC   41 HIGHWOOD AVE.   SOUTHINGTON
# 2076522                      A DUIE PYLE INC         PO BOX 564  WEST CHESTER
# 2076523                      A DUIE PYLE INC         PO BOX 564  WEST CHESTER
# 2076524                      A DUIE PYLE INC         PO BOX 564  WEST CHESTER
#
#         state      zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 2076515    CT   6489.0         2002        USCAR      USCL58SA            11
# 2076516    CT   6032.0         2013         FORD      F350 SUP             3
# 2076517    CT   6479.0         2008        TOYOT      TUNDRA D             3
# 2076518    CT   6479.0         2012        FREIG      M2 106 M             2
# 2076519    CT   6479.0         1999        INTER      4000 SER             2
# 2076520    CT   6489.0         2015        MERCE      SPRINTER             3
# 2076521    CT   6489.0         2017        FREED        6X10SA            10
# 2076522    PA  19381.0         2012         FRHT          CA12             2
# 2076523    PA  19381.0         2012         FRHT          CA12             2
# 2076524    PA  19381.0         2012         FRHT          CA12             2
#
#                 vehicle_id lease_street  UID lease_city lease_state lease_zip
# 2076515  4X4TSE0112X053369          NaN  NaN        NaN         NaN       NaN
# 2076516  1FTRF3B68DEA53496          NaN  NaN        NaN         NaN       NaN
# 2076517  5TBBV54198S491700          NaN  NaN        NaN         NaN       NaN
# 2076518  1FVACXDT5CHBV1762          NaN  NaN        NaN         NaN       NaN
# 2076519  1HTSCAAM3XH688887          NaN  NaN        NaN         NaN       NaN
# 2076520  WD3PF1CC9FP167427          NaN  NaN        NaN         NaN       NaN
# 2076521  5WKBE101XH1045634          NaN  NaN        NaN         NaN       NaN
# 2076522  1FUBGEDV9CLBK5195          NaN  NaN        NaN         NaN       NaN
# 2076523  1FUBGEDV0CLBK5165          NaN  NaN        NaN         NaN       NaN
# 2076524  1FUBGEDV0CLBK5196          NaN  NaN        NaN         NaN       NaN
#          Unnamed: 0               record_from  \
# 2375159     2375159  147_Voluntown_MV_21.xlsx
# 2375160     2375160  147_Voluntown_MV_21.xlsx
# 2375161     2375161  147_Voluntown_MV_21.xlsx
# 2375162     2375162  147_Voluntown_MV_21.xlsx
# 2375163     2375163  147_Voluntown_MV_21.xlsx
# 2375164     2375164  147_Voluntown_MV_21.xlsx
# 2375165     2375165  147_Voluntown_MV_21.xlsx
# 2375166     2375166  147_Voluntown_MV_21.xlsx
# 2375167     2375167  147_Voluntown_MV_21.xlsx
# 2375168     2375168  147_Voluntown_MV_21.xlsx
#
#                                              name  \
# 2375159  A KAUSCH & SONS LLC
# 2375160  ACAR LEASING LTD
# 2375161  ACAR LEASING LTD
# 2375162  ACAR LEASING LTD
# 2375163  ACAR LEASING LTD
# 2375164  ACAR LEASING LTD
# 2375165  ACAR LEASING LTD
# 2375166  ACAR LEASING LTD
# 2375167  ACAR LEASING LTD
# 2375168  ADAMS ANGELA D
#
#                                  street                            city state  \
# 2375159  15 BEACH VIEW ROAD EXT          VOLUNTOWN                         CT
# 2375160  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375161  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375162  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375163  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375164  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375165  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375166  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375167  4001 EMBARCADERO DR             ARLINGTON                         TX
# 2375168  66 TEN ROD RD                   VOLUNTOWN                         CT
#
#            zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 2375159   6384         2006        CHEVR      EXPRESS              2
# 2375160  76014         2019        GMC        ACADIA S             1
# 2375161  76014         2019        CHEVR      EQUINOX              1
# 2375162  76014         2019        CHEVR      SILVERAD             1
# 2375163  76014         2020        CHEVR      SILVERAD             1
# 2375164  76014         2020        CHEVR      SILVERAD             1
# 2375165  76014         2021        CHEVR      SILVERAD             3
# 2375166  76014         2021        GMC        YUKON DE             3
# 2375167  76014         2021        GMC        ACADIA S             1
# 2375168   6384         2014        MERCE      C300 4 M             1
#
#                 vehicle_id lease_street  UID lease_city lease_state lease_zip
# 2375159  1GBJG31U761268117          NaN  NaN        NaN         NaN       NaN
# 2375160  1GKKNULS2KZ110890          NaN  NaN        NaN         NaN       NaN
# 2375161  2GNAXUEV3K6194780          NaN  NaN        NaN         NaN       NaN
# 2375162  1GCRYCEF6KZ368941          NaN  NaN        NaN         NaN       NaN
# 2375163  1GCPYFED7LZ165405          NaN  NaN        NaN         NaN       NaN
# 2375164  1GCRYBEH8LZ271768          NaN  NaN        NaN         NaN       NaN
# 2375165  1GCRYBEH8MZ187550          NaN  NaN        NaN         NaN       NaN
# 2375166  1GKS2DKL1MR127895          NaN  NaN        NaN         NaN       NaN
# 2375167  1GKKNULS2MZ210281          NaN  NaN        NaN         NaN       NaN
# 2375168  WDDGF8AB8EA949962          NaN  NaN        NaN         NaN       NaN
#          Unnamed: 0             record_from                     name  \
# 2691877     2691877  163_Windham_MV_21.xlsx  0 TO 60 MOTORSPORTS LLC
# 2691878     2691878  163_Windham_MV_21.xlsx  A L FIRE PROTECTION LLC
# 2691879     2691879  163_Windham_MV_21.xlsx   A+ PUMPS & SERVICE LLC
# 2691880     2691880  163_Windham_MV_21.xlsx   A+ PUMPS & SERVICE LLC
# 2691881     2691881  163_Windham_MV_21.xlsx   A+ PUMPS & SERVICE LLC
# 2691882     2691882  163_Windham_MV_21.xlsx       AAA DURA GLAZE LLC
# 2691883     2691883  163_Windham_MV_21.xlsx       AAA DURA GLAZE LLC
# 2691884     2691884  163_Windham_MV_21.xlsx       AAA DURA GLAZE LLC
# 2691885     2691885  163_Windham_MV_21.xlsx       AAA DURA GLAZE LLC
# 2691886     2691886  163_Windham_MV_21.xlsx        ABBOTT CARLETON N
#
#                           street           city state   zip vehicle_year  \
# 2691877      114 PINE ORCHARD RD       BRANFORD    CT  6405         1974
# 2691878             45 CHERRY ST  EAST HARTFORD    CT  6108         2008
# 2691879  42 MACHINE SHOP HILL RD  SOUTH WINDHAM    CT  6266         2017
# 2691880  42 MACHINE SHOP HILL RD  SOUTH WINDHAM    CT  6266         2020
# 2691881  42 MACHINE SHOP HILL RD  SOUTH WINDHAM    CT  6266         2021
# 2691882          292 SCOTLAND RD        WINDHAM    CT  6280         2021
# 2691883          292 SCOTLAND RD        WINDHAM    CT  6280         2008
# 2691884          292 SCOTLAND RD        WINDHAM    CT  6280         2008
# 2691885          292 SCOTLAND RD        WINDHAM    CT  6280         2001
# 2691886         143 BOULEVARD RD  NORTH WINDHAM    CT  6256         2008
#
#         vehicle_make vehicle_model vehicle_class         vehicle_id  \
# 2691877        FERRA       365GTB4            25              17993
# 2691878         FORD      ECONOLIN             3  1FTSE34L88DA28181
# 2691879         FORD      F350 SUP             2  1FT8W3DT7HEF28494
# 2691880        BRAVO      SC712TA2            10  542BC1224LB031060
# 2691881        REISE       TRAILER            10  55L1F2028MN008651
# 2691882        VOLKS      ATLAS SE             1  1V2SR2CA8MC548989
# 2691883         FORD          F150             3  1FTRF14V78KC77911
# 2691884         FORD          F150             3  1FTRF12238KB63171
# 2691885        DODGE        DAKOTA             3  1B7FL26X61S310631
# 2691886        MITSU      GALANT E             1  4A3AB36F48E015544
#
#         lease_street  UID lease_city lease_state lease_zip
# 2691877          NaN  NaN        NaN         NaN       NaN
# 2691878          NaN  NaN        NaN         NaN       NaN
# 2691879          NaN  NaN        NaN         NaN       NaN
# 2691880          NaN  NaN        NaN         NaN       NaN
# 2691881          NaN  NaN        NaN         NaN       NaN
# 2691882          NaN  NaN        NaN         NaN       NaN
# 2691883          NaN  NaN        NaN         NaN       NaN
# 2691884          NaN  NaN        NaN         NaN       NaN
# 2691885          NaN  NaN        NaN         NaN       NaN
# 2691886          NaN  NaN        NaN         NaN       NaN

# %% [markdown]
# # Further checks

# %% [markdown]
# The original purpose of recompiling the data was to address issues with missing VINs, missing zip codes, and missing street addresses. below, I confirm that these issues have been addressed.

# %%
recompiled_data = pd.read_csv(raw_path / "2019-21_data_compiled_RN_100323.csv", chunksize = 1000)

# %%
i = 0

missing_df = pd.DataFrame([])

for chunk in recompiled_data:
    
    # Give progress
    if (i % 1000 ==0):
        print(f"Currently on chunk number {i}")
        # display(df)
        
    # Create DF
    # Get the total number for that record_from
    total = chunk.groupby("record_from").count()["Unnamed: 0"].reset_index(name="count")
    
    # Get the number with a missing ZIP
    missing_zips = chunk.groupby("record_from")["zip"].apply(lambda x: x.isna().sum()).reset_index(name = "missing zip")
    
    # Get the number with a missing VIN
    missing_vins = chunk.groupby("record_from")["vehicle_id"].apply(lambda x: x.isna().sum()).reset_index(name = "missing VIN")
    
    # Missing address
    missing_streets = chunk.groupby("record_from")["street"].apply(lambda x: x.isna().sum()).reset_index(name = "missing street")
    
    # Get the number with state not in CT
    state_not_CT = chunk.groupby("record_from")["state"].apply(lambda x: (x!="CT").sum()).reset_index(name ="not CT")
    
    # Merge
    all_columns  = missing_zips.merge(missing_vins,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(missing_streets,
                                   how = 'outer',
                                   left_on = 'record_from',
                                   right_on = 'record_from')
    
    all_columns  = all_columns.merge(state_not_CT,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(total,
                                    how = 'outer',
                                    left_on = 'record_from',
                                    right_on = 'record_from')
    
    
    # Assign this to a DF to save
    missing_df = pd.concat([missing_df, all_columns])
    
    # add to count
    i +=1

missing_df = missing_df.groupby("record_from").sum()
missing_df = missing_df.reset_index()
# Out:
# Currently on chunk number 0
# Currently on chunk number 1000
# Currently on chunk number 2000
# Currently on chunk number 3000
# Currently on chunk number 4000
# Currently on chunk number 5000

# %%
missing_df_new = missing_df.copy(deep = True)

# %%
i = 0

missing_df = pd.DataFrame([])

for chunk in original_data:
    
    # Give progress
    if (i % 1000 ==0):
        print(f"Currently on chunk number {i}")
        # display(df)
        
    # Create DF
    # Get the total number for that record_from
    total = chunk.groupby("record_from").count()["Unnamed: 0"].reset_index(name="count")
    
    # Get the number with a missing ZIP
    missing_zips = chunk.groupby("record_from")["zip"].apply(lambda x: x.isna().sum()).reset_index(name = "missing zip")
    
    # Get the number with a missing VIN
    missing_vins = chunk.groupby("record_from")["vehicle_id"].apply(lambda x: x.isna().sum()).reset_index(name = "missing VIN")
    
    # Missing address
    missing_streets = chunk.groupby("record_from")["street"].apply(lambda x: x.isna().sum()).reset_index(name = "missing street")
    
    # Get the number with state not in CT
    state_not_CT = chunk.groupby("record_from")["state"].apply(lambda x: (x!="CT").sum()).reset_index(name ="not CT")
    
    # Merge
    all_columns  = missing_zips.merge(missing_vins,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(missing_streets,
                                   how = 'outer',
                                   left_on = 'record_from',
                                   right_on = 'record_from')
    
    all_columns  = all_columns.merge(state_not_CT,
                                  how='outer',
                                  left_on = 'record_from',
                                  right_on = 'record_from')
    
    all_columns = all_columns.merge(total,
                                    how = 'outer',
                                    left_on = 'record_from',
                                    right_on = 'record_from')
    
    
    # Assign this to a DF to save
    missing_df = pd.concat([missing_df, all_columns])
    
    # add to count
    i +=1

missing_df = missing_df.groupby("record_from").sum()
missing_df = missing_df.reset_index()
# Out:
# Currently on chunk number 0
# Currently on chunk number 1000
# Currently on chunk number 2000
# Currently on chunk number 3000
# Currently on chunk number 4000
# Currently on chunk number 5000

# %%
missing_df_original = missing_df.copy(deep=True)

# %% [markdown]
# # Check zip codes and towns

# %% [markdown]
# The goal of this analysis is to identify discrepancies in addresses for the vehicles listed. Specifically, we want to know with confidence how to allocate EVs to Connecticut. We also wish to match the addresses to L2 data, requiring that we can confidently link a vehicle with its address. We have three variables we can easily use: **state**, **zip code** and **town name**.
#
# * The taxpayer Town Name and State Name are not in CT, but the zip code is --> Probably outside of CT
#     * Analysis: Get the Town Names for CT, and check the opposite of this
#     * Implications: Will need to look at the addresses. If both the town name and State Name don't belong to CT, then it's likely the address will be outside CT, and we can allocate the entry as being outside CT
# * The taxpayer Town Name and State Name are in CT, but the zip code is not --> Need to look into the address
#     * Analysis: Get the Town Names for CT, and check for these town names and the State Name as CT. For these, find those with non-CT Zip and investigate.
#     * Implications: The ZIP may be wrongly entered, there may be no address, or the address might be outside of CT.
# * The taxpayer Town Name is in CT, but the zip code and state are not --> Need to determine if the town name is duplicated across states

# %% [markdown]
# ## Define required functions

# %%
def check_valid_zip(zip_code):
    zip_str = str(zip_code)
    split_zip = re.split("-", zip_str)
    if len(split_zip) == 2:
        if check_valid_zip(split_zip[0]) & check_valid_zip(split_zip[1]):
            return 2
        elif check_valid_zip(split_zip[0]):
            return 3
        else:
            return 0
    elif len(split_zip) == 1:
        # MUST ADDRESS STARTING "Os"
        # starting_o = re.match('^O', split_zip[0])
        if len(split_zip[0]) < 5:
            matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", split_zip[0])
            if matched:
                return 1
            else:
                return 0
        else:
            split_zip = [split_zip[0][0:5], split_zip[0][5:]]
            if check_valid_zip(split_zip[0]) & check_valid_zip(split_zip[1]):
                return 2
            elif check_valid_zip(split_zip[0]):
                return 3
            else:
                return 0
    else:
        return 0

# %%
def create_valid_zip(zip):
    try:
        zip_str = str(zip)
        zip_str = zip_str.strip()
        has_dot = re.search(r"\.", zip_str)

        # Get rid of decimal places
        if has_dot:
            zip_str = zip_str[0:re.search(r"\.", zip_str).start()]

        split_zip = re.split("-", zip_str)
        
        if len(split_zip) == 2:
            return create_valid_zip(split_zip[0])
        else:
            # If length is less than 4, return na
            if len(zip_str) < 4:
                return np.NaN
                
            # If length is 4 or 5, check it
            elif((len(zip_str) == 5) | (len(zip_str) == 4)):
                matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)
                if matched:
                    return matched[0].zfill(5)
                else:
                    return np.NaN
            # If the zip is between 5 and 8 (inclusive) long, we assume the first 4 are the first part
            # And the second 4 are the second part
            # There is no other way to do this... 
            elif((len(zip_str) > 5) & (len(zip_str)<9)):
                return create_valid_zip(zip_str[0:4])
            elif (len(zip_str) == 9):
                return create_valid_zip(zip_str[0:5])
            else:
                return np.NaN
        
    except Exception as e:
        print(e)
        return np.NaN
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_489777/4245864615.py:22: SyntaxWarning: invalid escape sequence '\s'
#   matched = re.match("^\s*[0-9]*[0-9]{4}\.?0?\s*$", zip_str)

# %%
def get_valid_zips(zip_df, zip_column_name):
    """
    Inputs: A DataFrame with a column called "zip"
    Returns: A DataFrame of the same length as the input, with three columns: zip, zip_valid_code, and zip_corrected
    """
    # Prepare the list to be used
    zip_list = zip_df[[zip_column_name]].rename(columns = {zip_column_name : "zip"}).reset_index(drop = True)

    # Get validity code
    zip_list.loc[:, "zip_valid_code"] = zip_list.loc[:, "zip"].apply(lambda x: check_valid_zip(x))

    # Get indices
    correct_zips_indices = zip_list[zip_list["zip_valid_code"]==1].index
    invalid_zips_indices = zip_list[zip_list["zip_valid_code"]==0].index
    two_part_zips_indices = zip_list[zip_list["zip_valid_code"]>1].index

    zip_list.loc[correct_zips_indices, "zip_corrected"] = zip_list.loc[correct_zips_indices, "zip"]
    zip_list.loc[invalid_zips_indices, "zip_corrected"] = np.NaN
    zip_list.loc[two_part_zips_indices, "zip_corrected"] = zip_list.loc[two_part_zips_indices, "zip"].astype(str).str[0:5]

    return zip_list[["zip_corrected"]]

def convert_vin_valid(vin):
    try:
        vin_str = str(vin)
        if len(vin_str) < 11:
            return "NA"
        if " " in vin_str[0:11]:
            return "NA"
        else:
            return vin_str[0:8]+"*"+vin_str[9:11]
    except:
        return "NA"

def return_matched_vins(chunk_number, df, vin_column, matching_list):
    match = df.merge(matching_list,
                    left_on = vin_column,
                    right_on = vin_column,
                    how = 'left')
    
    # Get rows of DF where VINS matched
    df_vins_matched = match.loc[match["Manufacturer Name"].notna(), :]
    df_vins_unmatched = match.loc[match["Manufacturer Name"].isna(), :]
    
    # Get length
    len_matched = len(df_vins_matched)
    len_unmatched = len(df_vins_unmatched)
    len_all = len(match)
    
    # Create df
    tally_dict = {"Chunk Number": [chunk_number],
                  "Matched" : [len_matched],
                  "Unmatched" : [len_unmatched],
                  "All" : [len_all]}
    
    match_unmatched_tally = pd.DataFrame(tally_dict)

    return [match, match_unmatched_tally]

def ct_zip(zip):
    try:
        zip_str = str(int(zip)).zfill(5)
        if zip_str[0:2] == "06":
            return True
        else:
            return False
    except:
        return False

# %% [markdown]
# # Find CT zips with non-CT addresses

# %%
recompiled_data = reset_recompiled_data()

# %%
ct_zip_nonct_state = pd.DataFrame()
nonct_zip_ct_state = pd.DataFrame()

i = 0

for chunk in tqdm(recompiled_data):
    # Clean up
    chunk = chunk.drop("Unnamed: 0", axis = 1).reset_index(drop = True)
    
    # Check that the ZIPs and the states match
    chunk_corrected_zips = chunk
    chunk_corrected_zips["zip_corrected"] = chunk_corrected_zips["zip"].apply(lambda x: create_valid_zip(x))
    # get_valid_zips(chunk, "zip")
    # Join them
    #chunk_corrected_zips = chunk.join(valid_zips).reset_index(drop = True)
    
    # Get CT zip codes
    ct_zip_mask = chunk_corrected_zips["zip_corrected"].apply(lambda x: ct_zip(x))
    ct_state_mask = chunk_corrected_zips["state"] == "CT"
    ct_zip_nonct_state_mask = ~ct_state_mask & ct_zip_mask
    nonct_zip_ct_state_mask = ~ct_zip_mask & ct_state_mask
    
    # Get ct zip nonct state
    ct_zip_nonct_state_chunk = chunk_corrected_zips.loc[ct_zip_nonct_state_mask]
    ct_zip_nonct_state_chunk = ct_zip_nonct_state_chunk.dropna(axis = 0, subset = ["zip_corrected"])
    ct_zip_nonct_state = pd.concat([ct_zip_nonct_state, ct_zip_nonct_state_chunk])

    # Get non CT zip ct state
    nonct_zip_ct_state_chunk = chunk_corrected_zips.loc[nonct_zip_ct_state_mask]
    nonct_zip_ct_state_chunk = nonct_zip_ct_state_chunk.dropna(axis = 0, subset = ["zip_corrected"])
    nonct_zip_ct_state = pd.concat([nonct_zip_ct_state, nonct_zip_ct_state_chunk])
# Out:
# 5788it [01:24, 68.59it/s]

# %%
nonct_zip_ct_state
# Out:
#                        record_from                                      name  \
# 133         003_Ashford_MV_21.xlsx  COSTELLO MARY L
# 354         003_Ashford_MV_21.xlsx  JOHNS DANIEL B
# 719         003_Ashford_MV_21.xlsx  PLATT VICKI H
# 723         003_Ashford_MV_21.xlsx  WEIDIG RANDALL A
# 757         003_Ashford_MV_21.xlsx  WHITE-INGALLS PATRICIA A
# ..                             ...                                       ...
# 993     84_Milford_MVData_2020.csv                         KJR ENTERPRISE CO
# 714      85_Monroe_MVData_2020.csv  DAUTRICH STEVEN E
# 698   88_Naugatuck_MVData_2020.csv  CHARNEY SEAN
# 723  89_NewBritain_MVData_2020.csv  BABALOLA OLUWAGBENGA S
# 978  95_NewMilford_MVData_2020.csv                         KJR ENTERPRISE CO
#
#                              street                            city state  \
# 133  46 CHERRY VALLEY RD             COLUMBIA                          CT
# 354  5888 FOX ST                     HARRISBURG                        CT
# 719  5813 ROVER DR                   JACKSONVILLE                      CT
# 723  PO BOX 204                      STAFFORD SPRINGS                  CT
# 757  777 WESTFORD RD                 ASHFORD                           CT
# ..                              ...                             ...   ...
# 993                   15 RESEACH DR                         MILFORD    CT
# 714  PO BOX 1366                     NORTH CONWAY                      CT
# 698  433 CURTISS ST                  SOUTHINGTON                       CT
# 723  1 CUNNINGHAM SQ                 RHODE ISLAND                      CT
# 978                   15 RESEACH DR                         MILFORD    CT
#
#        zip  vehicle_year vehicle_make vehicle_model  vehicle_class  \
# 133   3237        2018.0        SUBAR      LEGACY 2            1.0
# 354  17112        2017.0        HYUND      ELANTRA             1.0
# 719  32244        2012.0        HYUND      ACCENT G            1.0
# 723  60768        2011.0        HM         HM                 11.0
# 757   3278        2013.0        VOLKS      JETTA S/            1.0
# ..     ...           ...          ...           ...            ...
# 993   8900        1995.0         FORD       F SUPER           70.0
# 714  13860        2006.0        PATRI      PAC8524T           11.0
# 698  16489        2015.0        BELMO      SS101614           11.0
# 723   2918        2010.0        HONDA      ACCORD L            1.0
# 978   8900        1995.0         FORD       F SUPER           70.0
#
#             vehicle_id lease_street     UID lease_city lease_state lease_zip  \
# 133  4S3BNAF6XJ3016489          NaN     NaN        NaN         NaN       NaN
# 354  KMHD04LB0HU355868          NaN     NaN        NaN         NaN       NaN
# 719  KMHCU4AE5CU072890          NaN     NaN        NaN         NaN       NaN
# 723  CTTRL22087                 NaN     NaN        NaN         NaN       NaN
# 757  3VWPP7AJXDM696585          NaN     NaN        NaN         NaN       NaN
# ..                 ...          ...     ...        ...         ...       ...
# 993  1FDLF47G8SEA22495          NaN     NaN        NaN         NaN       NaN
# 714  5NHUPAZ236W024707          NaN     NaN        NaN         NaN       NaN
# 698  1B9UT1421FL657608          NaN     NaN        NaN         NaN       NaN
# 723  1HGCP2F41AA022438          NaN  302536        NaN         NaN       NaN
# 978  1FDLF47G8SEA22495          NaN     NaN        NaN         NaN       NaN
#
#     zip_corrected
# 133         03237
# 354         17112
# 719         32244
# 723         60768
# 757         03278
# ..            ...
# 993         08900
# 714         13860
# 698         16489
# 723         02918
# 978         08900
#
# [761 rows x 17 columns]

# %%
ct_zip_nonct_state.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / "ct_zip_nonct_state.csv")
nonct_zip_ct_state.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / "nonct_zip_ct_state.csv")

# %%
old = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "non_matching_zips_states.csv")
# Out:
# /tmp/ipykernel_489777/904515573.py:1: DtypeWarning: Columns (12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   old = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "non_matching_zips_states.csv")

# %%
print(f"These errors come from {old["record_from"].nunique()} underlying files")
# Out:
# These errors come from 111 underlying files

# %%
old[old["state"]!="NY"].reset_index().head(40)
# Out:
#     index  Unnamed: 0                   record_from  \
# 0       0           0         009_Bethel_MV_21.xlsx
# 1       1           1         009_Bethel_MV_21.xlsx
# 2       4           4       014_Branford_MV_21.xlsx
# 3       7           7     015_Bridgeport_MV_21.xlsx
# 4       8           8     015_Bridgeport_MV_21.xlsx
# 5       9           9     015_Bridgeport_MV_21.xlsx
# 6      10          10     015_Bridgeport_MV_21.xlsx
# 7      11          11     015_Bridgeport_MV_21.xlsx
# 8      13          13     015_Bridgeport_MV_21.xlsx
# 9      14          14     015_Bridgeport_MV_21.xlsx
# 10     16          16        017_Bristol_MV_21.xlsx
# 11     17          17        017_Bristol_MV_21.xlsx
# 12     18          18        017_Bristol_MV_21.xlsx
# 13     19          19        017_Bristol_MV_21.xlsx
# 14     20          20     018_Brookfield_MV_21.xlsx
# 15     21          21     018_Brookfield_MV_21.xlsx
# 16     22          22     018_Brookfield_MV_21.xlsx
# 17     23          23         023_Canton_MV_21.xlsx
# 18     24          24         023_Canton_MV_21.xlsx
# 19     25          25       025_Cheshire_MV_21.xlsx
# 20     26          26       025_Cheshire_MV_21.xlsx
# 21     27          27       025_Cheshire_MV_21.xlsx
# 22     29          29       031_Cornwall_MV_21.xlsx
# 23     31          31        034_Danbury_MV_21.xlsx
# 24     32          32        034_Danbury_MV_21.xlsx
# 25     34          34        034_Danbury_MV_21.xlsx
# 26     35          35        034_Danbury_MV_21.xlsx
# 27     36          36        034_Danbury_MV_21.xlsx
# 28     37          37        034_Danbury_MV_21.xlsx
# 29     38          38        034_Danbury_MV_21.xlsx
# 30     39          39        034_Danbury_MV_21.xlsx
# 31     41          41        034_Danbury_MV_21.xlsx
# 32     43          43        034_Danbury_MV_21.xlsx
# 33     44          44        034_Danbury_MV_21.xlsx
# 34     45          45     036_Deep_River_MV_21.xlsx
# 35     46          46         038_Durham_MV_21.xlsx
# 36     47          47         038_Durham_MV_21.xlsx
# 37     48          48         038_Durham_MV_21.xlsx
# 38     49          49         038_Durham_MV_21.xlsx
# 39     50          50  043_East_Hartford_MV_21.xlsX
#
#                                         name                          street  \
# 0   FLYNN TAYLOR D                            28 SIMEON RD UNIT 16D
# 1   MENDIETA MENDIETA GERMANIA I              6 DRUMMER LN
# 2   CONNER FREDERICK J JR                     19 TERHUNE AVE 1ST
# 3   DUMAS RASHAAN                             838 CLARK ST
# 4   LUGO-BALOIS JESUS A                       368 BIRMINGHAM ST
# 5   LUGO-BALOIS JESUS A                       368 BIRMINGHAM ST
# 6   PARK CITY WIRELESS LLC                    2418 MAIN STREET
# 7   PARK CITY WIRELESS LLC                    2418 MAIN STREET
# 8   SILVA MADSON C                            40 GREENWOOD ST
# 9   TIFFANY CLEANING LLC                      350 GROVERS AVE 10-C
# 10  GARGANO JEFFREY H                         65 LAKE AVE APT 29
# 11  PRESTO BONNIE L                           31 SLIPTOWN RD
# 12  PRESTO FRANK L                            31 SLIPTOWN RD
# 13  TEMPLE CHRISTOPHER M                      12941 N FOX FOLLOW DR
# 14  MARIANO FRANK D                           1770 BEN FRANKLIN DR UNIT 702
# 15  ORDONEZ-VILLAVICENCIO SALVADOR E          11 OLD TURNPIKE RD
# 16  ORDONEZ-VILLAVICENCIO SALVADOR E          11 OLD TURNPIKE RD
# 17  CARROLL MARY P                            16 MOHAWK DR
# 18  JAEGER JOSEPH C                           6 COLLINS VIEW RD
# 19  SERVICE FIRST MERCHANDISING INC.          693 DOGWOOD DR
# 20  SERVICE FIRST MERCHANDISING INC.          693 DOGWOOD DR
# 21  SERVICE FIRST MERCHANDISING INC.          693 DOGWOOD DR
# 22                               STONE SUSAN                      PO BOX 247
# 23  ADAMS JILL L                              6 CEDAR CREST DR
# 24  ALVES PRISCILA M                          8 TOWER PL APT A
# 25  DOS SANTOS ROCHA IRENE                    257 MAIN ST
# 26  EHRHARD JOSEPH A                          30 STONE ST
# 27  EHRHARD JOSEPH A                          30 STONE ST
# 28  EHRHARD JOSEPH A                          30 STONE ST
# 29  LEO & SON GARDENS LLC                     155 WESTVILLE AVE EXT
# 30  LEO & SON GARDENS LLC                     155 WESTVILLE AVE EXT
# 31  PERALTA CLEANING LLC                      16 MCDERMOTT STREET APT 1
# 32  SHYMIDT GENERAL CLEANING LLC              5 BELMONT CIR FL 3
# 33  UGUNA-CHIMBO JOSE B                       82 LAKE AVE APT 2
# 34  DUBE JOHN P                               79 WOODLAND RD
# 35  VIZARD ANNYTA K                           PO BOX 115
# 36  WARDWELL ROBERT H                         152 DAISY LN
# 37  WARDWELL ROBERT H                         152 DAISY LN
# 38  WARDWELL ROBERT H                         152 DAISY LN
# 39  JULIANO MARK J                            7410 CLAYTON ST
#
#                               city state     zip  vehicle_year vehicle_make  \
# 0   BETHEL                            DC  6801.0        2021.0        SUBAR
# 1   BETHEL                            WA  6801.0        2008.0        HONDA
# 2   BRANFORD                          CO  6405.0        1993.0        DODGE
# 3   BRIDGEPORT                        NJ  6606.0        2006.0        NISSA
# 4   BRIDGEPORT                        MD  6606.0        1998.0        TOYOT
# 5   BRIDGEPORT                        MD  6606.0        2011.0        HONDA
# 6   BRIDGEPORT                        OT  6606.0        2009.0        TOYOT
# 7   BRIDGEPORT                        OT  6606.0        2021.0        TESLA
# 8   BRIDGEPORT                        MA  6606.0        2014.0        TOYOT
# 9   BRIDGEPORT                        OT  6605.0        2016.0        DODGE
# 10  BRISTOL                           FL  6010.0        2019.0        FORD
# 11  SHARON                            NH  6010.0        2016.0        SUBAR
# 12  SHARON                            NH  6010.0        2012.0        BMW
# 13  MARANA                            AZ  6010.0        2014.0        CHEVR
# 14  SARASOTA                          FL  6804.0        2002.0        CHEVR
# 15  BROOKFIELD                            6804.0        2017.0        HONDA
# 16  BROOKFIELD                            6804.0        2006.0        LEXUS
# 17  CANTON                            CA  6019.0        2017.0        VOLVO
# 18  COLLINSVILLE                      MA  6019.0        2013.0        HONDA
# 19  CHESHIRE                          OT  6410.0        2010.0        CHEVR
# 20  CHESHIRE                          OT  6410.0        2014.0        CHEVR
# 21  CHESHIRE                          OT  6410.0        2004.0        CHEVR
# 22                        CORNWALL    AL  6753.0        2018.0        PORSC
# 23  DANBURY                           CA  6811.0        2017.0        NISSA
# 24  DANBURY                           MD  6810.0        2016.0        HONDA
# 25  DANBURY                           WA  6810.0        2018.0        NISSA
# 26  DANBURY                           TX  6810.0        2003.0        FORD
# 27  DANBURY                           TX  6810.0        2007.0        VOLKS
# 28  DANBURY                           TX  6810.0        2016.0        HONDA
# 29  DANBURY                           OT  6811.0        2021.0        ISUZU
# 30  DANBURY                           OT  6811.0        2005.0        NISSA
# 31  DANBURY                           OT  6810.0        2003.0        NISSA
# 32  DANBURY                           OT  6810.0        2001.0        HONDA
# 33  DANBURY                           OR  6810.0        1998.0        HONDA
# 34  CARIBOU                           ME  6417.0        2019.0        PACE
# 35  DURHAM                            CM  6422.0        2018.0        TOYOT
# 36  DURHAM                            HI  6422.0        2004.0        MAZDA
# 37  DURHAM                            HI  6422.0        2004.0        MAZDA
# 38  DURHAM                            HI  6422.0        2014.0        MAZDA
# 39  ENGLEWOOD                         FL  6108.0        2010.0        NISSA
#
#    vehicle_model  vehicle_class         vehicle_id  \
# 0            NaN            1.0  JF2GTHMC3M8281048
# 1            NaN            1.0  JHMGD37488S002641
# 2       D-250               3.0  1B7JE26YXPS265330
# 3       MURANO S            1.0  JN8AZ08W16W535318
# 4       SIENNA L            1.0  4T3ZF13C5WU019942
# 5       CIVIC LX            1.0  2HGFA1F5XBH303769
# 6       CAMRY HY            1.0  4T1BB46K09U068660
# 7       MODEL Y             1.0  5YJYGDEE0MF070602
# 8       VENZA LE            1.0  4T3BA3BB6EU050331
# 9       GRAND CA            3.0  2C4RDGBG9GR107952
# 10      ESCAPE S            NaN  1FMCU9GD2KUA06694
# 11      FORESTER            NaN  JF2SJADC3GH448701
# 12      328XI SU            NaN  WBAKF5C57CE657300
# 13      CRUZE LT            NaN  1G1PC5SB6E7281536
# 14      S10                 3.0  1GCDT13W22K147314
# 15      PILOT TO            1.0  5FNYF6H96HB000993
# 16      IS250 AW            1.0  JTHCK262365005764
# 17      S60 DYNA            1.0  YV140MTL8H2433994
# 18      CR-V EX-            1.0  2HKRM4H77DH666558
# 19      HHR LS              3.0  3GNBAADB2AS618946
# 20      EQUINOX             3.0  2GNALAEK6E6105434
# 21      BLAZER              3.0  1GNDT13X84K165089
# 22       CAYENNE            1.0  WP1AC2A29JLA85037
# 23      MURANO S            1.0  5N1AZ2MH9HN125868
# 24      CR-V SE             1.0  2HKRM4H46GH651740
# 25      ROGUE S             1.0  KNMAT2MVXJP537769
# 26      EXPLORER            1.0  1FMZU74K33UC42807
# 27      NEW BEET            1.0  3VWRF31Y67M412651
# 28      CR-V EX-            1.0  5J6RM4H75GL107374
# 29      NQR                 2.0  JALE5J160M7900912
# 30      UD1800CS            2.0  JNAMC50H25AD50152
# 31      XTERRA X            1.0  5N1ED28Y63C683935
# 32      CR-V EX             1.0  JHLRD18631C041395
# 33      ACCORD L            1.0  1HGCG5641WA177418
# 34      AAST85X1           11.0  53BPTEA18KA048550
# 35      SIENNA L            1.0  5TDKZ3DC8JS958855
# 36      MIATA/LS            1.0  JM1NB353840400124
# 37      MAZDA3S             1.0  JM1BK323141182707
# 38      CX-5 TOU            1.0  JM3KE4CY6E0366126
# 39      MURANO S            1.0  JN8AZ1MW4AW137122
#
#                       lease_street      UID                      lease_city  \
# 0                                       NaN                             NaN
# 1   6 DRUMMERS LN                       NaN                             NaN
# 2                                   55273.0
# 3                              NaN      NaN                             NaN
# 4                              NaN      NaN                             NaN
# 5                              NaN      NaN                             NaN
# 6                              NaN      NaN                             NaN
# 7                              NaN      NaN                             NaN
# 8                              NaN      NaN                             NaN
# 9                              NaN      NaN                             NaN
# 10                             NaN      NaN                             NaN
# 11                             NaN      NaN                             NaN
# 12                             NaN      NaN                             NaN
# 13                             NaN      NaN                             NaN
# 14  24 PRITTEN HILL RD                  NaN  BROOKFIELD
# 15                                      NaN
# 16                                      NaN
# 17                             NaN      NaN                             NaN
# 18                             NaN      NaN                             NaN
# 19                             NaN      NaN                             NaN
# 20                             NaN      NaN                             NaN
# 21                             NaN      NaN                             NaN
# 22                             NaN      NaN                             NaN
# 23                             NaN      NaN                             NaN
# 24                             NaN      NaN                             NaN
# 25                             NaN      NaN                             NaN
# 26                             NaN      NaN                             NaN
# 27                             NaN      NaN                             NaN
# 28                             NaN      NaN                             NaN
# 29                             NaN      NaN                             NaN
# 30                             NaN      NaN                             NaN
# 31                             NaN      NaN                             NaN
# 32                             NaN      NaN                             NaN
# 33                             NaN      NaN                             NaN
# 34                             NaN      NaN                             NaN
# 35                             NaN      NaN                             NaN
# 36                             NaN      NaN                             NaN
# 37                             NaN      NaN                             NaN
# 38                             NaN      NaN                             NaN
# 39                             NaN      NaN                             NaN
#
#    lease_state lease_zip  zip_corrected
# 0          NaN       NaN         6801.0
# 1          NaN       NaN         6801.0
# 2                                6405.0
# 3          NaN       NaN         6606.0
# 4          NaN       NaN         6606.0
# 5          NaN       NaN         6606.0
# 6          NaN       NaN         6606.0
# 7          NaN       NaN         6606.0
# 8          NaN       NaN         6606.0
# 9          NaN       NaN         6605.0
# 10         NaN       NaN         6010.0
# 11         NaN       NaN         6010.0
# 12         NaN       NaN         6010.0
# 13         NaN       NaN         6010.0
# 14          CT     06804         6804.0
# 15                               6804.0
# 16                               6804.0
# 17         NaN       NaN         6019.0
# 18         NaN       NaN         6019.0
# 19         NaN       NaN         6410.0
# 20         NaN       NaN         6410.0
# 21         NaN       NaN         6410.0
# 22         NaN       NaN         6753.0
# 23         NaN       NaN         6811.0
# 24         NaN       NaN         6810.0
# 25         NaN       NaN         6810.0
# 26         NaN       NaN         6810.0
# 27         NaN       NaN         6810.0
# 28         NaN       NaN         6810.0
# 29         NaN       NaN         6811.0
# 30         NaN       NaN         6811.0
# 31         NaN       NaN         6810.0
# 32         NaN       NaN         6810.0
# 33         NaN       NaN         6810.0
# 34         NaN       NaN         6417.0
# 35         NaN       NaN         6422.0
# 36         NaN       NaN         6422.0
# 37         NaN       NaN         6422.0
# 38         NaN       NaN         6422.0
# 39         NaN       NaN         6108.0

# %% [markdown]
# * There appear to be a few kinds of errors:
#     * **CT ZIP, Non CT Address:**
#         * E.g. "31 SLIPTOWN RD" / "SHARON" / "NH" / 6010 (31 Sliptown Rd. is a real address in New Hampshire)
#         * "12941 N Fox Hollow Dr" / "MARANA" / "AZ" (Real address, but wrong ZIP code"
#         * Note that in both of the above instances from 017_Brisol_MV_21 - the underlying file provides no further information on how to parse this information.
#         * 79 WOODLAND RD CARIBOU ME 6417 - Not a CT address, CT Zip code. The Deep River underlying file provides no way to fix this.
#     * **Erroneous CT Addresses**
#         * E.g. 693 DOGWOOD DR CHESHIRE OT --> Probably means "CT," this is a real address
#         * E.g. 152 DAISY LN DURHAM HI 6422 --> 152 Daisy Lane is a CT address. Perhaps "CT" was written wrong?

# %% [markdown]
# ## Investigate CT ZIPs non CT state

# %%
print(f"Of the {len(ct_zip_nonct_state)} rows, {ct_zip_nonct_state["state"].isna().sum()} are NA for state")
print(f"These are from the following records: {'\n'.join(ct_zip_nonct_state[ct_zip_nonct_state["state"].isna()]["record_from"].unique().tolist())}")
# Out:
# Of the 66090 rows, 65713 are NA for state
# These are from the following records: 099_North_Branford_MV_21.xlsx
# 127_Sherman_MV_21.xlsx
# 127_Sherman_MVData_2020.csv
# 22_Canterbury_MVData_2019.csv
# 4_Avon_MVData_2020.csv
# 96_Newington_MVData_2020.csv

# %%
ct_zip_nonct_state[ct_zip_nonct_state["state"].notna()]
# Out:
#                        record_from                                      name  \
# 618          009_Bethel_MV_21.xlsx  FLYNN TAYLOR D
# 768          009_Bethel_MV_21.xlsx  MENDIETA MENDIETA GERMANIA I
# 753          009_Bethel_MV_21.xlsx  SHERWOOD BROOKE E
# 330      011_Bloomfield_MV_21.xlsx  FURSE ELIZABETH W
# 702        014_Branford_MV_21.xlsx  CONNER FREDERICK J JR
# ..                             ...                                       ...
# 830    93_NewHaven_MVData_2019.csv                           NOERAND MARIE M
# 831    93_NewHaven_MVData_2019.csv                           NOERAND MARIE M
# 773  95_NewMilford_MVData_2020.csv                           WILSON KEISHA L
# 309       9_Bethel_MVData_2020.csv  MENDIETA MENDIETA GERMANIA I
# 766       9_Bethel_MVData_2020.csv  RAMON WALTER A
#
#                              street                            city state  \
# 618  28 SIMEON RD UNIT 16D           BETHEL                            DC
# 768  6 DRUMMER LN                    BETHEL                            WA
# 753  20 HUDSON ST UNIT 14            BETHEL                            NY
# 330  2412 PENINSULA 107              FISHERS ISLE                      NY
# 702  19 TERHUNE AVE 1ST              BRANFORD                          CO
# ..                              ...                             ...   ...
# 830    210 BLATCCHLEY AVE 1ST FLOOR                       NEW HAVEN    NY
# 831    210 BLATCCHLEY AVE 1ST FLOOR                       NEW HAVEN    NY
# 773           75 MILFORD AVE APT 2G                         MILFORD    NY
# 309  6 DRUMMER LN                    BETHEL                            WA
# 766  73-51 71 ST                     GLENDALE                          OA
#
#         zip vehicle_year vehicle_make vehicle_model vehicle_class  \
# 618    6801       2021.0        SUBAR           NaN           1.0
# 768    6801       2008.0        HONDA           NaN           1.0
# 753    6801       2002.0        HONDA           NaN           1.0
# 330    6390       2016.0        BMW        X3 XDRIV           1.0
# 702    6405       1993.0        DODGE      D-250              3.0
# ..      ...          ...          ...           ...           ...
# 830  6513.0         2004        TOYOT      SIENNA C             1
# 831  6513.0         2007          KIA       SPECTRA             1
# 773    6460         2016        TOYOT      CAMRY LE             1
# 309    6801         2008        HONDA      FIT                  1
# 766    6801         2010        FORD       FUSION S             1
#
#             vehicle_id                    lease_street      UID  \
# 618  JF2GTHMC3M8281048                                      NaN
# 768  JHMGD37488S002641  6 DRUMMERS LN                       NaN
# 753  1HGEM22962L090002  3 KYLE CT                           NaN
# 330  5UXWX9C57G0D89216                             NaN      NaN
# 702  1B7JE26YXPS265330                                  55273.0
# ..                 ...                             ...      ...
# 830  5TDZA23C14S066954                             NaN    88723
# 831  KNAFE122875452949                             NaN    88724
# 773  4T4BF1FK4GR532006                             NaN      NaN
# 309  JHMGD37488S002641                             NaN      NaN
# 766  3FAHP0HA5AR109363                             NaN      NaN
#
#                          lease_city lease_state lease_zip zip_corrected
# 618                             NaN         NaN       NaN         06801
# 768                             NaN         NaN       NaN         06801
# 753                             NaN         NaN       NaN         06801
# 330                             NaN         NaN       NaN         06390
# 702                                                               06405
# ..                              ...         ...       ...           ...
# 830                             NaN         NaN       NaN         06513
# 831                             NaN         NaN       NaN         06513
# 773                             NaN         NaN       NaN         06460
# 309                             NaN         NaN       NaN         06801
# 766                             NaN         NaN       NaN         06801
#
# [377 rows x 17 columns]

# %% [markdown]
# Note: import appears to be an error - Bethel file has 06801

# %%
ct_zip_nonct_state[ct_zip_nonct_state["state"].notna()]["zip"].unique()
# Out:
# array([6801, 6390, 6405, 6604, 6606, 6605, 6010, 6804, '06013', 6019,
#        6410, '06415-', 6796, 6753, 6810, '06416', 6811, 6417, 6422, 6108,
#        6016, 6029, 6080, 6082, 6426, 6825, 6824, 6032, 6543, 6831, 6830,
#        6351, 6340, 6437.0, 6441, 6576, 6516, 6518, 6112, 6118, 6114, 6757,
#        '06335', '06234', '06390-0536', '06040', '06042', 6450.0, 6416.0,
#        6457.0, 6460, 6468, 6782, 6370, 6053, 6052, 6051, 6770, 6840, 6057,
#        6111, 6492, 6515, 6519, 6512, 6513, 6511, 6093, 6026, '06390',
#        '06320', '06755', 6776, 6470, 6482, 6473, '6473', 6359,
#        '06854     ', '06851     ', '06855     ', 6360, 6371, 6475, 6478,
#        6239, 6062, '06060', 6259, 6712, '06712', 6751, 6260, 6015, 6483,
#        6484, 6092, 6081, 6844, 6489.0, 6902, '06905', 6906, 6907, 6855,
#        6905, 6708, 6379, 6378, 6078, '06705', '06708', '06704', 6375,
#        6498, 6119, 6117, '06883', 6880, 6109, '06279', 6897, 6095, 6716,
#        6525, 6074, 6903, 6901, 6904, 6883.0, 6066, 6882, 6401.0, 6021,
#        6033, 6514, 6234, '6042-    ', 6250, '6450'], dtype=object)

# %%
ct_zip_nonct_state[ct_zip_nonct_state["state"].notna()].groupby("record_from").count()[["vehicle_id"]].sort_values("vehicle_id", ascending=False)
# Out:
#                                  vehicle_id
# record_from
# 135_Stamford_MV_21.xlsx                  16
# 034_Danbury_MV_21.xlsx                   14
# 105_Old_Lyme_MV_21.xlsx                  13
# 093_New_Haven_MV_21.xlsx                 12
# 105_Old_Lyme_MVData_2019.csv             11
# ...                                     ...
# 84_Milford_MVData_2020.csv                1
# 011_Bloomfield_MV_21.xlsx                 1
# 102_North_Stonington_MV_21.xlsx           1
# 104_Norwich_MV_21.xlsx                    1
# 124_Seymour_MV_21.csv                     0
#
# [117 rows x 1 columns]

# %% [markdown]
# ### Investigate Non CT ZIPS CT state

# %%
print(f"This error is present in {nonct_zip_ct_state["record_from"].nunique()} underlying files, suggesting it is generalized")
# Out:
# This error is present in 125 underlying files, suggesting it is generalized

# %%
nonct_zip_ct_state.groupby("record_from").count()[["vehicle_id"]].sort_values("vehicle_id", ascending=False)
# Out:
#                                vehicle_id
# record_from
# 103_Norwalk_MV_21.xlsx                491
# 135_Stamford_MVData_2020.csv           13
# 135_Stamford_MV_21.xlsx                12
# 111_Plymouth_MV_21.xlsx                12
# 034_Danbury_MV_21.xlsx                  7
# ...                                   ...
# 89_NewBritain_MVData_2020.csv           1
# 009_Bethel_MV_21.xlsx                   1
# 011_Bloomfield_MV_21.xlsx               1
# 015_Bridgeport_MV_21.xlsx               1
# 104_Norwich_MVData_2020.csv             1
#
# [125 rows x 1 columns]

# %%
nonct_zip_ct_state[nonct_zip_ct_state["record_from"].str.contains("Norwalk")]
# Out:
#                      record_from  \
# 974       103_Norwalk_MV_21.xlsx
# 975       103_Norwalk_MV_21.xlsx
# 977       103_Norwalk_MV_21.xlsx
# 978       103_Norwalk_MV_21.xlsx
# 979       103_Norwalk_MV_21.xlsx
# ..                           ...
# 671       103_Norwalk_MV_21.xlsx
# 606  103_Norwalk_MVData_2020.csv
# 737  103_Norwalk_MVData_2020.csv
# 219  103_Norwalk_MVData_2020.csv
# 636  103_Norwalk_MVData_2020.csv
#
#                                                   name  \
# 974  HEIDEMANN BEVERLY                             ...
# 975  MANDUJANO JAIME                               ...
# 977  SON YOUNG SANG                                ...
# 978  STEWARD WILLIAM C                             ...
# 979  REED MICHAEL E                                ...
# ..                                                 ...
# 671                       NORTH GREENY LANDSCAPING LLC
# 606  JONES LYNNELLE                                ...
# 737  FUSCO AL A                                    ...
# 219  JOHNS AUTO CENTER INC                         ...
# 636  BROWNING AMY C                                ...
#
#                                                 street                  city  \
# 974  146 W ROCKS RD                                ...  NORWALK
# 975  58 N TAYLOR AVE                               ...  NORWALK
# 977  198 ELY AVE                                   ...  NORWALK
# 978  13 SYCAMORE ST                                ...  NORWALK
# 979  146 PONUS AVE                                 ...  NORWALK
# ..                                                 ...                   ...
# 671                                     4 TERRY LN # 4               NORWALK
# 606  10 POINT RD WILSON PT                         ...  NORWALK
# 737  10 ROBIN SQ                                   ...  NORWALK
# 219  161 CONN AVE                                  ...  NORWALK
# 636  5 5 LONGSHORE AVE                             ...  NORWALK
#
#     state         zip  vehicle_year                    vehicle_make  \
# 974    CT  68512-232         2011.0  YAKIM
# 975    CT  68541-410         1977.0  HOLSC
# 977    CT  68544-229         2011.0  CHANGZHOU NANXIASHU
# 978    CT  68552-003         2007.0  LOADR
# 979    CT  68501-832         2006.0  LOADR
# ..    ...         ...           ...                             ...
# 671    CT  68544-304         2005.0                           CHEVR
# 606    CT  00000             1991.0  MERCEDES-BENZ
# 737    CT  00000             1978.0  HOMEM
# 219    CT  00000             1978.0  CHEVROLET
# 636    CT  00000             2019.0  VOLVO
#
#                       vehicle_model  vehicle_class            vehicle_id  \
# 974  VINS                                     11.0  510SF1114BN009217
# 975  2000                                     11.0  CTUNKNOWN95699011
# 977  TRAILER                                  11.0  LN2AD001XBJ000038
# 978  14U800                                   11.0  5A4XJRJ1472015660
# 979  OUT14800                                 11.0  5A4XJRJ1962012902
# ..                              ...            ...                   ...
# 671                    C4500 C4C042            2.0  1GBE4C1255F517265
# 606  560SEL                                    1.0  WDBCA39E1MA580237
# 737  HM                                       11.0  CTUNKNOWN29263511
# 219  CK31003                                  70.0  CKL3381182236
# 636  XC40 MOMENTUM                             1.0  YV4162XZXK2003978
#
#     lease_street  UID lease_city lease_state lease_zip zip_corrected
# 974          NaN  NaN        NaN         NaN       NaN         68512
# 975          NaN  NaN        NaN         NaN       NaN         68541
# 977          NaN  NaN        NaN         NaN       NaN         68544
# 978          NaN  NaN        NaN         NaN       NaN         68552
# 979          NaN  NaN        NaN         NaN       NaN         68501
# ..           ...  ...        ...         ...       ...           ...
# 671          NaN  NaN        NaN         NaN       NaN         68544
# 606          NaN  NaN        NaN         NaN       NaN         00000
# 737          NaN  NaN        NaN         NaN       NaN         00000
# 219          NaN  NaN        NaN         NaN       NaN         00000
# 636          NaN  NaN        NaN         NaN       NaN         00000
#
# [495 rows x 17 columns]

# %%
nonct_zip_ct_state[nonct_zip_ct_state["record_from"].str.contains("Norwalk")]["zip"].unique()
# Out:
# array(['68512-232 ', '68541-410 ', '68544-229 ', '68552-003 ',
#        '68501-832 ', '68511-221 ', '68516-038 ', '68501-616 ',
#        '00000     ', '68501-733 ', '68531-132 ', '68541-067 ',
#        '68513-605 ', '68514-466 ', '68512-827 ', '68504-430 ',
#        '68512-214 ', '68511-215 ', '68515-328 ', '68512-431 ',
#        '68543-216 ', '68502-730 ', '68501-835 ', '68552-103 ',
#        '68513-420 ', '68502-722 ', '68515-534 ', '68543-305 ',
#        '68543-627 ', '68543-422 ', '68513-008 ', '68552-235 ',
#        '68544-714 ', '68502-840 ', '68544-716 ', '68504-320 ',
#        '68515-940 ', '68513-108 ', '68511-715 ', '68541-613 ',
#        '68513-221 ', '68542-107 ', '68502-408 ', '68543-512 ',
#        '68511-042 ', '68516-027 ', '68514-316 ', '68502-728 ',
#        '68541-561 ', '68543-548 ', '68516-141 ', '68551-615 ',
#        '68544-304 ', '68512-645 ', '68511-536 ', '68544-727 ',
#        '68544-308 ', '68543-735 ', '68542-514 ', '68501-704 ',
#        '68513-115 ', '69024-108 ', '68552-703 ', '68515-514 ',
#        '68513-305 ', '68502-522 ', '68501-833 ', '68541-452 ',
#        '68503-113 ', '68515-513 ', '68551-012 ', '68544-113 ',
#        '68503-530 ', '68544-516 ', '68543-317 ', '68544-004 ',
#        '68503-322 ', '68501-920 ', '68512-215 ', '68541-402 ',
#        '68552-106 ', '68542-712 ', '68514-314 ', '68531-716 ',
#        '68531-644 ', '68501-823 ', '68501-926 ', '68542-420 ',
#        '68541-120 ', '68513-213 ', '68501-405 ', '68513-911 ',
#        '68504-312 ', '68512-219 ', '68502-541 ', '68512-304 ',
#        '68504-409 ', '68544-204 ', '68513-835 ', '68503-221 ',
#        '68501-707 ', '68544-345 ', '68551-622 ', '68504-317 ',
#        '68544-711 ', '68513-211 ', '68512-638 ', '68541-405 ',
#        '68503-317 ', '68512-326 ', '68544-246 ', '68512-802 ',
#        '68501-125 ', '68542-323 ', '68512-406 ', '68544-011 ',
#        '68542-511 ', '68544-127 ', '68541-406 ', '68544-951 ',
#        '68552-504 ', '68551-020 ', '68541-125 ', '68551-306 ',
#        '68513-516 ', '68542-285 ', '68542-835 ', '68551-449 ',
#        '68503-924 ', '68541-112 ', '68512-818 ', '68543-757 ',
#        '68511-556 ', '68502-224 ', '68542-816 ', '68542-881 ',
#        '68543-612 ', '68542-116 ', '68541-918 ', '68515-117 ',
#        '68542-022 ', '68551-926 ', '68512-313 ', '68541-419 ',
#        '68544-920 ', '68513-900 ', '68503-014 ', '68531-315 ',
#        '68542-830 ', '68501-213 ', '68552-034 ', '68503-630 ',
#        '68513-622 ', '68552-108 ', '68503-433 ', '68512-006 ',
#        '68543-910 ', '68515-207 ', '68542-413 ', '68542-804 ',
#        '68531-535 ', '68511-029 ', '68503-513 ', '68514-319 ',
#        '68514-305 ', '68516-142 ', '68544-134 ', '68513-203 ',
#        '68513-005 ', '68511-138 ', '68515-909 ', '68513-118 ',
#        '68502-847 ', '68503-857 ', '68543-316 ', '68531-136 ',
#        '68501-344 ', '68521-673 ', '68514-850 ', '68543-520 ',
#        '68531-542 ', '43026     ', '11106     ', '68512-424 '],
#       dtype=object)

# %% [markdown]
# Appears to occur most in **Ridgefield** and **Norwalk.** However **Ridgefield** is erroneous: The zips should be 06877.
#
# **NORWALK:** The import is correct. The VINs are wrong

# %% [markdown]
# ## Check CT towns with non-CT states

# %%
recompiled_data = reset_recompiled_data()

# %%
ct_towns = []

# Get list of CT towns
for chunk in tqdm(recompiled_data):
    ct_state_mask = chunk["state"] == "CT"
    ct_town_list = chunk.loc[ct_state_mask, "city"].unique().tolist()
    for town in ct_town_list:
        if not town in ct_towns:
            ct_towns.append(town)
# Out:
# 5787it [01:00, 94.97it/s]

# %%
ct_towns = [x.strip() for x in ct_towns if type(x) == str]

# %%
ct_towns_raw = ['Andover','Ansonia','Ashford','Avon','Bantam','Barkhamsted',
                'Beacon Falls','Berlin','Bethany','Bethel','Bethlehem','Bloomfield',
                'Bolton','Bozrah','Branford','Bridgeport','Bridgewater','Bristol',
                'Broad Brook','Brookfield','Brooklyn','Burlington','Canaan','Canterbury',
                'Canton','Chaplin','Cheshire','Chester','Clinton','Colchester','Colebrook',
                'Collinsville','Columbia','Cornwall','Coventry','Cromwell','Danbury',
                'Danielson','Darien','Deep River','Derby','Durham','East Granby','East Haddam',
                'East Hampton','East Hartford','East Haven','East Lyme','East Windsor','Eastford','Easton','Ellington','Enfield','Essex','Fairfield','Farmington','Georgetown','Glastonbury','Goshen','Granby','Greenwich','Groton','Guilford','Haddam','Hamden','Hampton','Hartford','Harwinton','Hebron','Higganum','Jewett City','Kent','Killingworth','Lebanon','Ledyard','Litchfield','Madison','Manchester','Mansfield Center','Marlborough','Meriden','Middlebury','Middlefield','Middletown','Milford','Monroe','Montville','Moodus','Moosup','Morris','Mystic','Naugatuck','New Britain','New Canaan','New Fairfield','New Hartford','New Haven','New London','New Milford','Newington','Newtown','Niantic','Norfolk','North Branford','North Granby','North Grosvenordale','North Haven','North Stonington','Norwalk','Norwich','Oakville','Old Lyme','Old Mystic','Old Saybrook','Orange','Oxford','Pawcatuck','Plainfield','Plainville','Plymouth','Pomfret','Poquonock','Portland','Preston','Prospect','Putnam','Redding','Ridgefield','Rocky Hill','Roxbury','Salem','Salisbury','Scotland','Seymour','Sharon','Shelton','Sherman','Simsbury','Somers',
                'South Windham','South Windsor','South Woodstock','Southbury','Southington',
                'Stafford','Stamford','Sterling','Stonington','Stratford','Suffield','Tariffville',
                'Terryville','Thomaston','Thompson','Tolland','Torrington','Trumbull','Voluntown','Wallingford',
                'Washington','Waterbury','Waterford','Watertown','Wauregan','Weatogue','West Hartford','West Haven',
                'West Simsbury','Westbrook','Weston','Westport','Wethersfield','Willimantic','Willington','Wilton',
                'Winchester Center','Windham','Windsor Locks','Windsor','Winsted','Wolcott','Woodbridge','Woodbury','Woodstock']

ct_towns_raw = [x.upper() for x in ct_towns_raw]

# %%
# Now get entries where town is a CT town but the state is not

recompiled_data = reset_recompiled_data()

ct_town_nonct_state = pd.DataFrame([])
nonct_town_ct_state = pd.DataFrame([])

# %%
for chunk in tqdm(recompiled_data):
    try:
        ct_state_mask = chunk["state"] == "CT"
        
        ct_city_mask = chunk["city"].str.upper().str.strip().isin(ct_towns_raw)
        ct_town_nonct_state_mask = ct_city_mask & ~ct_state_mask
        nonct_town_ct_state_mask = ~ct_city_mask & ct_state_mask

        chunk_ct_town_nonct_state = chunk.loc[ct_town_nonct_state_mask]
        chunk_nonct_town_ct_state = chunk.loc[nonct_town_ct_state_mask]

        ct_town_nonct_state = pd.concat([ct_town_nonct_state, chunk_ct_town_nonct_state])
        nonct_town_ct_state = pd.concat([nonct_town_ct_state, chunk_nonct_town_ct_state])
        
    except:
        pass
# Out:
# 4710it [07:04, 11.09it/s]

# %%
# Correct zips
valid_zips = get_valid_zips(nonct_town_ct_state, "zip")

# Join them
nonct_town_ct_state = nonct_town_ct_state.join(valid_zips).reset_index(drop = True)

# %%
nonct_town_ct_state.reset_index(drop = True).to_csv(path.parent.parent / "data" / "analysis_outputs" / "nonct_town_ct_state.csv")
ct_town_nonct_state.reset_index(drop = True).to_csv(path.parent.parent / "data"/ "analysis_outputs" / "ct_town_nonct_state.csv")

# %%
# Read back in
nonct_town_ct_state = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "nonct_town_ct_state.csv")
# Out:
# /tmp/ipykernel_462290/264407849.py:2: DtypeWarning: Columns (8,12,14,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   nonct_town_ct_state = pd.read_csv(path.parent.parent / "data" / "analysis_outputs" / "nonct_town_ct_state.csv")

# %%
nonct_town_ct_state
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0               record_from  \
# 0                  0             0          55     001_Andover_MV_21.csv
# 1                  1             1         391     001_Andover_MV_21.csv
# 2                  2             2         934     001_Andover_MV_21.csv
# 3                  3             3        1576     001_Andover_MV_21.csv
# 4                  4             4        1892     001_Andover_MV_21.csv
# ...              ...           ...         ...                       ...
# 362233        362233        362233     5782863  9_Bethel_MVData_2020.csv
# 362234        362234        362234     5784057  9_Bethel_MVData_2020.csv
# 362235        362235        362235     5784605  9_Bethel_MVData_2020.csv
# 362236        362236        362236     5784606  9_Bethel_MVData_2020.csv
# 362237        362237        362237     5784607  9_Bethel_MVData_2020.csv
#
#                                             name  \
# 0       ALLEN CARLY M
# 1       BOUCHARD DANIEL B
# 2       EDBERG NATHAN S
# 3       JAHN MATTHEW M
# 4       LAVEY LYNN K
# ...                                          ...
# 362233  REAL MOVING LLC
# 362234  SCRIBNER MILES D
# 362235  SOMOSKOVEC ROBERT M
# 362236  SOMOSKOVEC ROBERT M
# 362237  SOMOSKOVEC ROBERT M
#
#                                 street                            city state  \
# 0       125 SOUTH ST  APT 283           VERNON ROCKVILLE                  CT
# 1       42 KEENE PL                     UNIONVILLE                        CT
# 2       77 EAST ST                      STAFFORD SPRINGS                  CT
# 3       10 COUNTRY RD                   UNIONVILLE                        CT
# 4       141 LEBANON RD                  NORTH FRANKLIN                    CT
# ...                                ...                             ...   ...
# 362233  1 PINE ST                       SANDY HOOK                        CT
# 362234  4 TOP PASTURE RD                WASHINGTON DEPOT                  CT
# 362235  PO BOX 177                      HAWLEYVILLE                       CT
# 362236  PO BOX 177                      HAWLEYVILLE                       CT
# 362237  PO BOX 177                      HAWLEYVILLE                       CT
#
#          zip  vehicle_year vehicle_make vehicle_model vehicle_class  \
# 0       6066        2013.0        HONDA      CIVIC SI           1.0
# 1       6085        2009.0        CHEVR      SILVERAD           3.0
# 2       6076        2011.0        FORD       F350 SUP           3.0
# 3       6085        2007.0        CHEVR      IMPALA L           1.0
# 4       6254        2017.0        ACURA      RDX ADVA           1.0
# ...      ...           ...          ...           ...           ...
# 362233  6482        2004.0        INTER      4000 SER           2.0
# 362234  6794        2018.0        SUBAR      LEGACY 2           1.0
# 362235  6440        2005.0        JAGUA      X-TYPE 3           1.0
# 362236  6440        2008.0        FORD       RANGER             1.0
# 362237  6440        2002.0        KAWAS      VN1500-L          12.0
#
#                vehicle_id lease_street  UID lease_city lease_state lease_zip  \
# 0       2HGFG4A51DH703262          NaN  NaN        NaN         NaN       NaN
# 1       1GCEK29099Z180506          NaN  NaN        NaN         NaN       NaN
# 2       1FT8W3BT0BEB85196          NaN  NaN        NaN         NaN       NaN
# 3       2G1WT58N679293166          NaN  NaN        NaN         NaN       NaN
# 4       5J8TB4H70HL014959          NaN  NaN        NaN         NaN       NaN
# ...                   ...          ...  ...        ...         ...       ...
# 362233  1HTMMAAM84H612857          NaN  NaN        NaN         NaN       NaN
# 362234  4S3BNAC62J3020380          NaN  NaN        NaN         NaN       NaN
# 362235  SAJWA51AX5WE52543          NaN  NaN        NaN         NaN       NaN
# 362236  1FTZR15E28PA69914          NaN  NaN        NaN         NaN       NaN
# 362237  JKBVNAL122A014146          NaN  NaN        NaN         NaN       NaN
#
#        zip_corrected
# 0             6066.0
# 1             6085.0
# 2             6076.0
# 3             6085.0
# 4             6254.0
# ...              ...
# 362233        6482.0
# 362234        6794.0
# 362235        6440.0
# 362236        6440.0
# 362237        6440.0
#
# [362238 rows x 20 columns]

# %%
# Create a list of non CT towns, with the state CT, and the zip code.
nonct_town_ct_state_zips = nonct_town_ct_state[["city", "state", "zip_corrected"]]
nonct_town_ct_state_zips["city_state_zip_corrected"] = nonct_town_ct_state_zips["city"].str.strip() + ", "+ nonct_town_ct_state_zips["state"] +", "+ nonct_town_ct_state_zips["zip_corrected"].astype(str).str[:-2]
nonct_town_ct_state_zips_list = nonct_town_ct_state_zips["city_state_zip_corrected"].unique().tolist()
# Out:
# /tmp/ipykernel_1537128/846396570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonct_town_ct_state_zips["city_state_zip_corrected"] = nonct_town_ct_state_zips["city"].str.strip() + ", "+ nonct_town_ct_state_zips["state"] +", "+ nonct_town_ct_state_zips["zip_corrected"].astype(str).str[:-2]

# %%
# Save this to a text file
text_file = open(path.parent.parent / "data" / "analysis_outputs" / "possible_nonct_towns_withzips.txt", "w")
text_file.write(', '.join([x for x in nonct_town_ct_state_zips_list if type(x) == str]))
text_file.close()

# %%
# The same thing, but with only the town names and not the zip code and the state name
possible_nonct_towns = [x.strip() for x in nonct_town_ct_state["city"].unique().tolist() if type(x) == str]
text_file = open(path.parent.parent / "data" / "analysis_outputs" / "possible_nonct_towns.txt", "w")
text_file.write(', '.join(possible_nonct_towns))
text_file.close()

# %%
poss_nonct = pd.DataFrame(possible_nonct_towns, columns = ["town_names"])
poss_nonct["town_name_state"] = poss_nonct["town_names"] + ", CT"

# %% [markdown]
# ### Attempt to GeoCode non-CT towns with CT state (without ZIPs)

# %%
geocoded_out = gpd.GeoDataFrame([])

# %%
count = 0

for i in tqdm(range(84)):
    try:
        to_geocode = poss_nonct["town_name_state"][count:count+10]
    except:
        remainder = len(possible_nonct_towns)-count-1
        to_geocode = poss_nonct["town_name_state"][count:count+remainder]
        
    geo = geocode(to_geocode, provider='nominatim', user_agent='yale', timeout=4)
    geo["town_name_state"] = to_geocode
    geo = geo.reset_index(drop=True)

    geocoded_out = pd.concat([geocoded_out, geo])
    count +=10
# Out:
# 100%|██████████████████████████████████████████| 84/84 [07:20<00:00,  5.24s/it]

# %%
geocoded_out.to_csv(path.parent.parent / "data" / "analysis_outputs" / "geocoded_ct_towns.csv")

# %% [markdown]
# ### Attempt to GeoCode non-CT towns with CT state (with ZIPs)

# %%
geocoded_out_zips = gpd.GeoDataFrame([])

# %%
count = 0

# %%
for i in tqdm(range(109, 203)):
    try:
        to_geocode = nonct_town_ct_state_zips_list[count:count+10]
    except:
        remainder = len(nonct_town_ct_state_zips_list)-count-1
        to_geocode = nonct_town_ct_state_zips_list[count:count+remainder]
        
    geo = geocode(to_geocode, provider='nominatim', user_agent='yale', timeout=4)
    geo["city_state_zip"] = to_geocode
    geo = geo.reset_index(drop=True)

    geocoded_out_zips = pd.concat([geocoded_out_zips, geo])
    count +=10

# %%
geocoded_out_zips.to_csv(path.parent.parent / "data" / "analysis_outputs" / "geocoded_ct_towns_zips.csv")

# %%
# Truth-table analysis
def chunk_truth_table(chunk, town_list):
    ctstate_mask = chunk["state"] == "CT" 
    ctzip_mask = chunk["zip_corrected"].astype(str).str[:-2].str.zfill(5).str[0:2]=="06"
    cttown_mask = chunk["city"].str.upper().str.strip().isin(town_list)
    
    chunk.loc[ctstate_mask, "ctstate_mask"] = 1
    chunk.loc[~ctstate_mask, "ctstate_mask"] = 0

    chunk.loc[ctzip_mask, "ctzip_mask"] = 1
    chunk.loc[~ctzip_mask, "ctzip_mask"] = 0

    chunk.loc[cttown_mask, "cttown_mask"] = 1
    chunk.loc[~cttown_mask, "cttown_mask"] = 0

    chunk["masks"] = (chunk[ctstate_mask] * "ctstate_") + (chunk[ctzip_mask] * "ctzip_") + (chunk[cttown_mask] * "cttown")

    chunk["count"] = 1

    tally = chunk.groupy("masks").sum()[["masks", "count"]]

# %% [markdown]
# # Compare Original and New

# %%
missing_df_original["missing zip rank"] = missing_df_original["missing zip"].rank(method = 'min', ascending = False)
missing_df_original["missing VIN rank"] = missing_df_original["missing VIN"].rank(method = 'min', ascending = False)
missing_df_original["missing street rank"] = missing_df_original["missing street"].rank(method = 'min', ascending = False)

# %%
missing_df_new["missing zip rank"] = missing_df_new["missing zip"].rank(method = 'min', ascending = False)
missing_df_new["missing VIN rank"] = missing_df_new["missing VIN"].rank(method = 'min', ascending = False)
missing_df_new["missing street rank"] = missing_df_new["missing street"].rank(method = 'min', ascending = False)

# %%
missing_df_original.sort_values("missing street rank", ascending = True).head(20)
# Out:
#                        record_from  missing zip  missing VIN  missing street  \
# 91          103_Norwalk_MV_21.xlsx        75044        75044           75044
# 90     103_Norwalk_MVData_2020.csv        71664        71664           71664
# 290  77_Manchester_MVData_2019.csv        48990         3203           48990
# 64        077_Manchester_MV_21.xls        44487            3           44487
# 124  11_Bloomfield_MVData_2019.csv        19643        19643           19643
# 8            009_Bethel_MV_21.xlsx        17855            1           17855
# 99           107_Orange_MV_21.xlsx        13522            0           13522
# 235     27_Clinton_MVData_2020.csv        13202            0           13202
# 169        141_Thompson_MV_21.xlsx        10054          457           10054
# 28             037_Derby_MV_21.xls         9511            0            9511
# 14      016_Bridgewater_MV_21.xlsx         7254         4886            7254
# 104   10_Bethlehem_MVData_2019.csv         4760            0            4760
# 130       122_Salisbury_MV_21.xlsx         4390         4390            4390
# 109    112_Pomfret_MVData_2020.csv         4130            0            4130
# 44           055_Goshen_MV_21.XLSX         4004            0            4004
# 227      1_Andover_MVData_2020.csv         3938         3938            3938
# 232     24_Chaplin_MVData_2020.csv         2567         2567            2567
# 82          098_Norfolk_MV_21.xlsx         1945            0            1945
# 87      101_North_Haven_MV_21.xlsx        24425          194              86
# 69       083_Middletown_MV_21.xlsx        35302           82              82
#
#      not CT  count  missing zip rank  missing VIN rank  missing street rank
# 91    75044  75044               4.0               1.0                  1.0
# 90    71664  71664               5.0               2.0                  2.0
# 290   48990  48990              12.0              12.0                  3.0
# 64    44487  44487              18.0              37.0                  4.0
# 124    1630  19643              71.0               6.0                  5.0
# 8      1678  17855              79.0              44.0                  6.0
# 99    13522  13522             119.0              61.0                  7.0
# 235   13202  13202             123.0              61.0                  8.0
# 169   10054  10054             151.0              14.0                  9.0
# 28     9511   9511             161.0              61.0                 10.0
# 14     7254   7254             190.0               9.0                 11.0
# 104     206   4760             213.0              61.0                 12.0
# 130    4390   4390             217.0              10.0                 13.0
# 109    4130   4130             224.0              61.0                 14.0
# 44     4004   4004             228.0              61.0                 15.0
# 227    3938   3938             229.0              11.0                 16.0
# 232    2567   2567             253.0              13.0                 17.0
# 82     1945   1945             262.0              61.0                 18.0
# 87     2978  24425              56.0              18.0                 19.0
# 69     3060  35302              32.0              23.0                 20.0

# %%
missing_df_original_zips_formerge = missing_df_original[["record_from", "missing zip", "missing zip rank"]].sort_values("missing zip rank", ascending = True).head(15)
missing_df_original_VINS_formerge = missing_df_original[["record_from", "missing VIN", "missing VIN rank"]].sort_values("missing VIN rank", ascending = True).head(10)
missing_df_original_streets_formerge = missing_df_original[["record_from", "missing street", "missing street rank"]].sort_values("missing street rank", ascending = True).head(10)

# %%
missing_df_new_zips_formerge = missing_df_new[["record_from", "missing zip", "missing zip rank"]].sort_values("missing zip rank", ascending = True).head(15)
missing_df_new_VINS_formerge = missing_df_new[["record_from", "missing VIN", "missing VIN rank"]].sort_values("missing VIN rank", ascending = True).head(10)
missing_df_new_streets_formerge = missing_df_new[["record_from", "missing street", "missing street rank"]].sort_values("missing street rank", ascending = True).head(10)

# %%
compare_missing_zips = missing_df_original_zips_formerge.merge(missing_df_new_zips_formerge, how = 'left',
                                                              left_on = "missing zip rank",
                                                              right_on = "missing zip rank",
                                                              suffixes = ("_original", "_recompiled"))

compare_missing_zips = compare_missing_zips.set_index("missing zip rank")

compare_missing_zips["Difference"] = compare_missing_zips["missing zip_recompiled"] - compare_missing_zips["missing zip_original"]

compare_missing_zips = compare_missing_zips.reset_index()

# %%
cm = sns.light_palette("green", as_cmap=True, reverse = True)

# %%
compare_missing_zips = compare_missing_zips.style.background_gradient(subset = ["Difference"], cmap=cm)
# compare_missing_zips.data = compare_missing_zips.data.drop("Town_original", axis = 1)
compare_missing_zips.data = compare_missing_zips.data.drop("missing zip rank", axis = 1)

# %%
total_row_zips = pd.DataFrame(compare_missing_zips.data.sum(), columns=["Total"]).T
total_row_zips.loc["Total", "record_from_original"] = ""
total_row_zips.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_zips.data = pd.concat([compare_missing_zips.data, total_row_zips])

# %%
compare_missing_zips.set_caption("Comparison of Missing ZIP Codes: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_c68f4 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c68f4_row0_col4 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_c68f4_row1_col4, #T_c68f4_row2_col4, #T_c68f4_row3_col4 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_c68f4_row4_col4 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_c68f4_row5_col4 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_c68f4_row6_col4 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_c68f4_row7_col4 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_c68f4_row8_col4, #T_c68f4_row9_col4, #T_c68f4_row10_col4, #T_c68f4_row11_col4, #T_c68f4_row12_col4, #T_c68f4_row13_col4, #T_c68f4_row14_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c68f4_row15_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c68f4">
#   <caption>Comparison of Missing ZIP Codes: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c68f4_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_c68f4_level0_col1" class="col_heading level0 col1" >missing zip_original</th>
#       <th id="T_c68f4_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_c68f4_level0_col3" class="col_heading level0 col3" >missing zip_recompiled</th>
#       <th id="T_c68f4_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c68f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c68f4_row0_col0" class="data row0 col0" >15_Bridgeport_MVData_2019.csv</td>
#       <td id="T_c68f4_row0_col1" class="data row0 col1" >82704</td>
#       <td id="T_c68f4_row0_col2" class="data row0 col2" >107_Orange_MV_21.xlsx</td>
#       <td id="T_c68f4_row0_col3" class="data row0 col3" >13522</td>
#       <td id="T_c68f4_row0_col4" class="data row0 col4" >-69182</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c68f4_row1_col0" class="data row1 col0" >015_Bridgeport_MV_21.xlsx</td>
#       <td id="T_c68f4_row1_col1" class="data row1 col1" >80383</td>
#       <td id="T_c68f4_row1_col2" class="data row1 col2" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_c68f4_row1_col3" class="data row1 col3" >13202</td>
#       <td id="T_c68f4_row1_col4" class="data row1 col4" >-67181</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c68f4_row2_col0" class="data row2 col0" >135_Stamford_MV_21.xlsx</td>
#       <td id="T_c68f4_row2_col1" class="data row2 col1" >77594</td>
#       <td id="T_c68f4_row2_col2" class="data row2 col2" >131_Southington_MV_21.xlsx</td>
#       <td id="T_c68f4_row2_col3" class="data row2 col3" >10089</td>
#       <td id="T_c68f4_row2_col4" class="data row2 col4" >-67505</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c68f4_row3_col0" class="data row3 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_c68f4_row3_col1" class="data row3 col1" >75044</td>
#       <td id="T_c68f4_row3_col2" class="data row3 col2" >037_Derby_MV_21.xls</td>
#       <td id="T_c68f4_row3_col3" class="data row3 col3" >9511</td>
#       <td id="T_c68f4_row3_col4" class="data row3 col4" >-65533</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c68f4_row4_col0" class="data row4 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_c68f4_row4_col1" class="data row4 col1" >71664</td>
#       <td id="T_c68f4_row4_col2" class="data row4 col2" >117_Redding_MV_21.xlsx</td>
#       <td id="T_c68f4_row4_col3" class="data row4 col3" >8171</td>
#       <td id="T_c68f4_row4_col4" class="data row4 col4" >-63493</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c68f4_row5_col0" class="data row5 col0" >151_Waterbury_MV_21.xlsx</td>
#       <td id="T_c68f4_row5_col1" class="data row5 col1" >64647</td>
#       <td id="T_c68f4_row5_col2" class="data row5 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_c68f4_row5_col3" class="data row5 col3" >4886</td>
#       <td id="T_c68f4_row5_col4" class="data row5 col4" >-59761</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c68f4_row6_col0" class="data row6 col0" >93_NewHaven_MVData_2019.csv</td>
#       <td id="T_c68f4_row6_col1" class="data row6 col1" >60366</td>
#       <td id="T_c68f4_row6_col2" class="data row6 col2" >045_East_Lyme_MV_21_ALTERED.csv</td>
#       <td id="T_c68f4_row6_col3" class="data row6 col3" >4475</td>
#       <td id="T_c68f4_row6_col4" class="data row6 col4" >-55891</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c68f4_row7_col0" class="data row7 col0" >093_New_Haven_MV_21.xlsx</td>
#       <td id="T_c68f4_row7_col1" class="data row7 col1" >57470</td>
#       <td id="T_c68f4_row7_col2" class="data row7 col2" >44_East_Lyme_MVData_2019.csv</td>
#       <td id="T_c68f4_row7_col3" class="data row7 col3" >4301</td>
#       <td id="T_c68f4_row7_col4" class="data row7 col4" >-53169</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c68f4_row8_col0" class="data row8 col0" >057_Greenwich_MV_21.xlsx</td>
#       <td id="T_c68f4_row8_col1" class="data row8 col1" >51748</td>
#       <td id="T_c68f4_row8_col2" class="data row8 col2" >112_Pomfret_MVData_2020.csv</td>
#       <td id="T_c68f4_row8_col3" class="data row8 col3" >4130</td>
#       <td id="T_c68f4_row8_col4" class="data row8 col4" >-47618</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c68f4_row9_col0" class="data row9 col0" >57_Greenwich_MVData_2020.csv</td>
#       <td id="T_c68f4_row9_col1" class="data row9 col1" >51478</td>
#       <td id="T_c68f4_row9_col2" class="data row9 col2" >055_Goshen_MV_21.XLSX</td>
#       <td id="T_c68f4_row9_col3" class="data row9 col3" >4004</td>
#       <td id="T_c68f4_row9_col4" class="data row9 col4" >-47474</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c68f4_row10_col0" class="data row10 col0" >017_Bristol_MV_21.xlsx</td>
#       <td id="T_c68f4_row10_col1" class="data row10 col1" >50757</td>
#       <td id="T_c68f4_row10_col2" class="data row10 col2" >098_Norfolk_MV_21.xlsx</td>
#       <td id="T_c68f4_row10_col3" class="data row10 col3" >1945</td>
#       <td id="T_c68f4_row10_col4" class="data row10 col4" >-48812</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c68f4_row11_col0" class="data row11 col0" >77_Manchester_MVData_2019.csv</td>
#       <td id="T_c68f4_row11_col1" class="data row11 col1" >48990</td>
#       <td id="T_c68f4_row11_col2" class="data row11 col2" >77_Manchester_MVData_2019_ALTERED.csv</td>
#       <td id="T_c68f4_row11_col3" class="data row11 col3" >221</td>
#       <td id="T_c68f4_row11_col4" class="data row11 col4" >-48769</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c68f4_row12_col0" class="data row12 col0" >51_Fairfield_MVData_2019.csv</td>
#       <td id="T_c68f4_row12_col1" class="data row12 col1" >47928</td>
#       <td id="T_c68f4_row12_col2" class="data row12 col2" >072_Ledyard_MV_21_ALTERED.csv</td>
#       <td id="T_c68f4_row12_col3" class="data row12 col3" >143</td>
#       <td id="T_c68f4_row12_col4" class="data row12 col4" >-47785</td>
#     </tr>
#     <tr>
#       <th id="T_c68f4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c68f4_row13_col0" class="data row13 col0" >084_Milford_MV_21.xlsx</td>
#       <td id="T_c68f4_row13_col1" class="data row13 col1" >47335</td>
#       <td id="T

# %% [markdown]
# ### Comparing missing VINs

# %%
compare_missing_VINS = missing_df_original_VINS_formerge.merge(missing_df_new_VINS_formerge, how = 'left',
                                                              left_on = "missing VIN rank",
                                                              right_on = "missing VIN rank",
                                                              suffixes = ("_original", "_recompiled"))

compare_missing_VINS = compare_missing_VINS.set_index("missing VIN rank")

compare_missing_VINS["Difference"] = compare_missing_VINS["missing VIN_recompiled"] - compare_missing_VINS["missing VIN_original"]

compare_missing_VINS = compare_missing_VINS.reset_index()

compare_missing_VINS = compare_missing_VINS.style.background_gradient(subset = ["Difference"], cmap=cm)

compare_missing_VINS.data = compare_missing_VINS.data.drop("missing VIN rank", axis = 1)
# Out:
# <style type="text/css">
# #T_45534 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_45534_row0_col4 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_45534_row1_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_45534_row2_col4 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_45534_row3_col4, #T_45534_row4_col4 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_45534_row5_col4 {
#   background-color: #a7d2a7;
#   color: #000000;
# }
# #T_45534_row6_col4 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_45534_row7_col4 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_45534_row8_col4 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_45534_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_45534">
#   <caption>Comparison of Missing VINs: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45534_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_45534_level0_col1" class="col_heading level0 col1" >missing VIN_original</th>
#       <th id="T_45534_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_45534_level0_col3" class="col_heading level0 col3" >missing VIN_recompiled</th>
#       <th id="T_45534_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45534_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45534_row0_col0" class="data row0 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_45534_row0_col1" class="data row0 col1" >75044</td>
#       <td id="T_45534_row0_col2" class="data row0 col2" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_45534_row0_col3" class="data row0 col3" >19643</td>
#       <td id="T_45534_row0_col4" class="data row0 col4" >-55401</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45534_row1_col0" class="data row1 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_45534_row1_col1" class="data row1 col1" >71664</td>
#       <td id="T_45534_row1_col2" class="data row1 col2" >107_Orange_MVData_2020.csv</td>
#       <td id="T_45534_row1_col3" class="data row1 col3" >14650</td>
#       <td id="T_45534_row1_col4" class="data row1 col4" >-57014</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45534_row2_col0" class="data row2 col0" >126_Shelton_MV_21.xlsx</td>
#       <td id="T_45534_row2_col1" class="data row2 col1" >39086</td>
#       <td id="T_45534_row2_col2" class="data row2 col2" >124_Seymour_MV_21.csv</td>
#       <td id="T_45534_row2_col3" class="data row2 col3" >13860</td>
#       <td id="T_45534_row2_col4" class="data row2 col4" >-25226</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45534_row3_col0" class="data row3 col0" >143_Torrington_MV_21.xlsx</td>
#       <td id="T_45534_row3_col1" class="data row3 col1" >29674</td>
#       <td id="T_45534_row3_col2" class="data row3 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_45534_row3_col3" class="data row3 col3" >4886</td>
#       <td id="T_45534_row3_col4" class="data row3 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45534_row4_col0" class="data row4 col0" >143_Torrington_MVData_2020.csv</td>
#       <td id="T_45534_row4_col1" class="data row4 col1" >29674</td>
#       <td id="T_45534_row4_col2" class="data row4 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_45534_row4_col3" class="data row4 col3" >4886</td>
#       <td id="T_45534_row4_col4" class="data row4 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45534_row5_col0" class="data row5 col0" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_45534_row5_col1" class="data row5 col1" >19643</td>
#       <td id="T_45534_row5_col2" class="data row5 col2" >121_Salem_MVData_2019.csv</td>
#       <td id="T_45534_row5_col3" class="data row5 col3" >218</td>
#       <td id="T_45534_row5_col4" class="data row5 col4" >-19425</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45534_row6_col0" class="data row6 col0" >107_Orange_MVData_2020.csv</td>
#       <td id="T_45534_row6_col1" class="data row6 col1" >14650</td>
#       <td id="T_45534_row6_col2" class="data row6 col2" >101_North_Haven_MV_21.xlsx</td>
#       <td id="T_45534_row6_col3" class="data row6 col3" >84</td>
#       <td id="T_45534_row6_col4" class="data row6 col4" >-14566</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45534_row7_col0" class="data row7 col0" >124_Seymour_MV_21.csv</td>
#       <td id="T_45534_row7_col1" class="data row7 col1" >13860</td>
#       <td id="T_45534_row7_col2" class="data row7 col2" >083_Middletown_MV_21.xlsx</td>
#       <td id="T_45534_row7_col3" class="data row7 col3" >82</td>
#       <td id="T_45534_row7_col4" class="data row7 col4" >-13778</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45534_row8_col0" class="data row8 col0" >016_Bridgewater_MV_21.xlsx</td>
#       <td id="T_45534_row8_col1" class="data row8 col1" >4886</td>
#       <td id="T_45534_row8_col2" class="data row8 col2" >136_Sterling_MVData_2019.csv</td>
#       <td id="T_45534_row8_col3" class="data row8 col3" >69</td>
#       <td id="T_45534_row8_col4" class="data row8 col4" >-4817</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45534_row9_col0" class="data row9 col0" >122_Salisbury_MV_21.xlsx</td>
#       <td id="T_45534_row9_col1" class="data row9 col1" >4390</td>
#       <td id="T_45534_row9_col2" class="data row9 col2" >163_Windham_MV_21.xlsx</td>
#       <td id="T_45534_row9_col3" class="data row9 col3" >37</td>
#       <td id="T_45534_row9_col4" class="data row9 col4" >-4353</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_row = pd.DataFrame(compare_missing_VINS.data.sum(), columns=["Total"]).T

# %%
total_row.loc["Total", "record_from_original"] = ""
total_row.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_VINS.data = pd.concat([compare_missing_VINS.data, total_row])

# %%
compare_missing_VINS.set_caption("Comparison of Missing VINs: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_45534 caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_45534_row0_col4 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_45534_row1_col4 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_45534_row2_col4 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_45534_row3_col4, #T_45534_row4_col4 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_45534_row5_col4 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_45534_row6_col4, #T_45534_row7_col4 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_45534_row8_col4, #T_45534_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_45534_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_45534">
#   <caption>Comparison of Missing VINs: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45534_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_45534_level0_col1" class="col_heading level0 col1" >missing VIN_original</th>
#       <th id="T_45534_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_45534_level0_col3" class="col_heading level0 col3" >missing VIN_recompiled</th>
#       <th id="T_45534_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45534_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45534_row0_col0" class="data row0 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_45534_row0_col1" class="data row0 col1" >75044</td>
#       <td id="T_45534_row0_col2" class="data row0 col2" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_45534_row0_col3" class="data row0 col3" >19643</td>
#       <td id="T_45534_row0_col4" class="data row0 col4" >-55401</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45534_row1_col0" class="data row1 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_45534_row1_col1" class="data row1 col1" >71664</td>
#       <td id="T_45534_row1_col2" class="data row1 col2" >107_Orange_MVData_2020.csv</td>
#       <td id="T_45534_row1_col3" class="data row1 col3" >14650</td>
#       <td id="T_45534_row1_col4" class="data row1 col4" >-57014</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45534_row2_col0" class="data row2 col0" >126_Shelton_MV_21.xlsx</td>
#       <td id="T_45534_row2_col1" class="data row2 col1" >39086</td>
#       <td id="T_45534_row2_col2" class="data row2 col2" >124_Seymour_MV_21.csv</td>
#       <td id="T_45534_row2_col3" class="data row2 col3" >13860</td>
#       <td id="T_45534_row2_col4" class="data row2 col4" >-25226</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45534_row3_col0" class="data row3 col0" >143_Torrington_MV_21.xlsx</td>
#       <td id="T_45534_row3_col1" class="data row3 col1" >29674</td>
#       <td id="T_45534_row3_col2" class="data row3 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_45534_row3_col3" class="data row3 col3" >4886</td>
#       <td id="T_45534_row3_col4" class="data row3 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45534_row4_col0" class="data row4 col0" >143_Torrington_MVData_2020.csv</td>
#       <td id="T_45534_row4_col1" class="data row4 col1" >29674</td>
#       <td id="T_45534_row4_col2" class="data row4 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_45534_row4_col3" class="data row4 col3" >4886</td>
#       <td id="T_45534_row4_col4" class="data row4 col4" >-24788</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45534_row5_col0" class="data row5 col0" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_45534_row5_col1" class="data row5 col1" >19643</td>
#       <td id="T_45534_row5_col2" class="data row5 col2" >121_Salem_MVData_2019.csv</td>
#       <td id="T_45534_row5_col3" class="data row5 col3" >218</td>
#       <td id="T_45534_row5_col4" class="data row5 col4" >-19425</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45534_row6_col0" class="data row6 col0" >107_Orange_MVData_2020.csv</td>
#       <td id="T_45534_row6_col1" class="data row6 col1" >14650</td>
#       <td id="T_45534_row6_col2" class="data row6 col2" >101_North_Haven_MV_21.xlsx</td>
#       <td id="T_45534_row6_col3" class="data row6 col3" >84</td>
#       <td id="T_45534_row6_col4" class="data row6 col4" >-14566</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45534_row7_col0" class="data row7 col0" >124_Seymour_MV_21.csv</td>
#       <td id="T_45534_row7_col1" class="data row7 col1" >13860</td>
#       <td id="T_45534_row7_col2" class="data row7 col2" >083_Middletown_MV_21.xlsx</td>
#       <td id="T_45534_row7_col3" class="data row7 col3" >82</td>
#       <td id="T_45534_row7_col4" class="data row7 col4" >-13778</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45534_row8_col0" class="data row8 col0" >016_Bridgewater_MV_21.xlsx</td>
#       <td id="T_45534_row8_col1" class="data row8 col1" >4886</td>
#       <td id="T_45534_row8_col2" class="data row8 col2" >136_Sterling_MVData_2019.csv</td>
#       <td id="T_45534_row8_col3" class="data row8 col3" >69</td>
#       <td id="T_45534_row8_col4" class="data row8 col4" >-4817</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45534_row9_col0" class="data row9 col0" >122_Salisbury_MV_21.xlsx</td>
#       <td id="T_45534_row9_col1" class="data row9 col1" >4390</td>
#       <td id="T_45534_row9_col2" class="data row9 col2" >163_Windham_MV_21.xlsx</td>
#       <td id="T_45534_row9_col3" class="data row9 col3" >37</td>
#       <td id="T_45534_row9_col4" class="data row9 col4" >-4353</td>
#     </tr>
#     <tr>
#       <th id="T_45534_level0_row10" class="row_heading level0 row10" >Total</th>
#       <td id="T_45534_row10_col0" class="data row10 col0" ></td>
#       <td id="T_45534_row10_col1" class="data row10 col1" >302571</td>
#       <td id="T_45534_row10_col2" class="data row10 col2" ></td>
#       <td id="T_45534_row10_col3" class="data row10 col3" >58415</td>
#       <td id="T_45534_row10_col4" class="data row10 col4" >-244156</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparing Missing Street Addresses

# %%
compare_missing_streets = missing_df_original_streets_formerge.merge(missing_df_new_streets_formerge, how = 'left',
                                                      left_on = "missing street rank",
                                                      right_on = "missing street rank",
                                                      suffixes = ("_original", "_recompiled"))

compare_missing_streets = compare_missing_streets.set_index("missing street rank")

compare_missing_streets["Difference"] = compare_missing_streets["missing street_recompiled"] - compare_missing_streets["missing street_original"]

compare_missing_streets = compare_missing_streets.reset_index()

compare_missing_streets = compare_missing_streets.style.background_gradient(subset = ["Difference"], cmap=cm)

compare_missing_streets.data = compare_missing_streets.data.drop("missing street rank", axis = 1)

# %%
total_row_streets = pd.DataFrame(compare_missing_streets.data.sum(), columns=["Total"]).T
total_row_streets.loc["Total", "record_from_original"] = ""
total_row_streets.loc["Total", "record_from_recompiled"] =""

# %%
compare_missing_streets.data = pd.concat([compare_missing_streets.data, total_row_streets])

# %%
compare_missing_streets.set_caption("Comparison of Missing Street Addresses: New and Recompiled Data").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '20px'),
        ('font-weight', 'bold'),
        ('text-align', 'center')]}])
# Out:
# <style type="text/css">
# #T_2ad5e caption {
#   color: black;
#   font-size: 20px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_2ad5e_row0_col4 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_2ad5e_row1_col4 {
#   background-color: #bbdcbb;
#   color: #000000;
# }
# #T_2ad5e_row2_col4 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_2ad5e_row3_col4 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_2ad5e_row4_col4 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_2ad5e_row5_col4 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_2ad5e_row6_col4, #T_2ad5e_row7_col4, #T_2ad5e_row9_col4 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_2ad5e_row8_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_2ad5e_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ad5e">
#   <caption>Comparison of Missing Street Addresses: New and Recompiled Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ad5e_level0_col0" class="col_heading level0 col0" >record_from_original</th>
#       <th id="T_2ad5e_level0_col1" class="col_heading level0 col1" >missing street_original</th>
#       <th id="T_2ad5e_level0_col2" class="col_heading level0 col2" >record_from_recompiled</th>
#       <th id="T_2ad5e_level0_col3" class="col_heading level0 col3" >missing street_recompiled</th>
#       <th id="T_2ad5e_level0_col4" class="col_heading level0 col4" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ad5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ad5e_row0_col0" class="data row0 col0" >103_Norwalk_MV_21.xlsx</td>
#       <td id="T_2ad5e_row0_col1" class="data row0 col1" >75044</td>
#       <td id="T_2ad5e_row0_col2" class="data row0 col2" >107_Orange_MV_21.xlsx</td>
#       <td id="T_2ad5e_row0_col3" class="data row0 col3" >13522</td>
#       <td id="T_2ad5e_row0_col4" class="data row0 col4" >-61522</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ad5e_row1_col0" class="data row1 col0" >103_Norwalk_MVData_2020.csv</td>
#       <td id="T_2ad5e_row1_col1" class="data row1 col1" >71664</td>
#       <td id="T_2ad5e_row1_col2" class="data row1 col2" >045_East_Lyme_MV_21_ALTERED.csv</td>
#       <td id="T_2ad5e_row1_col3" class="data row1 col3" >13325</td>
#       <td id="T_2ad5e_row1_col4" class="data row1 col4" >-58339</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ad5e_row2_col0" class="data row2 col0" >77_Manchester_MVData_2019.csv</td>
#       <td id="T_2ad5e_row2_col1" class="data row2 col1" >48990</td>
#       <td id="T_2ad5e_row2_col2" class="data row2 col2" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_2ad5e_row2_col3" class="data row2 col3" >13202</td>
#       <td id="T_2ad5e_row2_col4" class="data row2 col4" >-35788</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ad5e_row3_col0" class="data row3 col0" >077_Manchester_MV_21.xls</td>
#       <td id="T_2ad5e_row3_col1" class="data row3 col1" >44487</td>
#       <td id="T_2ad5e_row3_col2" class="data row3 col2" >037_Derby_MV_21.xls</td>
#       <td id="T_2ad5e_row3_col3" class="data row3 col3" >9511</td>
#       <td id="T_2ad5e_row3_col4" class="data row3 col4" >-34976</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ad5e_row4_col0" class="data row4 col0" >11_Bloomfield_MVData_2019.csv</td>
#       <td id="T_2ad5e_row4_col1" class="data row4 col1" >19643</td>
#       <td id="T_2ad5e_row4_col2" class="data row4 col2" >016_Bridgewater_MV_21_ALTERED.csv</td>
#       <td id="T_2ad5e_row4_col3" class="data row4 col3" >4886</td>
#       <td id="T_2ad5e_row4_col4" class="data row4 col4" >-14757</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ad5e_row5_col0" class="data row5 col0" >009_Bethel_MV_21.xlsx</td>
#       <td id="T_2ad5e_row5_col1" class="data row5 col1" >17855</td>
#       <td id="T_2ad5e_row5_col2" class="data row5 col2" >10_Bethlehem_MVData_2019.csv</td>
#       <td id="T_2ad5e_row5_col3" class="data row5 col3" >4760</td>
#       <td id="T_2ad5e_row5_col4" class="data row5 col4" >-13095</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2ad5e_row6_col0" class="data row6 col0" >107_Orange_MV_21.xlsx</td>
#       <td id="T_2ad5e_row6_col1" class="data row6 col1" >13522</td>
#       <td id="T_2ad5e_row6_col2" class="data row6 col2" >112_Pomfret_MVData_2020.csv</td>
#       <td id="T_2ad5e_row6_col3" class="data row6 col3" >4130</td>
#       <td id="T_2ad5e_row6_col4" class="data row6 col4" >-9392</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2ad5e_row7_col0" class="data row7 col0" >27_Clinton_MVData_2020.csv</td>
#       <td id="T_2ad5e_row7_col1" class="data row7 col1" >13202</td>
#       <td id="T_2ad5e_row7_col2" class="data row7 col2" >055_Goshen_MV_21.XLSX</td>
#       <td id="T_2ad5e_row7_col3" class="data row7 col3" >4004</td>
#       <td id="T_2ad5e_row7_col4" class="data row7 col4" >-9198</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2ad5e_row8_col0" class="data row8 col0" >141_Thompson_MV_21.xlsx</td>
#       <td id="T_2ad5e_row8_col1" class="data row8 col1" >10054</td>
#       <td id="T_2ad5e_row8_col2" class="data row8 col2" >098_Norfolk_MV_21.xlsx</td>
#       <td id="T_2ad5e_row8_col3" class="data row8 col3" >1945</td>
#       <td id="T_2ad5e_row8_col4" class="data row8 col4" >-8109</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2ad5e_row9_col0" class="data row9 col0" >037_Derby_MV_21.xls</td>
#       <td id="T_2ad5e_row9_col1" class="data row9 col1" >9511</td>
#       <td id="T_2ad5e_row9_col2" class="data row9 col2" >101_North_Haven_MV_21.xlsx</td>
#       <td id="T_2ad5e_row9_col3" class="data row9 col3" >84</td>
#       <td id="T_2ad5e_row9_col4" class="data row9 col4" >-9427</td>
#     </tr>
#     <tr>
#       <th id="T_2ad5e_level0_row10" class="row_heading level0 row10" >Total</th>
#       <td id="T_2ad5e_row10_col0" class="data row10 col0" ></td>
#       <td id="T_2ad5e_row10_col1" class="data row10 col1" >323972</td>
#       <td id="T_2ad5e_row10_col2" class="data row10 col2" ></td>
#       <td id="T_2ad5e_row10_col3" class="data row10 col3" >69369</td>
#       <td id="T_2ad5e_row10_col4" class="data row10 col4" >-254603</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***

# %% [markdown]
# **Consider missing VINs**

# %%
 missing_df.sort_values("missing VIN", ascending = False).head(20)
# Out:
#                            record_from  missing zip  missing VIN  \
# 134      11_Bloomfield_MVData_2019.csv            0        19643
# 108         107_Orange_MVData_2020.csv            0        14650
# 144              124_Seymour_MV_21.csv            0        13860
# 15   016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 180            141_Thompson_MV_21.xlsx            0          457
# 137          121_Salem_MVData_2019.csv            0          218
# 97          101_North_Haven_MV_21.xlsx           84           84
# 77           083_Middletown_MV_21.xlsx           82           82
# 168       136_Sterling_MVData_2019.csv           71           69
# 224             163_Windham_MV_21.xlsx           37           37
# 104       105_Old_Lyme_MVData_2019.csv           37           37
# 169            136_Sterling_MV_21.xlsx           36           34
# 223        163_Windham_MVData_2020.csv           34           34
# 191      147_Voluntown_MVData_2020.csv           29           29
# 23              024_Chaplin_MV_21.xlsx           29           29
# 25    028_Colchester_MV_21_ALTERED.csv            8            8
# 288         63_Hampton_MVData_2019.csv            2            2
# 71    077_Manchester_MV_21_ALTERED.csv            3            2
# 287          62_Hamden_MVData_2020.csv            2            2
# 83          089_New_Britain_MV_21.xlsx            2            2
#
#      missing street  not CT  count
# 134               0    1630  19643
# 108               0    1939  14650
# 144               0    1119  15410
# 15             4886    5074   7254
# 180               7     447  10054
# 137               0     126   4914
# 97               84    2978  24425
# 77               82    3060  35302
# 168              69     223   4249
# 224              37     848  16516
# 104              37     530   9135
# 169              34     161   4091
# 223              34     864  16228
# 191              29     105   3129
# 23               29     104   2645
# 25                8     701  16219
# 288               2      67   2446
# 71                3    2974  44487
# 287               3    3796  38900
# 83                2    2174  45226

# %% [markdown]
# **MISSING VINs**
# * Bloomfield file for 2019 does not contain VINs
# * Orange file for 2019 does not contain VINs
# * Seymour file has major issues for missing VINs
# * Bridgewater file - has this many missing VINs in the underlying file.
# * Thompson file - has 457 missing VINs in the underlying file anyway
#
# That is - since the VINs are missing in the underlying file anyway, nothing can be done to fix these missing VINs. So we are good.

# %% [markdown]
# **Consider missing street addresses**

# %%
 missing_df.sort_values("missing street", ascending = False).head(20)
# Out:
#                            record_from  missing zip  missing VIN  \
# 109              107_Orange_MV_21.xlsx        13522            0
# 39     045_East_Lyme_MV_21_ALTERED.csv         4475            0
# 248         27_Clinton_MVData_2020.csv        13202            0
# 33                 037_Derby_MV_21.xls         9511            0
# 15   016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 114       10_Bethlehem_MVData_2019.csv            0            0
# 119        112_Pomfret_MVData_2020.csv         4130            0
# 49               055_Goshen_MV_21.XLSX         4004            0
# 92              098_Norfolk_MV_21.xlsx         1945            0
# 97          101_North_Haven_MV_21.xlsx           84           84
# 77           083_Middletown_MV_21.xlsx           82           82
# 168       136_Sterling_MVData_2019.csv           71           69
# 104       105_Old_Lyme_MVData_2019.csv           37           37
# 224             163_Windham_MV_21.xlsx           37           37
# 169            136_Sterling_MV_21.xlsx           36           34
# 223        163_Windham_MVData_2020.csv           34           34
# 23              024_Chaplin_MV_21.xlsx           29           29
# 191      147_Voluntown_MVData_2020.csv           29           29
# 66       072_Ledyard_MV_21_ALTERED.csv          143            0
# 25    028_Colchester_MV_21_ALTERED.csv            8            8
#
#      missing street  not CT  count
# 109           13522   13522  13522
# 39            13325    5171  17616
# 248           13202   13202  13202
# 33             9511    9511   9511
# 15             4886    5074   7254
# 114            4760     206   4760
# 119            4130    4130   4130
# 49             4004    4004   4004
# 92             1945    1945   1945
# 97               84    2978  24425
# 77               82    3060  35302
# 168              69     223   4249
# 104              37     530   9135
# 224              37     848  16516
# 169              34     161   4091
# 223              34     864  16228
# 23               29     104   2645
# 191              29     105   3129
# 66                9     522  13858
# 25                8     701  16219

# %% [markdown]
# Orange 2021, Clinton 2020, Derby 2021, Bridgewater 2021 - All missing this info anyway.
# Bethlehem 2019, Pomfret 2020, Goshen 2021 - all the same
# Norfolk 2019 - is missing 1945 addresses in the underlying file

# %% [markdown]
# **Consider missing ZIP codes**

# %%
missing_df.sort_values("missing zip", ascending = False).head(20)
# Out:
#                                record_from  missing zip  missing VIN  \
# 109                  107_Orange_MV_21.xlsx        13522            0
# 248             27_Clinton_MVData_2020.csv        13202            0
# 160             131_Southington_MV_21.xlsx        10089            0
# 33                     037_Derby_MV_21.xls         9511            0
# 129                 117_Redding_MV_21.xlsx         8171            0
# 15       016_Bridgewater_MV_21_ALTERED.csv         4886         4886
# 39         045_East_Lyme_MV_21_ALTERED.csv         4475            0
# 267           44_East_Lyme_MVData_2019.csv         4301            0
# 119            112_Pomfret_MVData_2020.csv         4130            0
# 49                   055_Goshen_MV_21.XLSX         4004            0
# 92                  098_Norfolk_MV_21.xlsx         1945            0
# 303  77_Manchester_MVData_2019_ALTERED.csv          221            0
# 66           072_Ledyard_MV_21_ALTERED.csv          143            0
# 97              101_North_Haven_MV_21.xlsx           84           84
# 77               083_Middletown_MV_21.xlsx           82           82
# 74                   080_Meriden_MV_21.csv           78            0
# 168           136_Sterling_MVData_2019.csv           71           69
# 123            114_Preston_MVData_2020.csv           48            0
# 224                 163_Windham_MV_21.xlsx           37           37
# 104           105_Old_Lyme_MVData_2019.csv           37           37
#
#      missing street  not CT  count
# 109           13522   13522  13522
# 248           13202   13202  13202
# 160               2   12764  42996
# 33             9511    9511   9511
# 129               0    8171   8171
# 15             4886    5074   7254
# 39            13325    5171  17616
# 267               0    5215  17448
# 119            4130    4130   4130
# 49             4004    4004   4004
# 92             1945    1945   1945
# 303               0    3456  45785
# 66                9     522  13858
# 97               84    2978  24425
# 77               82    3060  35302
# 74                0    2475  45360
# 168              69     223   4249
# 123               0      14   4105
# 224              37     848  16516
# 104              37     530   9135

# %% [markdown]
# * Orange 2021 - **not an error** - the ZIP is genuinely missing in the underlying file
# * Clinton - is genuinely missing
# * Southington - 10,089 ZIPs are genuinely missing
# * Derby - is genuinely missing
# * Redding - is genuinely missing in the underlying file
# * Bridgewater 2021 - real
# * East Lyme 21 - really 4475 are indeed missing.
# * Pomfret - Real
# * Goshen - Real
# * Norfolk 2021 - genuinely missing
